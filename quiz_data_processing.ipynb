# %%
# Import general packages
import pandas as pd
import re
import io
import json

# Set environment variable to authenticate GCP credentials
# !export GOOGLE_APPLICATION_CREDENTIALS='book-to-quiz-7558e7ee5aca.json'

LOCATION = "us-central1"
PROJECT = 'book-to-quiz'
BUCKET = 'book-to-quiz-question-bank'

MODEL = "gemini-1.5-flash-001"

# %%
# Imports the Google Cloud client library
from google.cloud import storage

def gcs_read(bucket_name, blob_name):
    """Read a blob from GCS using file-like IO"""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("r") as file:
        # Return data as lines
        return file.readlines()
    
def gcs_write(bucket_name, blob_name, content):
    """Write a blob from GCS using file-like IO"""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("w") as file:
        file.write(content)

# %%
# Import Vertex AI packages
import vertexai
from vertexai.generative_models import GenerativeModel
import vertexai.preview.generative_models as generative_models

def generate(p_text, g_config, s_settings):
    """Yield text with generator which receive prompt text, generation config and safety settings as arguments"""
    vertexai.init(project=PROJECT, location=LOCATION)
    model = GenerativeModel(
        MODEL,
    )
    responses = model.generate_content(
        [p_text],
        generation_config=g_config,
        safety_settings=s_settings,
        stream=True,
    )

    for response in responses:
        yield response.text

# %%
prompt = """Generate quiz with these requirements:
- Total questions: 50.
- Topic: AWS.
- Difficulty: Hard.
- Types: true/false, single correct answer, multiple correct answers.
- Indent questions with number.
- Indent choices and true/false with upper letter.
- If more than 2 correct answers questions, remind  \"(select [exact number] apply)\" before choice A.
- In each question, total correct answers is less than total choices.
- Choices consist multiple technically complicated steps.
- Show correct choices at the end of each question.
- No markdown, plain text.
- Group by type."""

generation_config = {
    "max_output_tokens": 8192,
    "temperature": 1,
    "top_p": 0.95,
}

safety_settings = {
    generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

# %%
# Assign generator to a variable
generator = generate(prompt, generation_config, safety_settings)

# %%
# Use string comprehension to gather text from generator
generate_text = ''.join(response for response in generator)

# %%
# Use print() for generate_text for better preview because generated_text is whole string, not list of lines
print(generate_text)
# Out:
# ## True/False
#
# 1.  You can use AWS Lambda to run code in response to events, such as changes to an Amazon S3 bucket.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 2.  AWS IAM users can have access keys that are used to authenticate to AWS services.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 3.  Amazon CloudFront can be used to deliver static content from Amazon S3 buckets, but not dynamic content generated by EC2 instances.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 4.  Amazon DynamoDB can only be used to store structured data.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 5.  AWS Auto Scaling can automatically adjust the number of instances in an EC2 Auto Scaling group based on predefined metrics.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 6.  AWS CodePipeline can be used to automate the build, test, and deployment of applications.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 7.  AWS CloudTrail can only be used to audit API calls made to AWS services.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 8.  AWS KMS can be used to encrypt data stored in Amazon S3 buckets.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 9.  Amazon CloudWatch can be used to monitor the health and performance of AWS resources.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 10.  AWS Elastic Beanstalk can be used to deploy and manage applications on EC2 instances.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 11.  AWS Route 53 can be used to manage DNS records for domains and subdomains.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 12.  Amazon ElastiCache can be used to cache data in memory, improving application performance.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 13.  AWS Lambda can only be used to run code in response to events, not as a scheduled task.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 14.  Amazon Redshift can be used for data warehousing and analytics.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 15.  AWS Direct Connect can be used to establish a dedicated connection between your on-premises network and AWS.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 16.  Amazon SQS can be used to decouple applications and improve the reliability of message delivery.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 17.  AWS CloudFormation can be used to define and provision AWS resources.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 18.  AWS WAF can be used to protect web applications from common web attacks.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 19.  AWS SNS can be used to send notifications to subscribers.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 20.  AWS Lightsail is a service that provides a simple way to create and manage virtual private servers (VPS).
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 21.  AWS Elastic Load Balancing can distribute traffic across multiple EC2 instances.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 22.  AWS Athena can query data stored in Amazon S3 buckets without the need for a separate database.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 23.  Amazon EMR can be used to run Hadoop and Spark applications on AWS.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 24.  AWS CloudWatch Logs can be used to collect and analyze log data from AWS resources.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 25.  AWS Lambda functions can be written in multiple programming languages, including Python, Java, Node.js, and Go.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
#
# ## Single Correct Answer
#
# 26.  Which AWS service allows you to create and manage a virtual private cloud (VPC) in AWS?
#     A. Amazon EC2
#     B. AWS VPC
#     C. Amazon S3
#     D. AWS CloudFormation
#     **Correct Answer:** B. AWS VPC
#
# 27.  What is the purpose of AWS CloudTrail?
#     A. To monitor the health and performance of AWS resources
#     B. To encrypt data stored in Amazon S3 buckets
#     C. To audit API calls made to AWS services
#     D. To manage DNS records for domains and subdomains
#     **Correct Answer:** C. To audit API calls made to AWS services
#
# 28.  Which AWS service is a fully managed, serverless database service?
#     A. Amazon DynamoDB
#     B. Amazon RDS
#     C. Amazon Redshift
#     D. Amazon ElastiCache
#     **Correct Answer:** A. Amazon DynamoDB
#
# 29.  Which AWS service can be used to create a web application load balancer?
#     A. AWS Elastic Load Balancing
#     B. Amazon EC2
#     C. AWS Route 53
#     D. AWS CloudFront
#     **Correct Answer:** A. AWS Elastic Load Balancing
#
# 30.  Which AWS service is used to manage and deploy containerized applications?
#     A. Amazon ECS
#     B. AWS Lambda
#     C. AWS Elastic Beanstalk
#     D. Amazon EKS
#     **Correct Answer:** D. Amazon EKS
#
# 31.  Which AWS service provides a fully managed service for running Hadoop and Spark applications?
#     A. Amazon EMR
#     B. Amazon Redshift
#     C. Amazon Athena
#     D. Amazon S3
#     **Correct Answer:** A. Amazon EMR
#
# 32.  What is the purpose of AWS CloudWatch?
#     A. To manage DNS records for domains and subdomains
#     B. To monitor the health and performance of AWS resources
#     C. To encrypt data stored in Amazon S3 buckets
#     D. To audit API calls made to AWS services
#     **Correct Answer:** B. To monitor the health and performance of AWS resources
#
# 33.  Which AWS service provides a managed service for queuing messages?
#     A. Amazon SQS
#     B. AWS SNS
#     C. AWS Lambda
#     D. Amazon DynamoDB
#     **Correct Answer:** A. Amazon SQS
#
# 34.  Which AWS service can be used to create and manage databases on AWS?
#     A. Amazon RDS
#     B. Amazon DynamoDB
#     C. Amazon Redshift
#     D. Amazon ElastiCache
#     **Correct Answer:** A. Amazon RDS
#
# 35.  Which AWS service provides a managed service for running serverless functions?
#     A. AWS Lambda
#     B. Amazon EC2
#     C. AWS Elastic Beanstalk
#     D. AWS CodePipeline
#     **Correct Answer:** A. AWS Lambda
#
# 36.  Which AWS service can be used to distribute content to users around the world?
#     A. AWS CloudFront
#     B. Amazon S3
#     C. AWS Route 53
#     D. AWS Elastic Load Balancing
#     **Correct Answer:** A. AWS CloudFront
#
# 37.  Which AWS service provides a fully managed service for running Apache Cassandra databases?
#     A. Amazon Keyspaces
#     B. Amazon DynamoDB
#     C. Amazon RDS
#     D. Amazon ElastiCache
#     **Correct Answer:** A. Amazon Keyspaces
#
# 38.  Which AWS service can be used to encrypt data at rest and in transit?
#     A. AWS KMS
#     B. AWS CloudTrail
#     C. AWS WAF
#     D. AWS CloudWatch
#     **Correct Answer:** A. AWS KMS
#
# 39.  Which AWS service can be used to create and manage a virtual private network (VPN) in AWS?
#     A. AWS VPN
#     B. AWS Direct Connect
#     C. AWS Transit Gateway
#     D. AWS Route 53
#     **Correct Answer:** A. AWS VPN
#
# 40.  Which AWS service provides a fully managed service for running Apache Kafka?
#     A. Amazon MSK
#     B. Amazon Kinesis
#     C. Amazon SQS
#     D. Amazon SNS
#     **Correct Answer:** A. Amazon MSK
#
# 41.  Which AWS service allows you to automate the build, test, and deployment of applications?
#     A. AWS CodePipeline
#     B. AWS CodeBuild
#     C. AWS CodeDeploy
#     D. AWS CloudFormation
#     **Correct Answer:** A. AWS CodePipeline
#
# 42.  Which AWS service provides a managed service for running Redis databases?
#     A. Amazon ElastiCache
#     B. Amazon DynamoDB
#     C. Amazon RDS
#     D. Amazon Redshift
#     **Correct Answer:** A. Amazon ElastiCache
#
# 43.  Which AWS service can be used to manage and deploy applications on EC2 instances?
#     A. AWS Elastic Beanstalk
#     B. AWS Lambda
#     C. Amazon ECS
#     D. Amazon EKS
#     **Correct Answer:** A. AWS Elastic Beanstalk
#
# 44.  Which AWS service provides a managed service for running MongoDB databases?
#     A. Amazon DocumentDB
#     B. Amazon RDS
#     C. Amazon DynamoDB
#     D. Amazon ElastiCache
#     **Correct Answer:** A. Amazon DocumentDB
#
# 45.  Which AWS service can be used to create and manage a serverless application?
#     A. AWS Serverless Application Model (SAM)
#     B. AWS Lambda
#     C. AWS CloudFormation
#     D. AWS Elastic Beanstalk
#     **Correct Answer:** A. AWS Serverless Application Model (SAM)
#
# 46.  Which AWS service can be used to create and manage a virtual network gateway?
#     A. AWS Transit Gateway
#     B. AWS VPN
#     C. AWS Direct Connect
#     D. AWS Route 53
#     **Correct Answer:** A. AWS Transit Gateway
#
# 47.  Which AWS service can be used to create and manage a private DNS service?
#     A. AWS Route 53
#     B. AWS CloudFront
#     C. Amazon EC2
#     D. AWS VPC
#     **Correct Answer:** A. AWS Route 53
#
# 48.  Which AWS service provides a managed service for running PostgreSQL databases?
#     A. Amazon RDS
#     B. Amazon DynamoDB
#     C. Amazon Redshift
#     D. Amazon ElastiCache
#     **Correct Answer:** A. Amazon RDS
#
# 49.  Which AWS service can be used to manage and deploy microservices?
#     A. Amazon ECS
#     B. Amazon EKS
#     C. AWS Lambda
#     D. AWS Elastic Beanstalk
#     **Correct Answer:** B. Amazon EKS
#
# 50.  Which AWS service can be used to create and manage a global load balancer?
#     A. AWS Elastic Load Balancing
#     B. Amazon EC2
#     C. AWS CloudFront
#     D. AWS Route 53
#     **Correct Answer:** A. AWS Elastic Load Balancing
#
#
# ## Multiple Correct Answers
#
# 51.  Which of the following AWS services can be used to store data? (Select 3 that apply)
#     A. Amazon S3
#     B. Amazon DynamoDB
#     C. Amazon RDS
#     D. Amazon Redshift
#     E. Amazon ElastiCache
#     **Correct Answer:** A. Amazon S3, B. Amazon DynamoDB, C. Amazon RDS
#
# 52.  Which of the following AWS services can be used to monitor the health and performance of AWS resources? (Select 2 that apply)
#     A. AWS CloudWatch
#     B. AWS CloudTrail
#     C. AWS KMS
#     D. AWS WAF
#     **Correct Answer:** A. AWS CloudWatch, B. AWS CloudTrail
#
# 53.  Which of the following AWS services can be used to deploy applications? (Select 3 that apply)
#     A. AWS CodePipeline
#     B. AWS CodeBuild
#     C. AWS CodeDeploy
#     D. AWS Lambda
#     E. AWS Elastic Beanstalk
#     **Correct Answer:** A. AWS CodePipeline, C. AWS CodeDeploy, E. AWS Elastic Beanstalk
#
# 54.  Which of the following AWS services can be used to manage network connectivity? (Select 3 that apply)
#     A. AWS VPC
#     B. AWS Route 53
#     C. AWS Direct Connect
#     D. AWS Transit Gateway
#     E. AWS VPN
#     **Correct Answer:** A. AWS VPC, C. AWS Direct Connect, D. AWS Transit Gateway
#
# 55.  Which of the following AWS services can be used to run serverless applications? (Select 2 that apply)
#     A. AWS Lambda
#     B. Amazon ECS
#     C. Amazon EKS
#     D. AWS Elastic Beanstalk
#     **Correct Answer:** A. AWS Lambda, D. AWS Elastic Beanstalk
#
# 56.  Which of the following AWS services can be used to manage security? (Select 2 that apply)
#     A. AWS IAM
#     B. AWS KMS
#     C. AWS CloudTrail
#     D. AWS WAF
#     **Correct Answer:** A. AWS IAM, B. AWS KMS
#
# 57.  Which of the following AWS services can be used to manage databases? (Select 4 that apply)
#     A. Amazon RDS
#     B. Amazon DynamoDB
#     C. Amazon Redshift
#     D. Amazon ElastiCache
#     E. Amazon DocumentDB
#     F. Amazon Keyspaces
#     G. Amazon MSK
#     **Correct Answer:** A. Amazon RDS, B. Amazon DynamoDB, C. Amazon Redshift, E. Amazon DocumentDB
#
# 58.  Which of the following AWS services can be used to manage data analytics? (Select 2 that apply)
#     A. Amazon Redshift
#     B. Amazon Athena
#     C. Amazon EMR
#     D. Amazon S3
#     **Correct Answer:** A. Amazon Redshift, C. Amazon EMR
#
# 59.  Which of the following AWS services can be used to manage application development? (Select 3 that apply)
#     A. AWS CodePipeline
#     B. AWS CodeBuild
#     C. AWS CodeDeploy
#     D. AWS CloudFormation
#     E. AWS Lambda
#     **Correct Answer:** A. AWS CodePipeline, B. AWS CodeBuild, C. AWS CodeDeploy
#
# 60.  Which of the following AWS services can be used to manage application deployment? (Select 3 that apply)
#     A. AWS CodePipeline
#     B. AWS CodeDeploy
#     C. AWS CloudFormation
#     D. AWS Lambda
#     E. AWS Elastic Beanstalk
#     **Correct Answer:** A. AWS CodePipeline, B. AWS CodeDeploy, E. AWS Elastic Beanstalk

# %%
# Read generated text as lines
buf = io.StringIO(prompt)
lines = buf.readlines()

# Check topic line
topic_line = [line for line in lines if '- Topic: ' in line][0]
topic = topic_line[9:].rstrip('\n.')
topic = re.sub(' ', '_', topic.lower())
print('Topic:', topic)

# Check difficulty line
difficulty_line = [line for line in lines if '- Difficulty: ' in line][0]
difficulty = difficulty_line[14:].rstrip('\n.').lower()
print('Difficulty:', difficulty)

# Check size line
size_line = [line for line in lines if '- Total questions: ' in line][0]
size = size_line[19:].rstrip('\n.')
print('Size:', size)

# Combine topic, difficulty and size into .txt file name
file_name = f'{topic}_{difficulty}_{size}.txt'
print('File name:', file_name)
# Out:
# Topic: aws
# Difficulty: hard
# Size: 50
# File name: aws_hard_50.txt

# %%
# Assign file_name to a constant using for writing to GCS
WRITE_BLOB = file_name

gcs_write(BUCKET, WRITE_BLOB, generate_text)

# %%
# Assign file_name to a constant using for reading from GCS
READ_BLOB = file_name

data = gcs_read(BUCKET, READ_BLOB)

# Use display() because data is already list of lines structure
display(data)
# Out:
# ['## True/False\n',
#  '\n',
#  '1.  You can use AWS Lambda to run code in response to events, such as changes to an Amazon S3 bucket.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '2.  AWS IAM users can have access keys that are used to authenticate to AWS services.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '3.  Amazon CloudFront can be used to deliver static content from Amazon S3 buckets, but not dynamic content generated by EC2 instances.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '4.  Amazon DynamoDB can only be used to store structured data.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '5.  AWS Auto Scaling can automatically adjust the number of instances in an EC2 Auto Scaling group based on predefined metrics.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '6.  AWS CodePipeline can be used to automate the build, test, and deployment of applications.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '7.  AWS CloudTrail can only be used to audit API calls made to AWS services.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '8.  AWS KMS can be used to encrypt data stored in Amazon S3 buckets.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '9.  Amazon CloudWatch can be used to monitor the health and performance of AWS resources.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '10.  AWS Elastic Beanstalk can be used to deploy and manage applications on EC2 instances.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '11.  AWS Route 53 can be used to manage DNS records for domains and subdomains.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '12.  Amazon ElastiCache can be used to cache data in memory, improving application performance.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '13.  AWS Lambda can only be used to run code in response to events, not as a scheduled task.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '14.  Amazon Redshift can be used for data warehousing and analytics.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '15.  AWS Direct Connect can be used to establish a dedicated connection between your on-premises network and AWS.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '16.  Amazon SQS can be used to decouple applications and improve the reliability of message delivery.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '17.  AWS CloudFormation can be used to define and provision AWS resources.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '18.  AWS WAF can be used to protect web applications from common web attacks.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '19.  AWS SNS can be used to send notifications to subscribers.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '20.  AWS Lightsail is a service that provides a simple way to create and manage virtual private servers (VPS).\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '21.  AWS Elastic Load Balancing can distribute traffic across multiple EC2 instances.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '22.  AWS Athena can query data stored in Amazon S3 buckets without the need for a separate database.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '23.  Amazon EMR can be used to run Hadoop and Spark applications on AWS.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '24.  AWS CloudWatch Logs can be used to collect and analyze log data from AWS resources.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '25.  AWS Lambda functions can be written in multiple programming languages, including Python, Java, Node.js, and Go.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '\n',
#  '## Single Correct Answer\n',
#  '\n',
#  '26.  Which AWS service allows you to create and manage a virtual private cloud (VPC) in AWS?\n',
#  '    A. Amazon EC2\n',
#  '    B. AWS VPC\n',
#  '    C. Amazon S3\n',
#  '    D. AWS CloudFormation\n',
#  '    **Correct Answer:** B. AWS VPC\n',
#  '\n',
#  '27.  What is the purpose of AWS CloudTrail?\n',
#  '    A. To monitor the health and performance of AWS resources\n',
#  '    B. To encrypt data stored in Amazon S3 buckets\n',
#  '    C. To audit API calls made to AWS services\n',
#  '    D. To manage DNS records for domains and subdomains\n',
#  '    **Correct Answer:** C. To audit API calls made to AWS services\n',
#  '\n',
#  '28.  Which AWS service is a fully managed, serverless database service?\n',
#  '    A. Amazon DynamoDB\n',
#  '    B. Amazon RDS\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon ElastiCache\n',
#  '    **Correct Answer:** A. Amazon DynamoDB\n',
#  '\n',
#  '29.  Which AWS service can be used to create a web application load balancer?\n',
#  '    A. AWS Elastic Load Balancing\n',
#  '    B. Amazon EC2\n',
#  '    C. AWS Route 53\n',
#  '    D. AWS CloudFront\n',
#  '    **Correct Answer:** A. AWS Elastic Load Balancing\n',
#  '\n',
#  '30.  Which AWS service is used to manage and deploy containerized applications?\n',
#  '    A. Amazon ECS\n',
#  '    B. AWS Lambda\n',
#  '    C. AWS Elastic Beanstalk\n',
#  '    D. Amazon EKS\n',
#  '    **Correct Answer:** D. Amazon EKS\n',
#  '\n',
#  '31.  Which AWS service provides a fully managed service for running Hadoop and Spark applications?\n',
#  '    A. Amazon EMR\n',
#  '    B. Amazon Redshift\n',
#  '    C. Amazon Athena\n',
#  '    D. Amazon S3\n',
#  '    **Correct Answer:** A. Amazon EMR\n',
#  '\n',
#  '32.  What is the purpose of AWS CloudWatch?\n',
#  '    A. To manage DNS records for domains and subdomains\n',
#  '    B. To monitor the health and performance of AWS resources\n',
#  '    C. To encrypt data stored in Amazon S3 buckets\n',
#  '    D. To audit API calls made to AWS services\n',
#  '    **Correct Answer:** B. To monitor the health and performance of AWS resources\n',
#  '\n',
#  '33.  Which AWS service provides a managed service for queuing messages?\n',
#  '    A. Amazon SQS\n',
#  '    B. AWS SNS\n',
#  '    C. AWS Lambda\n',
#  '    D. Amazon DynamoDB\n',
#  '    **Correct Answer:** A. Amazon SQS\n',
#  '\n',
#  '34.  Which AWS service can be used to create and manage databases on AWS?\n',
#  '    A. Amazon RDS\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon ElastiCache\n',
#  '    **Correct Answer:** A. Amazon RDS\n',
#  '\n',
#  '35.  Which AWS service provides a managed service for running serverless functions?\n',
#  '    A. AWS Lambda\n',
#  '    B. Amazon EC2\n',
#  '    C. AWS Elastic Beanstalk\n',
#  '    D. AWS CodePipeline\n',
#  '    **Correct Answer:** A. AWS Lambda\n',
#  '\n',
#  '36.  Which AWS service can be used to distribute content to users around the world?\n',
#  '    A. AWS CloudFront\n',
#  '    B. Amazon S3\n',
#  '    C. AWS Route 53\n',
#  '    D. AWS Elastic Load Balancing\n',
#  '    **Correct Answer:** A. AWS CloudFront\n',
#  '\n',
#  '37.  Which AWS service provides a fully managed service for running Apache Cassandra databases?\n',
#  '    A. Amazon Keyspaces\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon RDS\n',
#  '    D. Amazon ElastiCache\n',
#  '    **Correct Answer:** A. Amazon Keyspaces\n',
#  '\n',
#  '38.  Which AWS service can be used to encrypt data at rest and in transit?\n',
#  '    A. AWS KMS\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS WAF\n',
#  '    D. AWS CloudWatch\n',
#  '    **Correct Answer:** A. AWS KMS\n',
#  '\n',
#  '39.  Which AWS service can be used to create and manage a virtual private network (VPN) in AWS?\n',
#  '    A. AWS VPN\n',
#  '    B. AWS Direct Connect\n',
#  '    C. AWS Transit Gateway\n',
#  '    D. AWS Route 53\n',
#  '    **Correct Answer:** A. AWS VPN\n',
#  '\n',
#  '40.  Which AWS service provides a fully managed service for running Apache Kafka?\n',
#  '    A. Amazon MSK\n',
#  '    B. Amazon Kinesis\n',
#  '    C. Amazon SQS\n',
#  '    D. Amazon SNS\n',
#  '    **Correct Answer:** A. Amazon MSK\n',
#  '\n',
#  '41.  Which AWS service allows you to automate the build, test, and deployment of applications?\n',
#  '    A. AWS CodePipeline\n',
#  '    B. AWS CodeBuild\n',
#  '    C. AWS CodeDeploy\n',
#  '    D. AWS CloudFormation\n',
#  '    **Correct Answer:** A. AWS CodePipeline\n',
#  '\n',
#  '42.  Which AWS service provides a managed service for running Redis databases?\n',
#  '    A. Amazon ElastiCache\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon RDS\n',
#  '    D. Amazon Redshift\n',
#  '    **Correct Answer:** A. Amazon ElastiCache\n',
#  '\n',
#  '43.  Which AWS service can be used to manage and deploy applications on EC2 instances?\n',
#  '    A. AWS Elastic Beanstalk\n',
#  '    B. AWS Lambda\n',
#  '    C. Amazon ECS\n',
#  '    D. Amazon EKS\n',
#  '    **Correct Answer:** A. AWS Elastic Beanstalk\n',
#  '\n',
#  '44.  Which AWS service provides a managed service for running MongoDB databases?\n',
#  '    A. Amazon DocumentDB\n',
#  '    B. Amazon RDS\n',
#  '    C. Amazon DynamoDB\n',
#  '    D. Amazon ElastiCache\n',
#  '    **Correct Answer:** A. Amazon DocumentDB\n',
#  '\n',
#  '45.  Which AWS service can be used to create and manage a serverless application?\n',
#  '    A. AWS Serverless Application Model (SAM)\n',
#  '    B. AWS Lambda\n',
#  '    C. AWS CloudFormation\n',
#  '    D. AWS Elastic Beanstalk\n',
#  '    **Correct Answer:** A. AWS Serverless Application Model (SAM)\n',
#  '\n',
#  '46.  Which AWS service can be used to create and manage a virtual network gateway?\n',
#  '    A. AWS Transit Gateway\n',
#  '    B. AWS VPN\n',
#  '    C. AWS Direct Connect\n',
#  '    D. AWS Route 53\n',
#  '    **Correct Answer:** A. AWS Transit Gateway\n',
#  '\n',
#  '47.  Which AWS service can be used to create and manage a private DNS service?\n',
#  '    A. AWS Route 53\n',
#  '    B. AWS CloudFront\n',
#  '    C. Amazon EC2\n',
#  '    D. AWS VPC\n',
#  '    **Correct Answer:** A. AWS Route 53\n',
#  '\n',
#  '48.  Which AWS service provides a managed service for running PostgreSQL databases?\n',
#  '    A. Amazon RDS\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon ElastiCache\n',
#  '    **Correct Answer:** A. Amazon RDS\n',
#  '\n',
#  '49.  Which AWS service can be used to manage and deploy microservices?\n',
#  '    A. Amazon ECS\n',
#  '    B. Amazon EKS\n',
#  '    C. AWS Lambda\n',
#  '    D. AWS Elastic Beanstalk\n',
#  '    **Correct Answer:** B. Amazon EKS\n',
#  '\n',
#  '50.  Which AWS service can be used to create and manage a global load balancer?\n',
#  '    A. AWS Elastic Load Balancing\n',
#  '    B. Amazon EC2\n',
#  '    C. AWS CloudFront\n',
#  '    D. AWS Route 53\n',
#  '    **Correct Answer:** A. AWS Elastic Load Balancing\n',
#  '\n',
#  '\n',
#  '## Multiple Correct Answers\n',
#  '\n',
#  '51.  Which of the following AWS services can be used to store data? (Select 3 that apply)\n',
#  '    A. Amazon S3\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon RDS\n',
#  '    D. Amazon Redshift\n',
#  '    E. Amazon ElastiCache\n',
#  '    **Correct Answer:** A. Amazon S3, B. Amazon DynamoDB, C. Amazon RDS\n',
#  '\n',
#  '52.  Which of the following AWS services can be used to monitor the health and performance of AWS resources? (Select 2 that apply)\n',
#  '    A. AWS CloudWatch\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS KMS\n',
#  '    D. AWS WAF\n',
#  '    **Correct Answer:** A. AWS CloudWatch, B. AWS CloudTrail\n',
#  '\n',
#  '53.  Which of the following AWS services can be used to deploy applications? (Select 3 that apply)\n',
#  '    A. AWS CodePipeline\n',
#  '    B. AWS CodeBuild\n',
#  '    C. AWS CodeDeploy\n',
#  '    D. AWS Lambda\n',
#  '    E. AWS Elastic Beanstalk\n',
#  '    **Correct Answer:** A. AWS CodePipeline, C. AWS CodeDeploy, E. AWS Elastic Beanstalk\n',
#  '\n',
#  '54.  Which of the following AWS services can be used to manage network connectivity? (Select 3 that apply)\n',
#  '    A. AWS VPC\n',
#  '    B. AWS Route 53\n',
#  '    C. AWS Direct Connect\n',
#  '    D. AWS Transit Gateway\n',
#  '    E. AWS VPN\n',
#  '    **Correct Answer:** A. AWS VPC, C. AWS Direct Connect, D. AWS Transit Gateway\n',
#  '\n',
#  '55.  Which of the following AWS services can be used to run serverless applications? (Select 2 that apply)\n',
#  '    A. AWS Lambda\n',
#  '    B. Amazon ECS\n',
#  '    C. Amazon EKS\n',
#  '    D. AWS Elastic Beanstalk\n',
#  '    **Correct Answer:** A. AWS Lambda, D. AWS Elastic Beanstalk\n',
#  '\n',
#  '56.  Which of the following AWS services can be used to manage security? (Select 2 that apply)\n',
#  '    A. AWS IAM\n',
#  '    B. AWS KMS\n',
#  '    C. AWS CloudTrail\n',
#  '    D. AWS WAF\n',
#  '    **Correct Answer:** A. AWS IAM, B. AWS KMS\n',
#  '\n',
#  '57.  Which of the following AWS services can be used to manage databases? (Select 4 that apply)\n',
#  '    A. Amazon RDS\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon ElastiCache\n',
#  '    E. Amazon DocumentDB\n',
#  '    F. Amazon Keyspaces\n',
#  '    G. Amazon MSK\n',
#  '    **Correct Answer:** A. Amazon RDS, B. Amazon DynamoDB, C. Amazon Redshift, E. Amazon DocumentDB\n',
#  '\n',
#  '58.  Which of the following AWS services can be used to manage data analytics? (Select 2 that apply)\n',
#  '    A. Amazon Redshift\n',
#  '    B. Amazon Athena\n',
#  '    C. Amazon EMR\n',
#  '    D. Amazon S3\n',
#  '    **Correct Answer:** A. Amazon Redshift, C. Amazon EMR\n',
#  '\n',
#  '59.  Which of the following AWS services can be used to manage application development? (Select 3 that apply)\n',
#  '    A. AWS CodePipeline\n',
#  '    B. AWS CodeBuild\n',
#  '    C. AWS CodeDeploy\n',
#  '    D. AWS CloudFormation\n',
#  '    E. AWS Lambda\n',
#  '    **Correct Answer:** A. AWS CodePipeline, B. AWS CodeBuild, C. AWS CodeDeploy\n',
#  '\n',
#  '60.  Which of the following AWS services can be used to manage application deployment? (Select 3 that apply)\n',
#  '    A. AWS CodePipeline\n',
#  '    B. AWS CodeDeploy\n',
#  '    C. AWS CloudFormation\n',
#  '    D. AWS Lambda\n',
#  '    E. AWS Elastic Beanstalk\n',
#  '    **Correct Answer:** A. AWS CodePipeline, B. AWS CodeDeploy, E. AWS Elastic Beanstalk\n']

# %%
def split_qa(lines_data):
    """Accepts list of lines. Returns a dictionary with keys `question` and `answer`"""
    dict_data = {'question': [],
                 'answer': []}
    
    # Switch determines if the last line is in question section or not
    q_prev = False
    
    for line in lines_data:
        # Strip '**' style around 'Correct answer(s)'
        line = line.replace('**', '')
        # Check if line is not blank or title, heading ('##')
        if (line != '\n') and ('##' not in line):
            # Call the first word of the line is `head`
            head = line.split()[0]
            
            # Append new question if all of these meet:
            # - `q_prev` is False
            # - First character of `head` is numeric
            # - Last character of `head` is '.'
            if (not q_prev) and head[0].isnumeric() and head[-1] == ".":
                dict_data['question'].append(line)
                q_prev = True
    
            # Append new answer if all of these meet:
            # - `q_prev` is True
            # - `head` is 'A.'
            elif q_prev and head == 'A.':
                dict_data['answer'].append(line)
                q_prev = False
    
            # Add line to unfinished question
            elif q_prev:
                dict_data['question'][-1] += line
        
            # Add line to unfinished answer
            else:
                dict_data['answer'][-1] += line
    
    return dict_data

# %%
# Return split_qa result to a variable
dict0 = split_qa(data)

# Convert `dict0` to a DataFrame
df0 = pd.DataFrame(dict0)

print('Number of questions:', len(df0))
print('Columns:', df0.columns.values)
# Out:
# Number of questions: 60
# Columns: ['question' 'answer']

# %%
# View some rows
df0.iloc[15:60]
# Out:
#                                              question  \
# 15  16. AWS CodeDeploy automates application deplo...
# 16  17. AWS Organizations allows you to centrally ...
# 17  18. AWS CloudTrail records API calls made to A...
# 18  19. AWS WAF provides a web application firewal...
# 19  20. AWS Shield is a managed DDoS protection se...
# 20  21. Which of the following AWS services is use...
# 21  22. Which of the following AWS services is a f...
# 22  23. Which of the following AWS services is use...
# 23  24. Which of the following AWS services is use...
# 24  25. Which of the following AWS services is use...
# 25  26. Which of the following AWS services is use...
# 26  27. Which of the following AWS services is a f...
# 27  28. Which of the following AWS services is use...
# 28  29. Which of the following AWS services is use...
# 29  30. Which of the following AWS services is use...
# 30  31. Which of the following AWS services is a m...
# 31  32. Which of the following AWS services is use...
# 32  33. Which of the following AWS services is use...
# 33  34. Which of the following AWS services is use...
# 34  35. Which of the following AWS services is use...
# 35  36. Which of the following AWS services is a f...
# 36  37. Which of the following AWS services is use...
# 37  38. Which of the following AWS services is a f...
# 38  39. Which of the following AWS services is use...
# 39  40. Which of the following AWS services is use...
# 40  41. (Select 2 answers) Which two of the follow...
# 41  42. (Select 3 answers) Which three of the foll...
# 42  43. (Select 2 answers) Which two of the follow...
# 43  44. (Select 3 answers) Which three of the foll...
# 44  45. (Select 2 answers) Which two of the follow...
# 45  46. (Select 3 answers) Which three of the foll...
# 46  47. (Select 2 answers) Which two of the follow...
# 47  48. (Select 3 answers) Which three of the foll...
# 48  49. (Select 2 answers) Which two of the follow...
# 49  50. (Select 2 answers) Which two of the follow...
#
#                                                answer
# 15      A. True\n    B. False\n    Correct Answer:...
# 16      A. True\n    B. False\n    Correct Answer:...
# 17      A. True\n    B. False\n    Correct Answer:...
# 18      A. True\n    B. False\n    Correct Answer:...
# 19      A. True\n    B. False\n    Correct Answer:...
# 20      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 21      A. Amazon Redshift\n    B. Amazon DynamoDB...
# 22      A. AWS Auto Scaling\n    B. AWS Elastic Be...
# 23      A. AWS CloudWatch\n    B. AWS CloudTrail\n...
# 24      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 25      A. AWS Elastic Beanstalk\n    B. AWS CodeD...
# 26      A. AWS Management Console\n    B. AWS CLI\...
# 27      A. AWS VPN\n    B. AWS Direct Connect\n   ...
# 28      A. AWS KMS\n    B. AWS IAM\n    C. AWS WAF...
# 29      A. AWS CloudFormation\n    B. AWS CodePipe...
# 30      A. AWS CLI\n    B. AWS SDK\n    C. AWS Lam...
# 31      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 32      A. AWS Security Groups\n    B. AWS IAM\n  ...
# 33      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 34      A. AWS IAM\n    B. AWS CloudTrail\n    C. ...
# 35      A. Amazon ElastiCache\n    B. Amazon Dynam...
# 36      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 37      A. Amazon S3\n    B. Amazon DynamoDB\n    ...
# 38      A. AWS Direct Connect\n    B. AWS VPN\n   ...
# 39      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 40      A. AWS Security Groups\n    B. AWS IAM\n  ...
# 41      A. AWS CloudWatch\n    B. AWS CloudTrail\n...
# 42      A. AWS Elastic Beanstalk\n    B. AWS CodeD...
# 43      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 44      A. AWS KMS\n    B. AWS IAM\n    C. AWS WAF...
# 45      A. AWS IAM\n    B. AWS CloudTrail\n    C. ...
# 46      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 47      A. AWS Direct Connect\n    B. AWS VPN\n   ...
# 48      A. AWS Security Groups\n    B. AWS IAM\n  ...
# 49      A. AWS CloudFormation\n    B. AWS CodePipe...

# %%
# Make a copy of df0
df1 = df0.copy()

# %%
# Strip the number at the beginning and '\n' at the end of each question 
df1['question'] = df1['question'].str.replace(r'^\d{0,4}\.[ ]', '', regex=True).str.rstrip()

# %%
df1
# Out:
#                                              question  \
# 0    You can use AWS Lambda to run code in respons...
# 1    AWS IAM users can have access keys that are u...
# 2    Amazon CloudFront can be used to deliver stat...
# 3    Amazon DynamoDB can only be used to store str...
# 4    AWS Auto Scaling can automatically adjust the...
# 5    AWS CodePipeline can be used to automate the ...
# 6    AWS CloudTrail can only be used to audit API ...
# 7    AWS KMS can be used to encrypt data stored in...
# 8    Amazon CloudWatch can be used to monitor the ...
# 9    AWS Elastic Beanstalk can be used to deploy a...
# 10   AWS Route 53 can be used to manage DNS record...
# 11   Amazon ElastiCache can be used to cache data ...
# 12   AWS Lambda can only be used to run code in re...
# 13   Amazon Redshift can be used for data warehous...
# 14   AWS Direct Connect can be used to establish a...
# 15   Amazon SQS can be used to decouple applicatio...
# 16   AWS CloudFormation can be used to define and ...
# 17   AWS WAF can be used to protect web applicatio...
# 18   AWS SNS can be used to send notifications to ...
# 19   AWS Lightsail is a service that provides a si...
# 20   AWS Elastic Load Balancing can distribute tra...
# 21   AWS Athena can query data stored in Amazon S3...
# 22   Amazon EMR can be used to run Hadoop and Spar...
# 23   AWS CloudWatch Logs can be used to collect an...
# 24   AWS Lambda functions can be written in multip...
# 25   Which AWS service allows you to create and ma...
# 26             What is the purpose of AWS CloudTrail?
# 27   Which AWS service is a fully managed, serverl...
# 28   Which AWS service can be used to create a web...
# 29   Which AWS service is used to manage and deplo...
# 30   Which AWS service provides a fully managed se...
# 31             What is the purpose of AWS CloudWatch?
# 32   Which AWS service provides a managed service ...
# 33   Which AWS service can be used to create and m...
# 34   Which AWS service provides a managed service ...
# 35   Which AWS service can be used to distribute c...
# 36   Which AWS service provides a fully managed se...
# 37   Which AWS service can be used to encrypt data...
# 38   Which AWS service can be used to create and m...
# 39   Which AWS service provides a fully managed se...
# 40   Which AWS service allows you to automate the ...
# 41   Which AWS service provides a managed service ...
# 42   Which AWS service can be used to manage and d...
# 43   Which AWS service provides a managed service ...
# 44   Which AWS service can be used to create and m...
# 45   Which AWS service can be used to create and m...
# 46   Which AWS service can be used to create and m...
# 47   Which AWS service provides a managed service ...
# 48   Which AWS service can be used to manage and d...
# 49   Which AWS service can be used to create and m...
# 50   Which of the following AWS services can be us...
# 51   Which of the following AWS services can be us...
# 52   Which of the following AWS services can be us...
# 53   Which of the following AWS services can be us...
# 54   Which of the following AWS services can be us...
# 55   Which of the following AWS services can be us...
# 56   Which of the following AWS services can be us...
# 57   Which of the following AWS services can be us...
# 58   Which of the following AWS services can be us...
# 59   Which of the following AWS services can be us...
#
#                                                answer
# 0       A. True\n    B. False\n    Correct Answer:...
# 1       A. True\n    B. False\n    Correct Answer:...
# 2       A. True\n    B. False\n    Correct Answer:...
# 3       A. True\n    B. False\n    Correct Answer:...
# 4       A. True\n    B. False\n    Correct Answer:...
# 5       A. True\n    B. False\n    Correct Answer:...
# 6       A. True\n    B. False\n    Correct Answer:...
# 7       A. True\n    B. False\n    Correct Answer:...
# 8       A. True\n    B. False\n    Correct Answer:...
# 9       A. True\n    B. False\n    Correct Answer:...
# 10      A. True\n    B. False\n    Correct Answer:...
# 11      A. True\n    B. False\n    Correct Answer:...
# 12      A. True\n    B. False\n    Correct Answer:...
# 13      A. True\n    B. False\n    Correct Answer:...
# 14      A. True\n    B. False\n    Correct Answer:...
# 15      A. True\n    B. False\n    Correct Answer:...
# 16      A. True\n    B. False\n    Correct Answer:...
# 17      A. True\n    B. False\n    Correct Answer:...
# 18      A. True\n    B. False\n    Correct Answer:...
# 19      A. True\n    B. False\n    Correct Answer:...
# 20      A. True\n    B. False\n    Correct Answer:...
# 21      A. True\n    B. False\n    Correct Answer:...
# 22      A. True\n    B. False\n    Correct Answer:...
# 23      A. True\n    B. False\n    Correct Answer:...
# 24      A. True\n    B. False\n    Correct Answer:...
# 25      A. Amazon EC2\n    B. AWS VPC\n    C. Amaz...
# 26      A. To monitor the health and performance o...
# 27      A. Amazon DynamoDB\n    B. Amazon RDS\n   ...
# 28      A. AWS Elastic Load Balancing\n    B. Amaz...
# 29      A. Amazon ECS\n    B. AWS Lambda\n    C. A...
# 30      A. Amazon EMR\n    B. Amazon Redshift\n   ...
# 31      A. To manage DNS records for domains and s...
# 32      A. Amazon SQS\n    B. AWS SNS\n    C. AWS ...
# 33      A. Amazon RDS\n    B. Amazon DynamoDB\n   ...
# 34      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 35      A. AWS CloudFront\n    B. Amazon S3\n    C...
# 36      A. Amazon Keyspaces\n    B. Amazon DynamoD...
# 37      A. AWS KMS\n    B. AWS CloudTrail\n    C. ...
# 38      A. AWS VPN\n    B. AWS Direct Connect\n   ...
# 39      A. Amazon MSK\n    B. Amazon Kinesis\n    ...
# 40      A. AWS CodePipeline\n    B. AWS CodeBuild\...
# 41      A. Amazon ElastiCache\n    B. Amazon Dynam...
# 42      A. AWS Elastic Beanstalk\n    B. AWS Lambd...
# 43      A. Amazon DocumentDB\n    B. Amazon RDS\n ...
# 44      A. AWS Serverless Application Model (SAM)\...
# 45      A. AWS Transit Gateway\n    B. AWS VPN\n  ...
# 46      A. AWS Route 53\n    B. AWS CloudFront\n  ...
# 47      A. Amazon RDS\n    B. Amazon DynamoDB\n   ...
# 48      A. Amazon ECS\n    B. Amazon EKS\n    C. A...
# 49      A. AWS Elastic Load Balancing\n    B. Amaz...
# 50      A. Amazon S3\n    B. Amazon DynamoDB\n    ...
# 51      A. AWS CloudWatch\n    B. AWS CloudTrail\n...
# 52      A. AWS CodePipeline\n    B. AWS CodeBuild\...
# 53      A. AWS VPC\n    B. AWS Route 53\n    C. AW...
# 54      A. AWS Lambda\n    B. Amazon ECS\n    C. A...
# 55      A. AWS IAM\n    B. AWS KMS\n    C. AWS Clo...
# 56      A. Amazon RDS\n    B. Amazon DynamoDB\n   ...
# 57      A. Amazon Redshift\n    B. Amazon Athena\n...
# 58      A. AWS CodePipeline\n    B. AWS CodeBuild\...
# 59      A. AWS CodePipeline\n    B. AWS CodeDeploy...

# %%
def convert_index(capital):
    """Return zero-based index from capital, 'A' has unicode code as 65"""
    return ord(capital) - 65

def split_choice(answer):
    """
    Split the `answer` data into multiple choices
    """
    # print(answer)
    
    # Use 'Correct Answer(s): ' to split text.
    # Index 0 is all choices, index 1 is all answers
    split_all = re.split(r'Correct Answer[s]*: ', answer)
    # print("After strip 'Correct Answer: ': ", split_all)
    
    choices = split_all[0]
    # print('Choices text:', choices)
    
    correct_stack = split_all[1]
    # print('Correct stack:', correct_stack)
    
    # Split using ','
    correct_stack = correct_stack.split(',')
    
    # Pick only first capital indicating the choices
    correct_note = [item.strip()[0] for item in correct_stack]
    # print('Correct note:', correct_note)
    
    # Make zero-based index from alphabet
    correct_index = [convert_index(item) for item in correct_note]
    # print('Correct index', correct_index)
    
    # Split using 'X. ', index 0 is '', so pass
    choices = re.split(r'[A-Z]\.[ ]', choices)[1:]
    # Strip right side of choice text
    choices = [choice.rstrip() for choice in choices]
    # print('All choices in list: ', choices)
    
    incorrect = [choice for index, choice in enumerate(choices) if index not in correct_index]
    # print('Incorrect in list: ', incorrect)
    correct = [choice for index, choice in enumerate(choices) if index in correct_index]
    # print('Correct in list: ', correct)
    
    return {'incorrect': incorrect,
            'correct': correct}

# %%
# Make a copy of `df1`
df_2 = df1.copy()

# %%
# Test the function with sub set of data
df_test = df_2.iloc[20:22]['answer'].apply(split_choice)

# %%
# Print out to preview results
display(df_test.str['incorrect'])
df_test.str['correct']
# Out:
# 20         [AWS Route 53, AWS VPC, AWS Direct Connect]
# 21    [Amazon DynamoDB, Amazon S3, Amazon ElastiCache]
# Name: answer, dtype: object
# 20    [AWS NAT Gateway]
# 21    [Amazon Redshift]
# Name: answer, dtype: object

# %%
# Apply the function to full dataset
df_2['incorrect'] = df_2['answer'].apply(split_choice).str['incorrect']
df_2['correct'] = df_2['answer'].apply(split_choice).str['correct']

# %%
# Preview a row
display(df_2.loc[40, 'incorrect'])
display(df_2.loc[40, 'correct'])
# Out:
# ['AWS IAM', 'AWS CloudTrail']
# ['AWS Security Groups', 'AWS Network Load Balancer']

# %%
# New order of columns
new_order = ['question', 'incorrect', 'correct']

# Make a copy of `df_a` with new order of columns
df_clean = df_2[new_order].copy()

# Preview data in a row
display(df_clean['incorrect'][45])
display(df_clean['correct'][45])
df_clean.iloc[45]
# Out:
# ['AWS Trusted Advisor']
# ['AWS IAM', 'AWS CloudTrail', 'AWS Config']
# question     (Select 3 answers) Which three of the followin...
# incorrect                                [AWS Trusted Advisor]
# correct                  [AWS IAM, AWS CloudTrail, AWS Config]
# Name: 45, dtype: object

# %%
# Preview the whole final table
df_clean
# Out:
#                                              question  \
# 0   You can use AWS Lambda to create a serverless ...
# 1   AWS CloudFormation allows you to define and ma...
# 2   AWS S3 offers a built-in feature called "serve...
# 3   AWS IAM roles can be used to grant temporary a...
# 4   AWS Lambda functions can directly access data ...
# 5   AWS EBS volumes can be attached to multiple EC...
# 6   AWS Auto Scaling can automatically adjust the ...
# 7   AWS DynamoDB is a fully managed NoSQL database...
# 8   AWS Kinesis is a fully managed streaming servi...
# 9   AWS Elastic Beanstalk supports deploying and m...
# 10  AWS CloudFront is a global content delivery ne...
# 11  AWS Elastic Load Balancing automatically distr...
# 12  AWS Redshift is a fully managed, petabyte-scal...
# 13  AWS CloudWatch provides monitoring and logging...
# 14  AWS CodePipeline is a fully managed continuous...
# 15  AWS CodeDeploy automates application deploymen...
# 16  AWS Organizations allows you to centrally mana...
# 17  AWS CloudTrail records API calls made to AWS s...
# 18  AWS WAF provides a web application firewall (W...
# 19  AWS Shield is a managed DDoS protection servic...
# 20  Which of the following AWS services is used to...
# 21  Which of the following AWS services is a fully...
# 22  Which of the following AWS services is used to...
# 23  Which of the following AWS services is used to...
# 24  Which of the following AWS services is used to...
# 25  Which of the following AWS services is used to...
# 26  Which of the following AWS services is a fully...
# 27  Which of the following AWS services is used to...
# 28  Which of the following AWS services is used to...
# 29  Which of the following AWS services is used to...
# 30  Which of the following AWS services is a manag...
# 31  Which of the following AWS services is used to...
# 32  Which of the following AWS services is used to...
# 33  Which of the following AWS services is used to...
# 34  Which of the following AWS services is used to...
# 35  Which of the following AWS services is a fully...
# 36  Which of the following AWS services is used to...
# 37  Which of the following AWS services is a fully...
# 38  Which of the following AWS services is used to...
# 39  Which of the following AWS services is used to...
# 40  (Select 2 answers) Which two of the following ...
# 41  (Select 3 answers) Which three of the followin...
# 42  (Select 2 answers) Which two of the following ...
# 43  (Select 3 answers) Which three of the followin...
# 44  (Select 2 answers) Which two of the following ...
# 45  (Select 3 answers) Which three of the followin...
# 46  (Select 2 answers) Which two of the following ...
# 47  (Select 3 answers) Which three of the followin...
# 48  (Select 2 answers) Which two of the following ...
# 49  (Select 2 answers) Which two of the following ...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                             [False]
# 2                                             [False]
# 3                                             [False]
# 4                                              [True]
# 5                                              [True]
# 6                                             [False]
# 7                                             [False]
# 8                                             [False]
# 9                                             [False]
# 10                                            [False]
# 11                                            [False]
# 12                                            [False]
# 13                                            [False]
# 14                                            [False]
# 15                                            [False]
# 16                                            [False]
# 17                                            [False]
# 18                                            [False]
# 19                                            [False]
# 20        [AWS Route 53, AWS VPC, AWS Direct Connect]
# 21   [Amazon DynamoDB, Amazon S3, Amazon ElastiCache]
# 22  [AWS Elastic Beanstalk, AWS CloudFormation, AW...
# 23  [AWS CloudTrail, AWS Config, AWS Trusted Advisor]
# 24  [AWS Direct Connect, AWS CloudFront, AWS Elast...
# 25  [AWS CodeDeploy, AWS CodePipeline, AWS CloudFo...
# 26                 [AWS CLI, AWS SDK, AWS CloudTrail]
# 27  [AWS Direct Connect, AWS Transit Gateway, AWS ...
# 28                     [AWS IAM, AWS WAF, AWS Shield]
# 29  [AWS CodePipeline, AWS CodeDeploy, AWS Elastic...
# 30          [AWS SDK, AWS Lambda, AWS CloudFormation]
# 31                  [AWS VPC, AWS CloudFront, AWS S3]
# 32                 [AWS IAM, AWS CloudTrail, AWS WAF]
# 33  [AWS Direct Connect, AWS Transit Gateway, AWS ...
# 34  [AWS CloudTrail, AWS Config, AWS Trusted Advisor]
# 35      [Amazon DynamoDB, Amazon S3, Amazon Redshift]
# 36  [AWS Direct Connect, AWS CloudFront, AWS Elast...
# 37  [Amazon DynamoDB, Amazon Redshift, Amazon Elas...
# 38       [AWS VPN, AWS Transit Gateway, AWS Route 53]
# 39                  [AWS VPC, AWS CloudFront, AWS S3]
# 40                          [AWS IAM, AWS CloudTrail]
# 41                                   [AWS CloudTrail]
# 42             [AWS CodePipeline, AWS CloudFormation]
# 43                                     [AWS Route 53]
# 44                              [AWS WAF, AWS Shield]
# 45                              [AWS Trusted Advisor]
# 46                            [AWS Route 53, AWS VPC]
# 47                                     [AWS Route 53]
# 48                          [AWS IAM, AWS CloudTrail]
# 49                 [AWS CodePipeline, AWS CodeDeploy]
#
#                                               correct
# 0                                             [False]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                             [False]
# 5                                             [False]
# 6                                              [True]
# 7                                              [True]
# 8                                              [True]
# 9                                              [True]
# 10                                             [True]
# 11                                             [True]
# 12                                             [True]
# 13                                             [True]
# 14                                             [True]
# 15                                             [True]
# 16                                             [True]
# 17                                             [True]
# 18                                             [True]
# 19                                             [True]
# 20                                  [AWS NAT Gateway]
# 21                                  [Amazon Redshift]
# 22                                 [AWS Auto Scaling]
# 23                                   [AWS CloudWatch]
# 24                                          [AWS VPC]
# 25                            [AWS Elastic Beanstalk]
# 26                           [AWS Management Console]
# 27                                          [AWS VPN]
# 28                                          [AWS KMS]
# 29                               [AWS CloudFormation]
# 30                                          [AWS CLI]
# 31                                     [AWS Route 53]
# 32                              [AWS Security Groups]
# 33                                          [AWS VPC]
# 34                                          [AWS IAM]
# 35                               [Amazon ElastiCache]
# 36                                          [AWS VPC]
# 37                                        [Amazon S3]
# 38                               [AWS Direct Connect]
# 39                                     [AWS Route 53]
# 40   [AWS Security Groups, AWS Network Load Balancer]
# 41  [AWS CloudWatch, AWS Config, AWS Trusted Advisor]
# 42            [AWS Elastic Beanstalk, AWS CodeDeploy]
# 43  [AWS VPC, AWS Direct Connect, AWS Transit Gate...
# 44                                 [AWS KMS, AWS IAM]
# 45              [AWS IAM, AWS CloudTrail, AWS Config]
# 46              [AWS NAT Gateway, AWS Direct Connect]
# 47  [AWS Direct Connect, AWS VPN, AWS Transit Gate...
# 48   [AWS Security Groups, AWS Network Load Balancer]
# 49        [AWS CloudFormation, AWS Elastic Beanstalk]

# %%
# Pick up the read blob name with '.txt' excluded, to make new json file name
export_file = READ_BLOB[:-4] + '.json'

# Export `df_clean` to a JSON file
df_clean.to_json(export_file)

# %%
# Read exported json file as DataFrame
df_json = pd.read_json(export_file)

# %%
# Preview json file data
df_json
# Out:
#                                              question  \
# 0   You can use AWS Lambda to create a serverless ...
# 1   AWS CloudFormation allows you to define and ma...
# 2   AWS S3 offers a built-in feature called "serve...
# 3   AWS IAM roles can be used to grant temporary a...
# 4   AWS Lambda functions can directly access data ...
# 5   AWS EBS volumes can be attached to multiple EC...
# 6   AWS Auto Scaling can automatically adjust the ...
# 7   AWS DynamoDB is a fully managed NoSQL database...
# 8   AWS Kinesis is a fully managed streaming servi...
# 9   AWS Elastic Beanstalk supports deploying and m...
# 10  AWS CloudFront is a global content delivery ne...
# 11  AWS Elastic Load Balancing automatically distr...
# 12  AWS Redshift is a fully managed, petabyte-scal...
# 13  AWS CloudWatch provides monitoring and logging...
# 14  AWS CodePipeline is a fully managed continuous...
# 15  AWS CodeDeploy automates application deploymen...
# 16  AWS Organizations allows you to centrally mana...
# 17  AWS CloudTrail records API calls made to AWS s...
# 18  AWS WAF provides a web application firewall (W...
# 19  AWS Shield is a managed DDoS protection servic...
# 20  Which of the following AWS services is used to...
# 21  Which of the following AWS services is a fully...
# 22  Which of the following AWS services is used to...
# 23  Which of the following AWS services is used to...
# 24  Which of the following AWS services is used to...
# 25  Which of the following AWS services is used to...
# 26  Which of the following AWS services is a fully...
# 27  Which of the following AWS services is used to...
# 28  Which of the following AWS services is used to...
# 29  Which of the following AWS services is used to...
# 30  Which of the following AWS services is a manag...
# 31  Which of the following AWS services is used to...
# 32  Which of the following AWS services is used to...
# 33  Which of the following AWS services is used to...
# 34  Which of the following AWS services is used to...
# 35  Which of the following AWS services is a fully...
# 36  Which of the following AWS services is used to...
# 37  Which of the following AWS services is a fully...
# 38  Which of the following AWS services is used to...
# 39  Which of the following AWS services is used to...
# 40  (Select 2 answers) Which two of the following ...
# 41  (Select 3 answers) Which three of the followin...
# 42  (Select 2 answers) Which two of the following ...
# 43  (Select 3 answers) Which three of the followin...
# 44  (Select 2 answers) Which two of the following ...
# 45  (Select 3 answers) Which three of the followin...
# 46  (Select 2 answers) Which two of the following ...
# 47  (Select 3 answers) Which three of the followin...
# 48  (Select 2 answers) Which two of the following ...
# 49  (Select 2 answers) Which two of the following ...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                             [False]
# 2                                             [False]
# 3                                             [False]
# 4                                              [True]
# 5                                              [True]
# 6                                             [False]
# 7                                             [False]
# 8                                             [False]
# 9                                             [False]
# 10                                            [False]
# 11                                            [False]
# 12                                            [False]
# 13                                            [False]
# 14                                            [False]
# 15                                            [False]
# 16                                            [False]
# 17                                            [False]
# 18                                            [False]
# 19                                            [False]
# 20        [AWS Route 53, AWS VPC, AWS Direct Connect]
# 21   [Amazon DynamoDB, Amazon S3, Amazon ElastiCache]
# 22  [AWS Elastic Beanstalk, AWS CloudFormation, AW...
# 23  [AWS CloudTrail, AWS Config, AWS Trusted Advisor]
# 24  [AWS Direct Connect, AWS CloudFront, AWS Elast...
# 25  [AWS CodeDeploy, AWS CodePipeline, AWS CloudFo...
# 26                 [AWS CLI, AWS SDK, AWS CloudTrail]
# 27  [AWS Direct Connect, AWS Transit Gateway, AWS ...
# 28                     [AWS IAM, AWS WAF, AWS Shield]
# 29  [AWS CodePipeline, AWS CodeDeploy, AWS Elastic...
# 30          [AWS SDK, AWS Lambda, AWS CloudFormation]
# 31                  [AWS VPC, AWS CloudFront, AWS S3]
# 32                 [AWS IAM, AWS CloudTrail, AWS WAF]
# 33  [AWS Direct Connect, AWS Transit Gateway, AWS ...
# 34  [AWS CloudTrail, AWS Config, AWS Trusted Advisor]
# 35      [Amazon DynamoDB, Amazon S3, Amazon Redshift]
# 36  [AWS Direct Connect, AWS CloudFront, AWS Elast...
# 37  [Amazon DynamoDB, Amazon Redshift, Amazon Elas...
# 38       [AWS VPN, AWS Transit Gateway, AWS Route 53]
# 39                  [AWS VPC, AWS CloudFront, AWS S3]
# 40                          [AWS IAM, AWS CloudTrail]
# 41                                   [AWS CloudTrail]
# 42             [AWS CodePipeline, AWS CloudFormation]
# 43                                     [AWS Route 53]
# 44                              [AWS WAF, AWS Shield]
# 45                              [AWS Trusted Advisor]
# 46                            [AWS Route 53, AWS VPC]
# 47                                     [AWS Route 53]
# 48                          [AWS IAM, AWS CloudTrail]
# 49                 [AWS CodePipeline, AWS CodeDeploy]
#
#                                               correct
# 0                                             [False]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                             [False]
# 5                                             [False]
# 6                                              [True]
# 7                                              [True]
# 8                                              [True]
# 9                                              [True]
# 10                                             [True]
# 11                                             [True]
# 12                                             [True]
# 13                                             [True]
# 14                                             [True]
# 15                                             [True]
# 16                                             [True]
# 17                                             [True]
# 18                                             [True]
# 19                                             [True]
# 20                                  [AWS NAT Gateway]
# 21                                  [Amazon Redshift]
# 22                                 [AWS Auto Scaling]
# 23                                   [AWS CloudWatch]
# 24                                          [AWS VPC]
# 25                            [AWS Elastic Beanstalk]
# 26                           [AWS Management Console]
# 27                                          [AWS VPN]
# 28                                          [AWS KMS]
# 29                               [AWS CloudFormation]
# 30                                          [AWS CLI]
# 31                                     [AWS Route 53]
# 32                              [AWS Security Groups]
# 33                                          [AWS VPC]
# 34                                          [AWS IAM]
# 35                               [Amazon ElastiCache]
# 36                                          [AWS VPC]
# 37                                        [Amazon S3]
# 38                               [AWS Direct Connect]
# 39                                     [AWS Route 53]
# 40   [AWS Security Groups, AWS Network Load Balancer]
# 41  [AWS CloudWatch, AWS Config, AWS Trusted Advisor]
# 42            [AWS Elastic Beanstalk, AWS CodeDeploy]
# 43  [AWS VPC, AWS Direct Connect, AWS Transit Gate...
# 44                                 [AWS KMS, AWS IAM]
# 45              [AWS IAM, AWS CloudTrail, AWS Config]
# 46              [AWS NAT Gateway, AWS Direct Connect]
# 47  [AWS Direct Connect, AWS VPN, AWS Transit Gate...
# 48   [AWS Security Groups, AWS Network Load Balancer]
# 49        [AWS CloudFormation, AWS Elastic Beanstalk]

# %%
# Load json file in conventional way
f = open(export_file)
data = json.load(f)

# Preview index
data['question']['15']
# Out:
# 'AWS CodeDeploy automates application deployments to EC2 instances, making it easier to deploy and update your applications.\n'

# %%
import io

# Import packages
import pandas as pd
import re

# Set environment variable to authenticate GCP credentials
# !export GOOGLE_APPLICATION_CREDENTIALS='book-to-quiz-7558e7ee5aca.json'

LOCATION = "us-central1"
PROJECT = 'book-to-quiz'
BUCKET = 'book-to-quiz-question-bank'

MODEL = "gemini-1.5-flash-001"

# %%
# Imports the Google Cloud client library
from google.cloud import storage

def gcs_read(bucket_name, blob_name):
    """Read a blob from GCS using file-like IO"""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("r") as file:
        # Return data as lines
        return file.readlines()
    
def gcs_write(bucket_name, blob_name, content):
    """Write a blob from GCS using file-like IO"""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("w") as file:
        file.write(content)

# %%
import vertexai
from vertexai.generative_models import GenerativeModel
import vertexai.preview.generative_models as generative_models

def generate(p_text, g_config, s_settings):
  vertexai.init(project=PROJECT, location=LOCATION)
  model = GenerativeModel(
    MODEL,
  )
  responses = model.generate_content(
      [p_text],
      generation_config=g_config,
      safety_settings=s_settings,
      stream=True,
  )

  for response in responses:
    yield response.text

# %%
prompt = """Generate quiz with these requirements:
- Total questions: 50.
- Topic: AWS.
- Difficulty: Hard.
- Types: true/false, single correct answer, multiple correct answers.
- Indent questions with number.
- Indent choices and true/false with upper letter.
- If more than 2 correct answers questions, remind  \"(select [exact number] apply)\" before choice A.
- In each question, total correct answers is less than total choices.
- Choices consist multiple technically complicated steps.
- Show correct choices at the end of each question.
- No markdown, plain text.
- Group by type."""

generation_config = {
    "max_output_tokens": 8192,
    "temperature": 1,
    "top_p": 0.95,
}

safety_settings = {
    generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

# %%
generator = generate(prompt, generation_config, safety_settings)

# %%
generate_text = ''.join(response for response in generator)
display(generate_text)
# Out:
# '## True/False Questions\n\n1. You can use AWS Lambda to create a serverless application that runs on a specific EC2 instance.\n    A. True\n    B. False\n    **Correct Answer: B. False**\n\n2. AWS CloudFormation allows you to define and manage your AWS resources using a declarative language, making infrastructure as code possible.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n3. AWS S3 offers a built-in feature called "server-side encryption" that encrypts data at rest.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n4. AWS IAM roles can be used to grant temporary access to AWS resources without having to manage user credentials.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n5. AWS Lambda functions can directly access data in an Amazon RDS database without any configuration or security considerations.\n    A. True\n    B. False\n    **Correct Answer: B. False**\n\n6. AWS EBS volumes can be attached to multiple EC2 instances simultaneously, allowing for shared data access.\n    A. True\n    B. False\n    **Correct Answer: B. False**\n\n7. AWS Auto Scaling can automatically adjust the capacity of your EC2 instances based on predefined metrics, such as CPU utilization.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n8. AWS DynamoDB is a fully managed NoSQL database service that offers ACID properties.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n9. AWS Kinesis is a fully managed streaming service that can be used to ingest and process real-time data from various sources.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n10. AWS Elastic Beanstalk supports deploying and managing applications built on various programming languages and frameworks.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n11. AWS CloudFront is a global content delivery network (CDN) that caches static content closer to users, improving website performance.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n12. AWS Elastic Load Balancing automatically distributes incoming traffic across multiple EC2 instances, ensuring high availability and fault tolerance.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n13. AWS Redshift is a fully managed, petabyte-scale data warehouse service designed for analytical workloads.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n14. AWS CloudWatch provides monitoring and logging capabilities for various AWS services, allowing you to track metrics and identify potential issues.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n15. AWS CodePipeline is a fully managed continuous delivery service that automates the release of your applications to different environments.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n16. AWS CodeDeploy automates application deployments to EC2 instances, making it easier to deploy and update your applications.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n17. AWS Organizations allows you to centrally manage and govern multiple AWS accounts within your organization.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n18. AWS CloudTrail records API calls made to AWS services, enabling auditing and security analysis.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n19. AWS WAF provides a web application firewall (WAF) that helps protect your web applications from common web attacks.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n20. AWS Shield is a managed DDoS protection service that helps protect your applications and websites from large-scale DDoS attacks.\n    A. True\n    B. False\n    **Correct Answer: A. True**\n\n## Single Correct Answer Questions\n\n21. Which of the following AWS services is used to manage and configure network connectivity between your VPC and the internet?\n    A. AWS Route 53\n    B. AWS VPC\n    C. AWS NAT Gateway\n    D. AWS Direct Connect\n ...

# %%
buf = io.StringIO(prompt)
lines = buf.readlines()
topic_line = [line for line in lines if '- Topic: ' in line][0]
topic = topic_line[9:].rstrip('\n.')
topic = re.sub(' ', '_', topic.lower())
print(topic)
difficulty_line = [line for line in lines if '- Difficulty: ' in line][0]
difficulty = difficulty_line[14:].rstrip('\n.').lower()
print(difficulty)
size_line = [line for line in lines if '- Total questions: ' in line][0]
size = size_line[19:].rstrip('\n.')
print(size)

file_name = f'{topic}_{difficulty}_{size}.txt'
print(file_name)
# Out:
# aws
# hard
# 50
# aws_hard_50.txt

# %%
WRITE_BLOB = file_name
gcs_write(BUCKET, WRITE_BLOB, generate_text)

# %%
READ_BLOB = file_name
data = gcs_read(BUCKET, READ_BLOB)

display(data)
# Out:
# ['## True/False Questions\n',
#  '\n',
#  '1. You can use AWS Lambda to create a serverless application that runs on a specific EC2 instance.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: B. False**\n',
#  '\n',
#  '2. AWS CloudFormation allows you to define and manage your AWS resources using a declarative language, making infrastructure as code possible.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '3. AWS S3 offers a built-in feature called "server-side encryption" that encrypts data at rest.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '4. AWS IAM roles can be used to grant temporary access to AWS resources without having to manage user credentials.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '5. AWS Lambda functions can directly access data in an Amazon RDS database without any configuration or security considerations.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: B. False**\n',
#  '\n',
#  '6. AWS EBS volumes can be attached to multiple EC2 instances simultaneously, allowing for shared data access.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: B. False**\n',
#  '\n',
#  '7. AWS Auto Scaling can automatically adjust the capacity of your EC2 instances based on predefined metrics, such as CPU utilization.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '8. AWS DynamoDB is a fully managed NoSQL database service that offers ACID properties.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '9. AWS Kinesis is a fully managed streaming service that can be used to ingest and process real-time data from various sources.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '10. AWS Elastic Beanstalk supports deploying and managing applications built on various programming languages and frameworks.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '11. AWS CloudFront is a global content delivery network (CDN) that caches static content closer to users, improving website performance.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '12. AWS Elastic Load Balancing automatically distributes incoming traffic across multiple EC2 instances, ensuring high availability and fault tolerance.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '13. AWS Redshift is a fully managed, petabyte-scale data warehouse service designed for analytical workloads.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '14. AWS CloudWatch provides monitoring and logging capabilities for various AWS services, allowing you to track metrics and identify potential issues.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '15. AWS CodePipeline is a fully managed continuous delivery service that automates the release of your applications to different environments.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '16. AWS CodeDeploy automates application deployments to EC2 instances, making it easier to deploy and update your applications.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '17. AWS Organizations allows you to centrally manage and govern multiple AWS accounts within your organization.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '18. AWS CloudTrail records API calls made to AWS services, enabling auditing and security analysis.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '19. AWS WAF provides a web application firewall (WAF) that helps protect your web applications from common web attacks.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '20. AWS Shield is a managed DDoS protection service that helps protect your applications and websites from large-scale DDoS attacks.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer: A. True**\n',
#  '\n',
#  '## Single Correct Answer Questions\n',
#  '\n',
#  '21. Which of the following AWS services is used to manage and configure network connectivity between your VPC and the internet?\n',
#  '    A. AWS Route 53\n',
#  '    B. AWS VPC\n',
#  '    C. AWS NAT Gateway\n',
#  '    D. AWS Direct Connect\n',
#  '    **Correct Answer: C. AWS NAT Gateway**\n',
#  '\n',
#  '22. Which of the following AWS services is a fully managed, serverless data warehouse service designed for analytical workloads?\n',
#  '    A. Amazon Redshift\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon S3\n',
#  '    D. Amazon ElastiCache\n',
#  '    **Correct Answer: A. Amazon Redshift**\n',
#  '\n',
#  '23. Which of the following AWS services is used to automatically scale your EC2 instances based on predefined metrics?\n',
#  '    A. AWS Auto Scaling\n',
#  '    B. AWS Elastic Beanstalk\n',
#  '    C. AWS CloudFormation\n',
#  '    D. AWS CodeDeploy\n',
#  '    **Correct Answer: A. AWS Auto Scaling**\n',
#  '\n',
#  '24. Which of the following AWS services is used to manage and monitor your AWS resources, including infrastructure, applications, and services?\n',
#  '    A. AWS CloudWatch\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS Config\n',
#  '    D. AWS Trusted Advisor\n',
#  '    **Correct Answer: A. AWS CloudWatch**\n',
#  '\n',
#  '25. Which of the following AWS services is used to create and manage your own private cloud within AWS?\n',
#  '    A. AWS VPC\n',
#  '    B. AWS Direct Connect\n',
#  '    C. AWS CloudFront\n',
#  '    D. AWS Elastic Load Balancing\n',
#  '    **Correct Answer: A. AWS VPC**\n',
#  '\n',
#  '26. Which of the following AWS services is used to deploy and manage your applications on AWS, abstracting away the underlying infrastructure?\n',
#  '    A. AWS Elastic Beanstalk\n',
#  '    B. AWS CodeDeploy\n',
#  '    C. AWS CodePipeline\n',
#  '    D. AWS CloudFormation\n',
#  '    **Correct Answer: A. AWS Elastic Beanstalk**\n',
#  '\n',
#  '27. Which of the following AWS services is a fully managed service that allows you to access and manage your AWS resources from a central console?\n',
#  '    A. AWS Management Console\n',
#  '    B. AWS CLI\n',
#  '    C. AWS SDK\n',
#  '    D. AWS CloudTrail\n',
#  '    **Correct Answer: A. AWS Management Console**\n',
#  '\n',
#  '28. Which of the following AWS services is used to create and manage your own virtual private network (VPN) connections within AWS?\n',
#  '    A. AWS VPN\n',
#  '    B. AWS Direct Connect\n',
#  '    C. AWS Transit Gateway\n',
#  '    D. AWS Route 53\n',
#  '    **Correct Answer: A. AWS VPN**\n',
#  '\n',
#  '29. Which of the following AWS services is used to secure your AWS resources using encryption at rest and in transit?\n',
#  '    A. AWS KMS\n',
#  '    B. AWS IAM\n',
#  '    C. AWS WAF\n',
#  '    D. AWS Shield\n',
#  '    **Correct Answer: A. AWS KMS**\n',
#  '\n',
#  '30. Which of the following AWS services is used to deploy and manage your applications using a declarative language, making infrastructure as code possible?\n',
#  '    A. AWS CloudFormation\n',
#  '    B. AWS CodePipeline\n',
#  '    C. AWS CodeDeploy\n',
#  '    D. AWS Elastic Beanstalk\n',
#  '    **Correct Answer: A. AWS CloudFormation**\n',
#  '\n',
#  '31. Which of the following AWS services is a managed service that allows you to access and manage your AWS resources using code?\n',
#  '    A. AWS CLI\n',
#  '    B. AWS SDK\n',
#  '    C. AWS Lambda\n',
#  '    D. AWS CloudFormation\n',
#  '    **Correct Answer: A. AWS CLI**\n',
#  '\n',
#  '32. Which of the following AWS services is used to create and manage your own custom domains and DNS records?\n',
#  '    A. AWS Route 53\n',
#  '    B. AWS VPC\n',
#  '    C. AWS CloudFront\n',
#  '    D. AWS S3\n',
#  '    **Correct Answer: A. AWS Route 53**\n',
#  '\n',
#  '33. Which of the following AWS services is used to manage and configure network security within your VPC?\n',
#  '    A. AWS Security Groups\n',
#  '    B. AWS IAM\n',
#  '    C. AWS CloudTrail\n',
#  '    D. AWS WAF\n',
#  '    **Correct Answer: A. AWS Security Groups**\n',
#  '\n',
#  '34. Which of the following AWS services is used to create and manage your own private virtual network within AWS?\n',
#  '    A. AWS VPC\n',
#  '    B. AWS Direct Connect\n',
#  '    C. AWS Transit Gateway\n',
#  '    D. AWS Route 53\n',
#  '    **Correct Answer: A. AWS VPC**\n',
#  '\n',
#  '35. Which of the following AWS services is used to manage and configure access to your AWS resources?\n',
#  '    A. AWS IAM\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS Config\n',
#  '    D. AWS Trusted Advisor\n',
#  '    **Correct Answer: A. AWS IAM**\n',
#  '\n',
#  '36. Which of the following AWS services is a fully managed, in-memory caching service that improves application performance?\n',
#  '    A. Amazon ElastiCache\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon S3\n',
#  '    D. Amazon Redshift\n',
#  '    **Correct Answer: A. Amazon ElastiCache**\n',
#  '\n',
#  '37. Which of the following AWS services is used to create and manage your own virtual private clouds (VPCs) within AWS?\n',
#  '    A. AWS VPC\n',
#  '    B. AWS Direct Connect\n',
#  '    C. AWS CloudFront\n',
#  '    D. AWS Elastic Load Balancing\n',
#  '    **Correct Answer: A. AWS VPC**\n',
#  '\n',
#  '38. Which of the following AWS services is a fully managed service that provides a secure and scalable way to store and retrieve data?\n',
#  '    A. Amazon S3\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon ElastiCache\n',
#  '    **Correct Answer: A. Amazon S3**\n',
#  '\n',
#  '39. Which of the following AWS services is used to manage and configure network connectivity between your VPC and on-premises data centers?\n',
#  '    A. AWS Direct Connect\n',
#  '    B. AWS VPN\n',
#  '    C. AWS Transit Gateway\n',
#  '    D. AWS Route 53\n',
#  '    **Correct Answer: A. AWS Direct Connect**\n',
#  '\n',
#  '40. Which of the following AWS services is used to create and manage your own custom domains and DNS records?\n',
#  '    A. AWS Route 53\n',
#  '    B. AWS VPC\n',
#  '    C. AWS CloudFront\n',
#  '    D. AWS S3\n',
#  '    **Correct Answer: A. AWS Route 53**\n',
#  '\n',
#  '## Multiple Correct Answers Questions\n',
#  '\n',
#  '41. (Select 2 answers) Which two of the following AWS services are used to manage and configure network security within your VPC?\n',
#  '    A. AWS Security Groups\n',
#  '    B. AWS IAM\n',
#  '    C. AWS CloudTrail\n',
#  '    D. AWS Network Load Balancer\n',
#  '    **Correct Answers: A. AWS Security Groups, D. AWS Network Load Balancer**\n',
#  '\n',
#  '42. (Select 3 answers) Which three of the following AWS services are used to monitor and manage your AWS resources?\n',
#  '    A. AWS CloudWatch\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS Config\n',
#  '    D. AWS Trusted Advisor\n',
#  '    **Correct Answers: A. AWS CloudWatch, C. AWS Config, D. AWS Trusted Advisor**\n',
#  '\n',
#  '43. (Select 2 answers) Which two of the following AWS services are used to deploy and manage your applications on AWS?\n',
#  '    A. AWS Elastic Beanstalk\n',
#  '    B. AWS CodeDeploy\n',
#  '    C. AWS CodePipeline\n',
#  '    D. AWS CloudFormation\n',
#  '    **Correct Answers: A. AWS Elastic Beanstalk, B. AWS CodeDeploy**\n',
#  '\n',
#  '44. (Select 3 answers) Which three of the following AWS services are used to create and manage your own private cloud within AWS?\n',
#  '    A. AWS VPC\n',
#  '    B. AWS Direct Connect\n',
#  '    C. AWS Transit Gateway\n',
#  '    D. AWS Route 53\n',
#  '    **Correct Answers: A. AWS VPC, B. AWS Direct Connect, C. AWS Transit Gateway**\n',
#  '\n',
#  '45. (Select 2 answers) Which two of the following AWS services are used to secure your AWS resources using encryption at rest and in transit?\n',
#  '    A. AWS KMS\n',
#  '    B. AWS IAM\n',
#  '    C. AWS WAF\n',
#  '    D. AWS Shield\n',
#  '    **Correct Answers: A. AWS KMS, B. AWS IAM**\n',
#  '\n',
#  '46. (Select 3 answers) Which three of the following AWS services are used to manage and configure access to your AWS resources?\n',
#  '    A. AWS IAM\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS Config\n',
#  '    D. AWS Trusted Advisor\n',
#  '    **Correct Answers: A. AWS IAM, B. AWS CloudTrail, C. AWS Config**\n',
#  '\n',
#  '47. (Select 2 answers) Which two of the following AWS services are used to manage and configure network connectivity between your VPC and the internet?\n',
#  '    A. AWS Route 53\n',
#  '    B. AWS VPC\n',
#  '    C. AWS NAT Gateway\n',
#  '    D. AWS Direct Connect\n',
#  '    **Correct Answers: C. AWS NAT Gateway, D. AWS Direct Connect**\n',
#  '\n',
#  '48. (Select 3 answers) Which three of the following AWS services are used to manage and configure network connectivity between your VPC and on-premises data centers?\n',
#  '    A. AWS Direct Connect\n',
#  '    B. AWS VPN\n',
#  '    C. AWS Transit Gateway\n',
#  '    D. AWS Route 53\n',
#  '    **Correct Answers: A. AWS Direct Connect, B. AWS VPN, C. AWS Transit Gateway**\n',
#  '\n',
#  '49. (Select 2 answers) Which two of the following AWS services are used to manage and configure network security within your VPC?\n',
#  '    A. AWS Security Groups\n',
#  '    B. AWS IAM\n',
#  '    C. AWS CloudTrail\n',
#  '    D. AWS Network Load Balancer\n',
#  '    **Correct Answers: A. AWS Security Groups, D. AWS Network Load Balancer**\n',
#  '\n',
#  '50. (Select 2 answers) Which two of the following AWS services are used to deploy and manage your applications using a declarative language, making infrastructure as code possible?\n',
#  '    A. AWS CloudFormation\n',
#  '    B. AWS CodePipeline\n',
#  '    C. AWS CodeDeploy\n',
#  '    D. AWS Elastic Beanstalk\n',
#  '    **Correct Answers: A. AWS CloudFormation, D. AWS Elastic Beanstalk**']

# %%
dict_data = {'question': [],
             'answer': []}

# Switch determine if the last line is in question section or no
q_prev = False

for line in data:
    line = line.replace('**', '')
    # Check if line is not blank or title, heading ('##')
    if (line != '\n') and ('##' not in line):
        # Call the first word of the line is `head`
        head = line.split()[0]

        # Append new question if all of these meet:
        # - `q_prev` is False
        # - First character of `head` is numeric
        # - Last character of `head` is '.'
        if (not q_prev) and head[0].isnumeric() and head[-1] == ".":
            dict_data['question'].append(line)
            q_prev = True

        # Append new answer if all of these meet:
        # - `q_prev` is True
        # - `head` is 'A.'
        elif q_prev and head == 'A.':
            dict_data['answer'].append(line)
            q_prev = False

        # Add line to unfinished question
        elif q_prev:
            dict_data['question'][-1] += line
    
        # Add line to unfinished answer
        else:
            dict_data['answer'][-1] += line

# Convert `dict_data` to a DataFrame and make a copy of it
df0 = pd.DataFrame(dict_data)

print('Number of questions: ', len(df0))
print('Columns: ', df0.columns.values)
# Out:
# Number of questions:  50
# Columns:  ['question' 'answer']

# %%
# View some indices (15 to 38)
df0.iloc[15:60]
# Out:
#                                              question  \
# 15  16. AWS CodeDeploy automates application deplo...
# 16  17. AWS Organizations allows you to centrally ...
# 17  18. AWS CloudTrail records API calls made to A...
# 18  19. AWS WAF provides a web application firewal...
# 19  20. AWS Shield is a managed DDoS protection se...
# 20  21. Which of the following AWS services is use...
# 21  22. Which of the following AWS services is a f...
# 22  23. Which of the following AWS services is use...
# 23  24. Which of the following AWS services is use...
# 24  25. Which of the following AWS services is use...
# 25  26. Which of the following AWS services is use...
# 26  27. Which of the following AWS services is a f...
# 27  28. Which of the following AWS services is use...
# 28  29. Which of the following AWS services is use...
# 29  30. Which of the following AWS services is use...
# 30  31. Which of the following AWS services is a m...
# 31  32. Which of the following AWS services is use...
# 32  33. Which of the following AWS services is use...
# 33  34. Which of the following AWS services is use...
# 34  35. Which of the following AWS services is use...
# 35  36. Which of the following AWS services is a f...
# 36  37. Which of the following AWS services is use...
# 37  38. Which of the following AWS services is a f...
# 38  39. Which of the following AWS services is use...
# 39  40. Which of the following AWS services is use...
# 40  41. (Select 2 answers) Which two of the follow...
# 41  42. (Select 3 answers) Which three of the foll...
# 42  43. (Select 2 answers) Which two of the follow...
# 43  44. (Select 3 answers) Which three of the foll...
# 44  45. (Select 2 answers) Which two of the follow...
# 45  46. (Select 3 answers) Which three of the foll...
# 46  47. (Select 2 answers) Which two of the follow...
# 47  48. (Select 3 answers) Which three of the foll...
# 48  49. (Select 2 answers) Which two of the follow...
# 49  50. (Select 2 answers) Which two of the follow...
#
#                                                answer
# 15      A. True\n    B. False\n    Correct Answer:...
# 16      A. True\n    B. False\n    Correct Answer:...
# 17      A. True\n    B. False\n    Correct Answer:...
# 18      A. True\n    B. False\n    Correct Answer:...
# 19      A. True\n    B. False\n    Correct Answer:...
# 20      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 21      A. Amazon Redshift\n    B. Amazon DynamoDB...
# 22      A. AWS Auto Scaling\n    B. AWS Elastic Be...
# 23      A. AWS CloudWatch\n    B. AWS CloudTrail\n...
# 24      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 25      A. AWS Elastic Beanstalk\n    B. AWS CodeD...
# 26      A. AWS Management Console\n    B. AWS CLI\...
# 27      A. AWS VPN\n    B. AWS Direct Connect\n   ...
# 28      A. AWS KMS\n    B. AWS IAM\n    C. AWS WAF...
# 29      A. AWS CloudFormation\n    B. AWS CodePipe...
# 30      A. AWS CLI\n    B. AWS SDK\n    C. AWS Lam...
# 31      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 32      A. AWS Security Groups\n    B. AWS IAM\n  ...
# 33      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 34      A. AWS IAM\n    B. AWS CloudTrail\n    C. ...
# 35      A. Amazon ElastiCache\n    B. Amazon Dynam...
# 36      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 37      A. Amazon S3\n    B. Amazon DynamoDB\n    ...
# 38      A. AWS Direct Connect\n    B. AWS VPN\n   ...
# 39      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 40      A. AWS Security Groups\n    B. AWS IAM\n  ...
# 41      A. AWS CloudWatch\n    B. AWS CloudTrail\n...
# 42      A. AWS Elastic Beanstalk\n    B. AWS CodeD...
# 43      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 44      A. AWS KMS\n    B. AWS IAM\n    C. AWS WAF...
# 45      A. AWS IAM\n    B. AWS CloudTrail\n    C. ...
# 46      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 47      A. AWS Direct Connect\n    B. AWS VPN\n   ...
# 48      A. AWS Security Groups\n    B. AWS IAM\n  ...
# 49      A. AWS CloudFormation\n    B. AWS CodePipe...

# %%
# Make a copy of df0
df1 = df0.copy()

# %%
# Strip the numbers
df1['question'] = df1['question'].str.replace(r'^\d{0,4}\.[ ]', '', regex=True)

# %%
df1
# Out:
#                                              question  \
# 0   You can use AWS Lambda to create a serverless ...
# 1   AWS CloudFormation allows you to define and ma...
# 2   AWS S3 offers a built-in feature called "serve...
# 3   AWS IAM roles can be used to grant temporary a...
# 4   AWS Lambda functions can directly access data ...
# 5   AWS EBS volumes can be attached to multiple EC...
# 6   AWS Auto Scaling can automatically adjust the ...
# 7   AWS DynamoDB is a fully managed NoSQL database...
# 8   AWS Kinesis is a fully managed streaming servi...
# 9   AWS Elastic Beanstalk supports deploying and m...
# 10  AWS CloudFront is a global content delivery ne...
# 11  AWS Elastic Load Balancing automatically distr...
# 12  AWS Redshift is a fully managed, petabyte-scal...
# 13  AWS CloudWatch provides monitoring and logging...
# 14  AWS CodePipeline is a fully managed continuous...
# 15  AWS CodeDeploy automates application deploymen...
# 16  AWS Organizations allows you to centrally mana...
# 17  AWS CloudTrail records API calls made to AWS s...
# 18  AWS WAF provides a web application firewall (W...
# 19  AWS Shield is a managed DDoS protection servic...
# 20  Which of the following AWS services is used to...
# 21  Which of the following AWS services is a fully...
# 22  Which of the following AWS services is used to...
# 23  Which of the following AWS services is used to...
# 24  Which of the following AWS services is used to...
# 25  Which of the following AWS services is used to...
# 26  Which of the following AWS services is a fully...
# 27  Which of the following AWS services is used to...
# 28  Which of the following AWS services is used to...
# 29  Which of the following AWS services is used to...
# 30  Which of the following AWS services is a manag...
# 31  Which of the following AWS services is used to...
# 32  Which of the following AWS services is used to...
# 33  Which of the following AWS services is used to...
# 34  Which of the following AWS services is used to...
# 35  Which of the following AWS services is a fully...
# 36  Which of the following AWS services is used to...
# 37  Which of the following AWS services is a fully...
# 38  Which of the following AWS services is used to...
# 39  Which of the following AWS services is used to...
# 40  (Select 2 answers) Which two of the following ...
# 41  (Select 3 answers) Which three of the followin...
# 42  (Select 2 answers) Which two of the following ...
# 43  (Select 3 answers) Which three of the followin...
# 44  (Select 2 answers) Which two of the following ...
# 45  (Select 3 answers) Which three of the followin...
# 46  (Select 2 answers) Which two of the following ...
# 47  (Select 3 answers) Which three of the followin...
# 48  (Select 2 answers) Which two of the following ...
# 49  (Select 2 answers) Which two of the following ...
#
#                                                answer
# 0       A. True\n    B. False\n    Correct Answer:...
# 1       A. True\n    B. False\n    Correct Answer:...
# 2       A. True\n    B. False\n    Correct Answer:...
# 3       A. True\n    B. False\n    Correct Answer:...
# 4       A. True\n    B. False\n    Correct Answer:...
# 5       A. True\n    B. False\n    Correct Answer:...
# 6       A. True\n    B. False\n    Correct Answer:...
# 7       A. True\n    B. False\n    Correct Answer:...
# 8       A. True\n    B. False\n    Correct Answer:...
# 9       A. True\n    B. False\n    Correct Answer:...
# 10      A. True\n    B. False\n    Correct Answer:...
# 11      A. True\n    B. False\n    Correct Answer:...
# 12      A. True\n    B. False\n    Correct Answer:...
# 13      A. True\n    B. False\n    Correct Answer:...
# 14      A. True\n    B. False\n    Correct Answer:...
# 15      A. True\n    B. False\n    Correct Answer:...
# 16      A. True\n    B. False\n    Correct Answer:...
# 17      A. True\n    B. False\n    Correct Answer:...
# 18      A. True\n    B. False\n    Correct Answer:...
# 19      A. True\n    B. False\n    Correct Answer:...
# 20      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 21      A. Amazon Redshift\n    B. Amazon DynamoDB...
# 22      A. AWS Auto Scaling\n    B. AWS Elastic Be...
# 23      A. AWS CloudWatch\n    B. AWS CloudTrail\n...
# 24      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 25      A. AWS Elastic Beanstalk\n    B. AWS CodeD...
# 26      A. AWS Management Console\n    B. AWS CLI\...
# 27      A. AWS VPN\n    B. AWS Direct Connect\n   ...
# 28      A. AWS KMS\n    B. AWS IAM\n    C. AWS WAF...
# 29      A. AWS CloudFormation\n    B. AWS CodePipe...
# 30      A. AWS CLI\n    B. AWS SDK\n    C. AWS Lam...
# 31      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 32      A. AWS Security Groups\n    B. AWS IAM\n  ...
# 33      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 34      A. AWS IAM\n    B. AWS CloudTrail\n    C. ...
# 35      A. Amazon ElastiCache\n    B. Amazon Dynam...
# 36      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 37      A. Amazon S3\n    B. Amazon DynamoDB\n    ...
# 38      A. AWS Direct Connect\n    B. AWS VPN\n   ...
# 39      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 40      A. AWS Security Groups\n    B. AWS IAM\n  ...
# 41      A. AWS CloudWatch\n    B. AWS CloudTrail\n...
# 42      A. AWS Elastic Beanstalk\n    B. AWS CodeD...
# 43      A. AWS VPC\n    B. AWS Direct Connect\n   ...
# 44      A. AWS KMS\n    B. AWS IAM\n    C. AWS WAF...
# 45      A. AWS IAM\n    B. AWS CloudTrail\n    C. ...
# 46      A. AWS Route 53\n    B. AWS VPC\n    C. AW...
# 47      A. AWS Direct Connect\n    B. AWS VPN\n   ...
# 48      A. AWS Security Groups\n    B. AWS IAM\n  ...
# 49      A. AWS CloudFormation\n    B. AWS CodePipe...

# %%
# Make a copy of `df1`
df_2 = df1.copy()

# %%
def convert_index(capital):
    """Return zero base index of capital"""
    return ord(capital) - 65

def choices_split(answer):
    """
    Split the `answer` data into multiple choices
    """
    # print(answer)
    # Use 'Correct Answer: ' to split text, index 0 is all choices, index 1 is all answers
    split_all = re.split(r'Correct Answer[s]*: ', answer)
    # print("After strip 'Correct Answer: ': ", split_all)
    choices = split_all[0]
    # print('Choices text:', choices)
    correct_stack = split_all[1]
    # print('Correct stack:', correct_stack)
    
    # Split using ','
    correct_stack = correct_stack.split(',')
    # Pick only first capital indicating the choices
    correct_note = [item.strip()[0] for item in correct_stack]
    # print('Correct note:', correct_note)
    correct_index = [convert_index(item) for item in correct_note]
    # print('Correct index', correct_index)
    
    # Split using 'X. ', index 0 will be ''
    choices = re.split(r'[A-Z]\.[ ]', choices)[1:]
    choices = [choice.rstrip() for choice in choices]
    # print('All choices in list: ', choices)
    
    incorrect = [choice for index, choice in enumerate(choices) if index not in correct_index]
    # print('Incorrect in list: ', incorrect)
    correct = [choice for index, choice in enumerate(choices) if index in correct_index]
    # print('Correct in list: ', correct)
    
    return {'incorrect': incorrect,
            'correct': correct}

# %%
df_test = df_2.iloc[20:22]['answer'].apply(choices_split)

# %%
display(df_test.str['incorrect'])
df_test.str['correct']
# Out:
# 20         [AWS Route 53, AWS VPC, AWS Direct Connect]
# 21    [Amazon DynamoDB, Amazon S3, Amazon ElastiCache]
# Name: answer, dtype: object
# 20    [AWS NAT Gateway]
# 21    [Amazon Redshift]
# Name: answer, dtype: object

# %%
df_2['incorrect'] = df_2['answer'].apply(choices_split).str['incorrect']
df_2['correct'] = df_2['answer'].apply(choices_split).str['correct']

# %%
display(df_2.loc[40, 'incorrect'])
display(df_2.loc[40, 'correct'])
# Out:
# ['AWS IAM', 'AWS CloudTrail']
# ['AWS Security Groups', 'AWS Network Load Balancer']

# %%
# New order of columns
new_order = ['question', 'incorrect', 'correct']

# Make a copy of `df_a` with new order of columns
df_clean = df_2[new_order].copy()

display(df_clean['incorrect'][45])

display(df_clean['correct'][45])

df_clean.iloc[45]
# Out:
# ['AWS Trusted Advisor']
# ['AWS IAM', 'AWS CloudTrail', 'AWS Config']
# question     (Select 3 answers) Which three of the followin...
# incorrect                                [AWS Trusted Advisor]
# correct                  [AWS IAM, AWS CloudTrail, AWS Config]
# Name: 45, dtype: object

# %%
df_clean
# Out:
#                                              question  \
# 0   You can use AWS Lambda to create a serverless ...
# 1   AWS CloudFormation allows you to define and ma...
# 2   AWS S3 offers a built-in feature called "serve...
# 3   AWS IAM roles can be used to grant temporary a...
# 4   AWS Lambda functions can directly access data ...
# 5   AWS EBS volumes can be attached to multiple EC...
# 6   AWS Auto Scaling can automatically adjust the ...
# 7   AWS DynamoDB is a fully managed NoSQL database...
# 8   AWS Kinesis is a fully managed streaming servi...
# 9   AWS Elastic Beanstalk supports deploying and m...
# 10  AWS CloudFront is a global content delivery ne...
# 11  AWS Elastic Load Balancing automatically distr...
# 12  AWS Redshift is a fully managed, petabyte-scal...
# 13  AWS CloudWatch provides monitoring and logging...
# 14  AWS CodePipeline is a fully managed continuous...
# 15  AWS CodeDeploy automates application deploymen...
# 16  AWS Organizations allows you to centrally mana...
# 17  AWS CloudTrail records API calls made to AWS s...
# 18  AWS WAF provides a web application firewall (W...
# 19  AWS Shield is a managed DDoS protection servic...
# 20  Which of the following AWS services is used to...
# 21  Which of the following AWS services is a fully...
# 22  Which of the following AWS services is used to...
# 23  Which of the following AWS services is used to...
# 24  Which of the following AWS services is used to...
# 25  Which of the following AWS services is used to...
# 26  Which of the following AWS services is a fully...
# 27  Which of the following AWS services is used to...
# 28  Which of the following AWS services is used to...
# 29  Which of the following AWS services is used to...
# 30  Which of the following AWS services is a manag...
# 31  Which of the following AWS services is used to...
# 32  Which of the following AWS services is used to...
# 33  Which of the following AWS services is used to...
# 34  Which of the following AWS services is used to...
# 35  Which of the following AWS services is a fully...
# 36  Which of the following AWS services is used to...
# 37  Which of the following AWS services is a fully...
# 38  Which of the following AWS services is used to...
# 39  Which of the following AWS services is used to...
# 40  (Select 2 answers) Which two of the following ...
# 41  (Select 3 answers) Which three of the followin...
# 42  (Select 2 answers) Which two of the following ...
# 43  (Select 3 answers) Which three of the followin...
# 44  (Select 2 answers) Which two of the following ...
# 45  (Select 3 answers) Which three of the followin...
# 46  (Select 2 answers) Which two of the following ...
# 47  (Select 3 answers) Which three of the followin...
# 48  (Select 2 answers) Which two of the following ...
# 49  (Select 2 answers) Which two of the following ...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                             [False]
# 2                                             [False]
# 3                                             [False]
# 4                                              [True]
# 5                                              [True]
# 6                                             [False]
# 7                                             [False]
# 8                                             [False]
# 9                                             [False]
# 10                                            [False]
# 11                                            [False]
# 12                                            [False]
# 13                                            [False]
# 14                                            [False]
# 15                                            [False]
# 16                                            [False]
# 17                                            [False]
# 18                                            [False]
# 19                                            [False]
# 20        [AWS Route 53, AWS VPC, AWS Direct Connect]
# 21   [Amazon DynamoDB, Amazon S3, Amazon ElastiCache]
# 22  [AWS Elastic Beanstalk, AWS CloudFormation, AW...
# 23  [AWS CloudTrail, AWS Config, AWS Trusted Advisor]
# 24  [AWS Direct Connect, AWS CloudFront, AWS Elast...
# 25  [AWS CodeDeploy, AWS CodePipeline, AWS CloudFo...
# 26                 [AWS CLI, AWS SDK, AWS CloudTrail]
# 27  [AWS Direct Connect, AWS Transit Gateway, AWS ...
# 28                     [AWS IAM, AWS WAF, AWS Shield]
# 29  [AWS CodePipeline, AWS CodeDeploy, AWS Elastic...
# 30          [AWS SDK, AWS Lambda, AWS CloudFormation]
# 31                  [AWS VPC, AWS CloudFront, AWS S3]
# 32                 [AWS IAM, AWS CloudTrail, AWS WAF]
# 33  [AWS Direct Connect, AWS Transit Gateway, AWS ...
# 34  [AWS CloudTrail, AWS Config, AWS Trusted Advisor]
# 35      [Amazon DynamoDB, Amazon S3, Amazon Redshift]
# 36  [AWS Direct Connect, AWS CloudFront, AWS Elast...
# 37  [Amazon DynamoDB, Amazon Redshift, Amazon Elas...
# 38       [AWS VPN, AWS Transit Gateway, AWS Route 53]
# 39                  [AWS VPC, AWS CloudFront, AWS S3]
# 40                          [AWS IAM, AWS CloudTrail]
# 41                                   [AWS CloudTrail]
# 42             [AWS CodePipeline, AWS CloudFormation]
# 43                                     [AWS Route 53]
# 44                              [AWS WAF, AWS Shield]
# 45                              [AWS Trusted Advisor]
# 46                            [AWS Route 53, AWS VPC]
# 47                                     [AWS Route 53]
# 48                          [AWS IAM, AWS CloudTrail]
# 49                 [AWS CodePipeline, AWS CodeDeploy]
#
#                                               correct
# 0                                             [False]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                             [False]
# 5                                             [False]
# 6                                              [True]
# 7                                              [True]
# 8                                              [True]
# 9                                              [True]
# 10                                             [True]
# 11                                             [True]
# 12                                             [True]
# 13                                             [True]
# 14                                             [True]
# 15                                             [True]
# 16                                             [True]
# 17                                             [True]
# 18                                             [True]
# 19                                             [True]
# 20                                  [AWS NAT Gateway]
# 21                                  [Amazon Redshift]
# 22                                 [AWS Auto Scaling]
# 23                                   [AWS CloudWatch]
# 24                                          [AWS VPC]
# 25                            [AWS Elastic Beanstalk]
# 26                           [AWS Management Console]
# 27                                          [AWS VPN]
# 28                                          [AWS KMS]
# 29                               [AWS CloudFormation]
# 30                                          [AWS CLI]
# 31                                     [AWS Route 53]
# 32                              [AWS Security Groups]
# 33                                          [AWS VPC]
# 34                                          [AWS IAM]
# 35                               [Amazon ElastiCache]
# 36                                          [AWS VPC]
# 37                                        [Amazon S3]
# 38                               [AWS Direct Connect]
# 39                                     [AWS Route 53]
# 40   [AWS Security Groups, AWS Network Load Balancer]
# 41  [AWS CloudWatch, AWS Config, AWS Trusted Advisor]
# 42            [AWS Elastic Beanstalk, AWS CodeDeploy]
# 43  [AWS VPC, AWS Direct Connect, AWS Transit Gate...
# 44                                 [AWS KMS, AWS IAM]
# 45              [AWS IAM, AWS CloudTrail, AWS Config]
# 46              [AWS NAT Gateway, AWS Direct Connect]
# 47  [AWS Direct Connect, AWS VPN, AWS Transit Gate...
# 48   [AWS Security Groups, AWS Network Load Balancer]
# 49        [AWS CloudFormation, AWS Elastic Beanstalk]

# %%
export_file = READ_BLOB[:-4] + '.json'
# Export `df_clean` to a JSON file
df_clean.to_json(export_file)

# %%
df_json = pd.read_json(export_file)

# %%
df_json
# Out:
#                                              question  \
# 0   You can use AWS Lambda to create a serverless ...
# 1   AWS CloudFormation allows you to define and ma...
# 2   AWS S3 offers a built-in feature called "serve...
# 3   AWS IAM roles can be used to grant temporary a...
# 4   AWS Lambda functions can directly access data ...
# 5   AWS EBS volumes can be attached to multiple EC...
# 6   AWS Auto Scaling can automatically adjust the ...
# 7   AWS DynamoDB is a fully managed NoSQL database...
# 8   AWS Kinesis is a fully managed streaming servi...
# 9   AWS Elastic Beanstalk supports deploying and m...
# 10  AWS CloudFront is a global content delivery ne...
# 11  AWS Elastic Load Balancing automatically distr...
# 12  AWS Redshift is a fully managed, petabyte-scal...
# 13  AWS CloudWatch provides monitoring and logging...
# 14  AWS CodePipeline is a fully managed continuous...
# 15  AWS CodeDeploy automates application deploymen...
# 16  AWS Organizations allows you to centrally mana...
# 17  AWS CloudTrail records API calls made to AWS s...
# 18  AWS WAF provides a web application firewall (W...
# 19  AWS Shield is a managed DDoS protection servic...
# 20  Which of the following AWS services is used to...
# 21  Which of the following AWS services is a fully...
# 22  Which of the following AWS services is used to...
# 23  Which of the following AWS services is used to...
# 24  Which of the following AWS services is used to...
# 25  Which of the following AWS services is used to...
# 26  Which of the following AWS services is a fully...
# 27  Which of the following AWS services is used to...
# 28  Which of the following AWS services is used to...
# 29  Which of the following AWS services is used to...
# 30  Which of the following AWS services is a manag...
# 31  Which of the following AWS services is used to...
# 32  Which of the following AWS services is used to...
# 33  Which of the following AWS services is used to...
# 34  Which of the following AWS services is used to...
# 35  Which of the following AWS services is a fully...
# 36  Which of the following AWS services is used to...
# 37  Which of the following AWS services is a fully...
# 38  Which of the following AWS services is used to...
# 39  Which of the following AWS services is used to...
# 40  (Select 2 answers) Which two of the following ...
# 41  (Select 3 answers) Which three of the followin...
# 42  (Select 2 answers) Which two of the following ...
# 43  (Select 3 answers) Which three of the followin...
# 44  (Select 2 answers) Which two of the following ...
# 45  (Select 3 answers) Which three of the followin...
# 46  (Select 2 answers) Which two of the following ...
# 47  (Select 3 answers) Which three of the followin...
# 48  (Select 2 answers) Which two of the following ...
# 49  (Select 2 answers) Which two of the following ...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                             [False]
# 2                                             [False]
# 3                                             [False]
# 4                                              [True]
# 5                                              [True]
# 6                                             [False]
# 7                                             [False]
# 8                                             [False]
# 9                                             [False]
# 10                                            [False]
# 11                                            [False]
# 12                                            [False]
# 13                                            [False]
# 14                                            [False]
# 15                                            [False]
# 16                                            [False]
# 17                                            [False]
# 18                                            [False]
# 19                                            [False]
# 20        [AWS Route 53, AWS VPC, AWS Direct Connect]
# 21   [Amazon DynamoDB, Amazon S3, Amazon ElastiCache]
# 22  [AWS Elastic Beanstalk, AWS CloudFormation, AW...
# 23  [AWS CloudTrail, AWS Config, AWS Trusted Advisor]
# 24  [AWS Direct Connect, AWS CloudFront, AWS Elast...
# 25  [AWS CodeDeploy, AWS CodePipeline, AWS CloudFo...
# 26                 [AWS CLI, AWS SDK, AWS CloudTrail]
# 27  [AWS Direct Connect, AWS Transit Gateway, AWS ...
# 28                     [AWS IAM, AWS WAF, AWS Shield]
# 29  [AWS CodePipeline, AWS CodeDeploy, AWS Elastic...
# 30          [AWS SDK, AWS Lambda, AWS CloudFormation]
# 31                  [AWS VPC, AWS CloudFront, AWS S3]
# 32                 [AWS IAM, AWS CloudTrail, AWS WAF]
# 33  [AWS Direct Connect, AWS Transit Gateway, AWS ...
# 34  [AWS CloudTrail, AWS Config, AWS Trusted Advisor]
# 35      [Amazon DynamoDB, Amazon S3, Amazon Redshift]
# 36  [AWS Direct Connect, AWS CloudFront, AWS Elast...
# 37  [Amazon DynamoDB, Amazon Redshift, Amazon Elas...
# 38       [AWS VPN, AWS Transit Gateway, AWS Route 53]
# 39                  [AWS VPC, AWS CloudFront, AWS S3]
# 40                          [AWS IAM, AWS CloudTrail]
# 41                                   [AWS CloudTrail]
# 42             [AWS CodePipeline, AWS CloudFormation]
# 43                                     [AWS Route 53]
# 44                              [AWS WAF, AWS Shield]
# 45                              [AWS Trusted Advisor]
# 46                            [AWS Route 53, AWS VPC]
# 47                                     [AWS Route 53]
# 48                          [AWS IAM, AWS CloudTrail]
# 49                 [AWS CodePipeline, AWS CodeDeploy]
#
#                                               correct
# 0                                             [False]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                             [False]
# 5                                             [False]
# 6                                              [True]
# 7                                              [True]
# 8                                              [True]
# 9                                              [True]
# 10                                             [True]
# 11                                             [True]
# 12                                             [True]
# 13                                             [True]
# 14                                             [True]
# 15                                             [True]
# 16                                             [True]
# 17                                             [True]
# 18                                             [True]
# 19                                             [True]
# 20                                  [AWS NAT Gateway]
# 21                                  [Amazon Redshift]
# 22                                 [AWS Auto Scaling]
# 23                                   [AWS CloudWatch]
# 24                                          [AWS VPC]
# 25                            [AWS Elastic Beanstalk]
# 26                           [AWS Management Console]
# 27                                          [AWS VPN]
# 28                                          [AWS KMS]
# 29                               [AWS CloudFormation]
# 30                                          [AWS CLI]
# 31                                     [AWS Route 53]
# 32                              [AWS Security Groups]
# 33                                          [AWS VPC]
# 34                                          [AWS IAM]
# 35                               [Amazon ElastiCache]
# 36                                          [AWS VPC]
# 37                                        [Amazon S3]
# 38                               [AWS Direct Connect]
# 39                                     [AWS Route 53]
# 40   [AWS Security Groups, AWS Network Load Balancer]
# 41  [AWS CloudWatch, AWS Config, AWS Trusted Advisor]
# 42            [AWS Elastic Beanstalk, AWS CodeDeploy]
# 43  [AWS VPC, AWS Direct Connect, AWS Transit Gate...
# 44                                 [AWS KMS, AWS IAM]
# 45              [AWS IAM, AWS CloudTrail, AWS Config]
# 46              [AWS NAT Gateway, AWS Direct Connect]
# 47  [AWS Direct Connect, AWS VPN, AWS Transit Gate...
# 48   [AWS Security Groups, AWS Network Load Balancer]
# 49        [AWS CloudFormation, AWS Elastic Beanstalk]

# %%
import json

f = open(export_file)
data = json.load(f)
data['question']['15']
# Out:
# 'AWS CodeDeploy automates application deployments to EC2 instances, making it easier to deploy and update your applications.\n'

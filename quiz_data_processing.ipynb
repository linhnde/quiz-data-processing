# %%
# Import general packages
import pandas as pd
import re
import io
import json

# Set environment variable to authenticate GCP credentials
# !export GOOGLE_APPLICATION_CREDENTIALS='quiz-generate.json'

LOCATION = "us-central1"
PROJECT = 'exam-practice-404408'
BUCKET = 'exam-banks'
MODEL = "gemini-1.5-flash-001"

# %%
# Imports the Google Cloud client library
from google.cloud import storage

def gcs_read(bucket_name, blob_name, j_load=False):
    """
    Read a blob from GCS using file-like IO.
    Default use readlines() for text file.
    Change `j_load` to True if json.load() is used for reading clean JSON file.
    """
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("r") as file:
        if j_load:
            return json.load(file)
        return file.readlines()
    
def gcs_write(bucket_name, blob_name, content):
    """Write a blob from GCS using file-like IO"""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("w") as file:
        file.write(content)

# %%
# Import Vertex AI packages
import vertexai
from vertexai.generative_models import GenerativeModel
import vertexai.preview.generative_models as generative_models

def generate(p_text, g_config, s_settings):
    """Yield text with generator which receive prompt text, generation config and safety settings as arguments"""
    vertexai.init(project=PROJECT, location=LOCATION)
    model = GenerativeModel(
        MODEL,
    )
    responses = model.generate_content(
        [p_text],
        generation_config=g_config,
        safety_settings=s_settings,
        stream=True,
    )

    for response in responses:
        yield response.text

# %%
prompt = """Generate quiz with these requirements:
- Total questions: 50.
- Topic: AWS.
- Difficulty: Hard.
- Types: true/false, single correct answer, multiple correct answers.
- Indent questions with number.
- Indent choices and true/false with upper letter.
- If more than 2 correct answers questions, remind  \"(select [exact number] apply)\" before choice A.
- In each question, total correct answers is less than total choices.
- Choices consist multiple technically complicated steps.
- Show correct choices at the end of each question.
- No markdown, plain text.
- Group by type."""

generation_config = {
    "max_output_tokens": 8192,
    "temperature": 1,
    "top_p": 0.95,
}

safety_settings = {
    generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

# %%
# Assign generator to a variable
generator = generate(prompt, generation_config, safety_settings)

# %%
# Use string comprehension to gather text from generator
generate_text = ''.join(response for response in generator)

# %%
# Use print() for generate_text for better preview because generated_text is whole string, not list of lines
print(generate_text)
# Out:
# ## True/False
#
# 1. A single AWS account can only have one IAM user.
#     A. True
#     B. False
#     **Correct: B**
#
# 2. Amazon S3 buckets can be directly accessed from the internet without any configuration.
#     A. True
#     B. False
#     **Correct: B**
#
# 3. AWS Lambda functions can only be triggered by HTTP requests.
#     A. True
#     B. False
#     **Correct: B**
#
# 4. AWS CloudTrail can only record API calls made to AWS services.
#     A. True
#     B. False
#     **Correct: B**
#
# 5. AWS CloudFormation can only be used to create new resources, not update or delete existing ones.
#     A. True
#     B. False
#     **Correct: B**
#
# 6. Amazon DynamoDB supports both document and relational data models.
#     A. True
#     B. False
#     **Correct: B**
#
# 7. AWS Elastic Beanstalk automatically scales your application based on traffic patterns.
#     A. True
#     B. False
#     **Correct: A**
#
# 8. AWS Direct Connect provides a dedicated private connection to the AWS cloud.
#     A. True
#     B. False
#     **Correct: A**
#
# 9. AWS CloudWatch only monitors resources within your AWS account.
#     A. True
#     B. False
#     **Correct: B**
#
# 10. AWS Organizations allows you to manage multiple AWS accounts under a single umbrella.
#     A. True
#     B. False
#     **Correct: A**
#
# ## Single Correct Answer
#
# 11. Which AWS service is primarily used for managing and deploying containerized applications?
#     A. Amazon EC2
#     B. Amazon ECS
#     C. AWS Lambda
#     D. Amazon S3
#     **Correct: B**
#
# 12. What is the primary purpose of Amazon Route 53?
#     A. Providing object storage
#     B. Managing virtual private networks
#     C. Providing DNS services
#     D. Running containerized applications
#     **Correct: C**
#
# 13. Which AWS service is used for managing and monitoring your AWS resources?
#     A. AWS CloudFormation
#     B. AWS CloudTrail
#     C. AWS CloudWatch
#     D. Amazon S3
#     **Correct: C**
#
# 14. Which AWS service is used for deploying and managing serverless applications?
#     A. AWS Lambda
#     B. Amazon EC2
#     C. AWS Elastic Beanstalk
#     D. Amazon ECS
#     **Correct: A**
#
# 15. Which AWS service provides a managed database service for NoSQL workloads?
#     A. Amazon RDS
#     B. Amazon DynamoDB
#     C. Amazon Redshift
#     D. Amazon Aurora
#     **Correct: B**
#
# 16. Which AWS service is primarily used for securing access to your AWS resources?
#     A. AWS CloudTrail
#     B. AWS IAM
#     C. AWS CloudFormation
#     D. Amazon S3
#     **Correct: B**
#
# 17. Which AWS service allows you to create and manage virtual private networks?
#     A. AWS VPC
#     B. Amazon Route 53
#     C. AWS CloudWatch
#     D. Amazon S3
#     **Correct: A**
#
# 18. Which AWS service is primarily used for automating deployments and managing infrastructure?
#     A. AWS CloudFormation
#     B. AWS CloudTrail
#     C. AWS CloudWatch
#     D. Amazon EC2
#     **Correct: A**
#
# 19. Which AWS service provides a managed service for running and scaling web applications?
#     A. AWS Lambda
#     B. Amazon EC2
#     C. AWS Elastic Beanstalk
#     D. Amazon S3
#     **Correct: C**
#
# 20. Which AWS service is primarily used for collecting and analyzing log data from your applications?
#     A. Amazon S3
#     B. AWS CloudTrail
#     C. AWS CloudWatch
#     D. Amazon CloudFront
#     **Correct: C**
#
# ## Multiple Correct Answers
#
# 21. Which of the following are valid methods for deploying an AWS Lambda function? (Select 2 apply)
#     A. Using the AWS Management Console
#     B. Using the AWS CLI
#     C. Using the AWS SDK
#     D. Using Terraform
#     **Correct: A, C**
#
# 22. Which of the following are benefits of using AWS Lambda? (Select 3 apply)
#     A. Serverless architecture
#     B. Pay-per-use pricing
#     C. Automatic scaling
#     D. High availability
#     **Correct: A, B, C**
#
# 23. Which of the following are components of an AWS VPC? (Select 3 apply)
#     A. Subnets
#     B. Route tables
#     C. Security groups
#     D. Load balancers
#     **Correct: A, B, C**
#
# 24. Which of the following are valid ways to configure access to an Amazon S3 bucket? (Select 3 apply)
#     A. Using IAM policies
#     B. Using bucket policies
#     C. Using access control lists (ACLs)
#     D. Using CloudFront distributions
#     **Correct: A, B, C**
#
# 25. Which of the following are ways to monitor AWS resources using AWS CloudWatch? (Select 3 apply)
#     A. Creating custom metrics
#     B. Using predefined metrics
#     C. Setting up alarms
#     D. Analyzing log data
#     **Correct: A, B, C**
#
# 26. Which of the following are valid methods for deploying an AWS CloudFormation stack? (Select 2 apply)
#     A. Using the AWS Management Console
#     B. Using the AWS CLI
#     C. Using the AWS SDK
#     D. Using Terraform
#     **Correct: A, C**
#
# 27. Which of the following are benefits of using AWS Elastic Beanstalk? (Select 3 apply)
#     A. Simplified deployment process
#     B. Automatic scaling
#     C. Built-in monitoring and logging
#     D. High availability
#     **Correct: A, B, D**
#
# 28. Which of the following are ways to access resources in a private subnet within an AWS VPC? (Select 2 apply)
#     A. Using a NAT gateway
#     B. Using a VPN connection
#     C. Using a direct connection
#     D. Using a public subnet
#     **Correct: A, B**
#
# 29. Which of the following are valid ways to manage AWS resources across multiple accounts? (Select 2 apply)
#     A. Using AWS Organizations
#     B. Using AWS IAM
#     C. Using AWS CloudFormation
#     D. Using AWS CloudTrail
#     **Correct: A, B**
#
# 30. Which of the following are ways to secure an AWS Lambda function? (Select 3 apply)
#     A. Using IAM roles
#     B. Using VPC endpoints
#     C. Using Lambda layers
#     D. Using Lambda triggers
#     **Correct: A, B, C**
#
# ## True/False
#
# 31. AWS Lambda functions can be triggered by events from other AWS services, such as S3 bucket events.
#     A. True
#     B. False
#     **Correct: A**
#
# 32. AWS CloudTrail can only record API calls made to AWS services, not user activity within AWS services.
#     A. True
#     B. False
#     **Correct: B**
#
# 33. AWS CloudFormation can be used to create, update, and delete AWS resources, including those in other accounts.
#     A. True
#     B. False
#     **Correct: B**
#
# 34. Amazon DynamoDB supports both document and key-value data models.
#     A. True
#     B. False
#     **Correct: A**
#
# 35. AWS Elastic Beanstalk can automatically scale your application based on traffic patterns and resource usage.
#     A. True
#     B. False
#     **Correct: A**
#
# 36. AWS Direct Connect provides a dedicated private connection to the AWS cloud, bypassing the public internet.
#     A. True
#     B. False
#     **Correct: A**
#
# 37. AWS CloudWatch can monitor resources in other AWS accounts by using cross-account permissions.
#     A. True
#     B. False
#     **Correct: A**
#
# 38. AWS Organizations allows you to manage multiple AWS accounts under a single umbrella, enforcing policies and controlling access.
#     A. True
#     B. False
#     **Correct: A**
#
# 39. Amazon S3 buckets can be configured with different access control policies for different users and groups.
#     A. True
#     B. False
#     **Correct: A**
#
# 40. AWS IAM users can be assigned specific permissions to access AWS resources, preventing unauthorized access.
#     A. True
#     B. False
#     **Correct: A**
#
# ## Single Correct Answer
#
# 41. Which AWS service is primarily used for managing and deploying serverless applications, including those written in Python, Node.js, and Java?
#     A. AWS Lambda
#     B. Amazon EC2
#     C. AWS Elastic Beanstalk
#     D. Amazon ECS
#     **Correct: A**
#
# 42. What is the primary purpose of AWS Kinesis?
#     A. Providing object storage
#     B. Managing virtual private networks
#     C. Providing real-time data processing
#     D. Running containerized applications
#     **Correct: C**
#
# 43. Which AWS service is used for managing and monitoring your AWS resources, including setting up alarms and creating dashboards?
#     A. AWS CloudFormation
#     B. AWS CloudTrail
#     C. AWS CloudWatch
#     D. Amazon S3
#     **Correct: C**
#
# 44. Which AWS service is used for deploying and managing serverless applications, including those written in Go, PHP, and Ruby?
#     A. AWS Lambda
#     B. Amazon EC2
#     C. AWS Elastic Beanstalk
#     D. Amazon ECS
#     **Correct: A**
#
# 45. Which AWS service provides a managed database service for NoSQL workloads, with high availability and scalability?
#     A. Amazon RDS
#     B. Amazon DynamoDB
#     C. Amazon Redshift
#     D. Amazon Aurora
#     **Correct: B**
#
# 46. Which AWS service is primarily used for securing access to your AWS resources, including creating and managing user accounts and permissions?
#     A. AWS CloudTrail
#     B. AWS IAM
#     C. AWS CloudFormation
#     D. Amazon S3
#     **Correct: B**
#
# 47. Which AWS service allows you to create and manage virtual private networks, including subnets, security groups, and route tables?
#     A. AWS VPC
#     B. Amazon Route 53
#     C. AWS CloudWatch
#     D. Amazon S3
#     **Correct: A**
#
# 48. Which AWS service is primarily used for automating deployments and managing infrastructure, using infrastructure as code principles?
#     A. AWS CloudFormation
#     B. AWS CloudTrail
#     C. AWS CloudWatch
#     D. Amazon EC2
#     **Correct: A**
#
# 49. Which AWS service provides a managed service for running and scaling web applications, including support for multiple languages and frameworks?
#     A. AWS Lambda
#     B. Amazon EC2
#     C. AWS Elastic Beanstalk
#     D. Amazon S3
#     **Correct: C**
#
# 50. Which AWS service is primarily used for collecting and analyzing log data from your applications, including metrics, events, and traces?
#     A. Amazon S3
#     B. AWS CloudTrail
#     C. AWS CloudWatch
#     D. Amazon CloudFront
#     **Correct: C**

# %%
# Read generated text as lines
buf = io.StringIO(prompt)
lines = buf.readlines()

# Extract topic
topic_line = [line for line in lines if '- Topic: ' in line][0]
topic = topic_line[9:].rstrip('\n.')
topic = re.sub(' ', '_', topic.lower())
print('Topic:', topic)

# Extract difficulty
difficulty_line = [line for line in lines if '- Difficulty: ' in line][0]
difficulty = difficulty_line[14:].rstrip('\n.').lower()
print('Difficulty:', difficulty)

# Extract size
size_line = [line for line in lines if '- Total questions: ' in line][0]
size = size_line[19:].rstrip('\n.')
print('Size:', size)

# Combine topic, difficulty and size into .txt file name
file_name = f'{topic}_{difficulty}_{size}.txt'
print('File name:', file_name)
# Out:
# Topic: aws
# Difficulty: hard
# Size: 50
# File name: aws_hard_50.txt

# %%
# Assign file_name to a constant using for writing to GCS
WRITE_BLOB = file_name

gcs_write(BUCKET, WRITE_BLOB, generate_text)

# %%
# Assign file_name to a constant using for reading from GCS
READ_BLOB = file_name

# Read data as lines
data = gcs_read(BUCKET, READ_BLOB)

# Use display() because data is already list of lines structure
display(data)
# Out:
# ['## True/False\n',
#  '\n',
#  '1. A single AWS account can only have one IAM user.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: B**\n',
#  '\n',
#  '2. Amazon S3 buckets can be directly accessed from the internet without any configuration.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: B**\n',
#  '\n',
#  '3. AWS Lambda functions can only be triggered by HTTP requests.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: B**\n',
#  '\n',
#  '4. AWS CloudTrail can only record API calls made to AWS services.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: B**\n',
#  '\n',
#  '5. AWS CloudFormation can only be used to create new resources, not update or delete existing ones.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: B**\n',
#  '\n',
#  '6. Amazon DynamoDB supports both document and relational data models.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: B**\n',
#  '\n',
#  '7. AWS Elastic Beanstalk automatically scales your application based on traffic patterns.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '8. AWS Direct Connect provides a dedicated private connection to the AWS cloud.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '9. AWS CloudWatch only monitors resources within your AWS account.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: B**\n',
#  '\n',
#  '10. AWS Organizations allows you to manage multiple AWS accounts under a single umbrella.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '## Single Correct Answer\n',
#  '\n',
#  '11. Which AWS service is primarily used for managing and deploying containerized applications?\n',
#  '    A. Amazon EC2\n',
#  '    B. Amazon ECS\n',
#  '    C. AWS Lambda\n',
#  '    D. Amazon S3\n',
#  '    **Correct: B**\n',
#  '\n',
#  '12. What is the primary purpose of Amazon Route 53?\n',
#  '    A. Providing object storage\n',
#  '    B. Managing virtual private networks\n',
#  '    C. Providing DNS services\n',
#  '    D. Running containerized applications\n',
#  '    **Correct: C**\n',
#  '\n',
#  '13. Which AWS service is used for managing and monitoring your AWS resources?\n',
#  '    A. AWS CloudFormation\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS CloudWatch\n',
#  '    D. Amazon S3\n',
#  '    **Correct: C**\n',
#  '\n',
#  '14. Which AWS service is used for deploying and managing serverless applications?\n',
#  '    A. AWS Lambda\n',
#  '    B. Amazon EC2\n',
#  '    C. AWS Elastic Beanstalk\n',
#  '    D. Amazon ECS\n',
#  '    **Correct: A**\n',
#  '\n',
#  '15. Which AWS service provides a managed database service for NoSQL workloads?\n',
#  '    A. Amazon RDS\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon Aurora\n',
#  '    **Correct: B**\n',
#  '\n',
#  '16. Which AWS service is primarily used for securing access to your AWS resources?\n',
#  '    A. AWS CloudTrail\n',
#  '    B. AWS IAM\n',
#  '    C. AWS CloudFormation\n',
#  '    D. Amazon S3\n',
#  '    **Correct: B**\n',
#  '\n',
#  '17. Which AWS service allows you to create and manage virtual private networks?\n',
#  '    A. AWS VPC\n',
#  '    B. Amazon Route 53\n',
#  '    C. AWS CloudWatch\n',
#  '    D. Amazon S3\n',
#  '    **Correct: A**\n',
#  '\n',
#  '18. Which AWS service is primarily used for automating deployments and managing infrastructure?\n',
#  '    A. AWS CloudFormation\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS CloudWatch\n',
#  '    D. Amazon EC2\n',
#  '    **Correct: A**\n',
#  '\n',
#  '19. Which AWS service provides a managed service for running and scaling web applications?\n',
#  '    A. AWS Lambda\n',
#  '    B. Amazon EC2\n',
#  '    C. AWS Elastic Beanstalk\n',
#  '    D. Amazon S3\n',
#  '    **Correct: C**\n',
#  '\n',
#  '20. Which AWS service is primarily used for collecting and analyzing log data from your applications?\n',
#  '    A. Amazon S3\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS CloudWatch\n',
#  '    D. Amazon CloudFront\n',
#  '    **Correct: C**\n',
#  '\n',
#  '## Multiple Correct Answers\n',
#  '\n',
#  '21. Which of the following are valid methods for deploying an AWS Lambda function? (Select 2 apply)\n',
#  '    A. Using the AWS Management Console\n',
#  '    B. Using the AWS CLI\n',
#  '    C. Using the AWS SDK\n',
#  '    D. Using Terraform\n',
#  '    **Correct: A, C**\n',
#  '\n',
#  '22. Which of the following are benefits of using AWS Lambda? (Select 3 apply)\n',
#  '    A. Serverless architecture\n',
#  '    B. Pay-per-use pricing\n',
#  '    C. Automatic scaling\n',
#  '    D. High availability\n',
#  '    **Correct: A, B, C**\n',
#  '\n',
#  '23. Which of the following are components of an AWS VPC? (Select 3 apply)\n',
#  '    A. Subnets\n',
#  '    B. Route tables\n',
#  '    C. Security groups\n',
#  '    D. Load balancers\n',
#  '    **Correct: A, B, C**\n',
#  '\n',
#  '24. Which of the following are valid ways to configure access to an Amazon S3 bucket? (Select 3 apply)\n',
#  '    A. Using IAM policies\n',
#  '    B. Using bucket policies\n',
#  '    C. Using access control lists (ACLs)\n',
#  '    D. Using CloudFront distributions\n',
#  '    **Correct: A, B, C**\n',
#  '\n',
#  '25. Which of the following are ways to monitor AWS resources using AWS CloudWatch? (Select 3 apply)\n',
#  '    A. Creating custom metrics\n',
#  '    B. Using predefined metrics\n',
#  '    C. Setting up alarms\n',
#  '    D. Analyzing log data\n',
#  '    **Correct: A, B, C**\n',
#  '\n',
#  '26. Which of the following are valid methods for deploying an AWS CloudFormation stack? (Select 2 apply)\n',
#  '    A. Using the AWS Management Console\n',
#  '    B. Using the AWS CLI\n',
#  '    C. Using the AWS SDK\n',
#  '    D. Using Terraform\n',
#  '    **Correct: A, C**\n',
#  '\n',
#  '27. Which of the following are benefits of using AWS Elastic Beanstalk? (Select 3 apply)\n',
#  '    A. Simplified deployment process\n',
#  '    B. Automatic scaling\n',
#  '    C. Built-in monitoring and logging\n',
#  '    D. High availability\n',
#  '    **Correct: A, B, D**\n',
#  '\n',
#  '28. Which of the following are ways to access resources in a private subnet within an AWS VPC? (Select 2 apply)\n',
#  '    A. Using a NAT gateway\n',
#  '    B. Using a VPN connection\n',
#  '    C. Using a direct connection\n',
#  '    D. Using a public subnet\n',
#  '    **Correct: A, B**\n',
#  '\n',
#  '29. Which of the following are valid ways to manage AWS resources across multiple accounts? (Select 2 apply)\n',
#  '    A. Using AWS Organizations\n',
#  '    B. Using AWS IAM\n',
#  '    C. Using AWS CloudFormation\n',
#  '    D. Using AWS CloudTrail\n',
#  '    **Correct: A, B**\n',
#  '\n',
#  '30. Which of the following are ways to secure an AWS Lambda function? (Select 3 apply)\n',
#  '    A. Using IAM roles\n',
#  '    B. Using VPC endpoints\n',
#  '    C. Using Lambda layers\n',
#  '    D. Using Lambda triggers\n',
#  '    **Correct: A, B, C**\n',
#  '\n',
#  '## True/False\n',
#  '\n',
#  '31. AWS Lambda functions can be triggered by events from other AWS services, such as S3 bucket events.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '32. AWS CloudTrail can only record API calls made to AWS services, not user activity within AWS services.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: B**\n',
#  '\n',
#  '33. AWS CloudFormation can be used to create, update, and delete AWS resources, including those in other accounts.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: B**\n',
#  '\n',
#  '34. Amazon DynamoDB supports both document and key-value data models.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '35. AWS Elastic Beanstalk can automatically scale your application based on traffic patterns and resource usage.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '36. AWS Direct Connect provides a dedicated private connection to the AWS cloud, bypassing the public internet.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '37. AWS CloudWatch can monitor resources in other AWS accounts by using cross-account permissions.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '38. AWS Organizations allows you to manage multiple AWS accounts under a single umbrella, enforcing policies and controlling access.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '39. Amazon S3 buckets can be configured with different access control policies for different users and groups.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '40. AWS IAM users can be assigned specific permissions to access AWS resources, preventing unauthorized access.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct: A**\n',
#  '\n',
#  '## Single Correct Answer\n',
#  '\n',
#  '41. Which AWS service is primarily used for managing and deploying serverless applications, including those written in Python, Node.js, and Java?\n',
#  '    A. AWS Lambda\n',
#  '    B. Amazon EC2\n',
#  '    C. AWS Elastic Beanstalk\n',
#  '    D. Amazon ECS\n',
#  '    **Correct: A**\n',
#  '\n',
#  '42. What is the primary purpose of AWS Kinesis?\n',
#  '    A. Providing object storage\n',
#  '    B. Managing virtual private networks\n',
#  '    C. Providing real-time data processing\n',
#  '    D. Running containerized applications\n',
#  '    **Correct: C**\n',
#  '\n',
#  '43. Which AWS service is used for managing and monitoring your AWS resources, including setting up alarms and creating dashboards?\n',
#  '    A. AWS CloudFormation\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS CloudWatch\n',
#  '    D. Amazon S3\n',
#  '    **Correct: C**\n',
#  '\n',
#  '44. Which AWS service is used for deploying and managing serverless applications, including those written in Go, PHP, and Ruby?\n',
#  '    A. AWS Lambda\n',
#  '    B. Amazon EC2\n',
#  '    C. AWS Elastic Beanstalk\n',
#  '    D. Amazon ECS\n',
#  '    **Correct: A**\n',
#  '\n',
#  '45. Which AWS service provides a managed database service for NoSQL workloads, with high availability and scalability?\n',
#  '    A. Amazon RDS\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon Aurora\n',
#  '    **Correct: B**\n',
#  '\n',
#  '46. Which AWS service is primarily used for securing access to your AWS resources, including creating and managing user accounts and permissions?\n',
#  '    A. AWS CloudTrail\n',
#  '    B. AWS IAM\n',
#  '    C. AWS CloudFormation\n',
#  '    D. Amazon S3\n',
#  '    **Correct: B**\n',
#  '\n',
#  '47. Which AWS service allows you to create and manage virtual private networks, including subnets, security groups, and route tables?\n',
#  '    A. AWS VPC\n',
#  '    B. Amazon Route 53\n',
#  '    C. AWS CloudWatch\n',
#  '    D. Amazon S3\n',
#  '    **Correct: A**\n',
#  '\n',
#  '48. Which AWS service is primarily used for automating deployments and managing infrastructure, using infrastructure as code principles?\n',
#  '    A. AWS CloudFormation\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS CloudWatch\n',
#  '    D. Amazon EC2\n',
#  '    **Correct: A**\n',
#  '\n',
#  '49. Which AWS service provides a managed service for running and scaling web applications, including support for multiple languages and frameworks?\n',
#  '    A. AWS Lambda\n',
#  '    B. Amazon EC2\n',
#  '    C. AWS Elastic Beanstalk\n',
#  '    D. Amazon S3\n',
#  '    **Correct: C**\n',
#  '\n',
#  '50. Which AWS service is primarily used for collecting and analyzing log data from your applications, including metrics, events, and traces?\n',
#  '    A. Amazon S3\n',
#  '    B. AWS CloudTrail\n',
#  '    C. AWS CloudWatch\n',
#  '    D. Amazon CloudFront\n',
#  '    **Correct: C** \n']

# %%
def split_qa(lines_data):
    """
    Accepts list of lines.
    Returns a dictionary with keys `question` and `answer`
    """
    dict_data = {'question': [],
                 'answer': []}
    
    # Switch determines if the last line is in question section or not
    q_prev = False
    
    for line in lines_data:
        
        # Strip '**' style around 'Correct answer(s)' or 'Correct'
        line = line.replace('**', '')
        
        # Check if line is not blank, title or heading ('##')
        if (line != '\n') and ('##' not in line):
            
            # Call the first word of the line is `head`
            head = line.split()[0]
            
            # Append new question if all of these meet:
            # - Previous line is not in question text
            # - First character of `head` is numeric
            # - Last character of `head` is '.'
            if (not q_prev) and head[0].isnumeric() and head[-1] == ".":
                dict_data['question'].append(line)
                q_prev = True
    
            # Append new answer if all of these meet:
            # - Previous line is in question text
            # - `head` is 'A.'
            elif q_prev and head == 'A.':
                dict_data['answer'].append(line)
                q_prev = False
    
            # Add line to unfinished question
            elif q_prev:
                dict_data['question'][-1] += line
        
            # Add line to unfinished answer
            else:
                dict_data['answer'][-1] += line
    
    return dict_data

# %%
# Return split_qa result to a variable
dict0 = split_qa(data)

# Convert `dict0` to a DataFrame
df0 = pd.DataFrame(dict0)

print('Number of questions:', len(df0))
print('Columns:', df0.columns.values)
# Out:
# Number of questions: 50
# Columns: ['question' 'answer']

# %%
# View some rows
df0.iloc[15:60]
# Out:
#                                              question  \
# 15  16. Which AWS service is primarily used for se...
# 16  17. Which AWS service allows you to create and...
# 17  18. Which AWS service is primarily used for au...
# 18  19. Which AWS service provides a managed servi...
# 19  20. Which AWS service is primarily used for co...
# 20  21. Which of the following are valid methods f...
# 21  22. Which of the following are benefits of usi...
# 22  23. Which of the following are components of a...
# 23  24. Which of the following are valid ways to c...
# 24  25. Which of the following are ways to monitor...
# 25  26. Which of the following are valid methods f...
# 26  27. Which of the following are benefits of usi...
# 27  28. Which of the following are ways to access ...
# 28  29. Which of the following are valid ways to m...
# 29  30. Which of the following are ways to secure ...
# 30  31. AWS Lambda functions can be triggered by e...
# 31  32. AWS CloudTrail can only record API calls m...
# 32  33. AWS CloudFormation can be used to create, ...
# 33  34. Amazon DynamoDB supports both document and...
# 34  35. AWS Elastic Beanstalk can automatically sc...
# 35  36. AWS Direct Connect provides a dedicated pr...
# 36  37. AWS CloudWatch can monitor resources in ot...
# 37  38. AWS Organizations allows you to manage mul...
# 38  39. Amazon S3 buckets can be configured with d...
# 39  40. AWS IAM users can be assigned specific per...
# 40  41. Which AWS service is primarily used for ma...
# 41  42. What is the primary purpose of AWS Kinesis?\n
# 42  43. Which AWS service is used for managing and...
# 43  44. Which AWS service is used for deploying an...
# 44  45. Which AWS service provides a managed datab...
# 45  46. Which AWS service is primarily used for se...
# 46  47. Which AWS service allows you to create and...
# 47  48. Which AWS service is primarily used for au...
# 48  49. Which AWS service provides a managed servi...
# 49  50. Which AWS service is primarily used for co...
#
#                                                answer
# 15      A. AWS CloudTrail\n    B. AWS IAM\n    C. ...
# 16      A. AWS VPC\n    B. Amazon Route 53\n    C....
# 17      A. AWS CloudFormation\n    B. AWS CloudTra...
# 18      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 19      A. Amazon S3\n    B. AWS CloudTrail\n    C...
# 20      A. Using the AWS Management Console\n    B...
# 21      A. Serverless architecture\n    B. Pay-per...
# 22      A. Subnets\n    B. Route tables\n    C. Se...
# 23      A. Using IAM policies\n    B. Using bucket...
# 24      A. Creating custom metrics\n    B. Using p...
# 25      A. Using the AWS Management Console\n    B...
# 26      A. Simplified deployment process\n    B. A...
# 27      A. Using a NAT gateway\n    B. Using a VPN...
# 28      A. Using AWS Organizations\n    B. Using A...
# 29      A. Using IAM roles\n    B. Using VPC endpo...
# 30            A. True\n    B. False\n    Correct: A\n
# 31            A. True\n    B. False\n    Correct: B\n
# 32            A. True\n    B. False\n    Correct: B\n
# 33            A. True\n    B. False\n    Correct: A\n
# 34            A. True\n    B. False\n    Correct: A\n
# 35            A. True\n    B. False\n    Correct: A\n
# 36            A. True\n    B. False\n    Correct: A\n
# 37            A. True\n    B. False\n    Correct: A\n
# 38            A. True\n    B. False\n    Correct: A\n
# 39            A. True\n    B. False\n    Correct: A\n
# 40      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 41      A. Providing object storage\n    B. Managi...
# 42      A. AWS CloudFormation\n    B. AWS CloudTra...
# 43      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 44      A. Amazon RDS\n    B. Amazon DynamoDB\n   ...
# 45      A. AWS CloudTrail\n    B. AWS IAM\n    C. ...
# 46      A. AWS VPC\n    B. Amazon Route 53\n    C....
# 47      A. AWS CloudFormation\n    B. AWS CloudTra...
# 48      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 49      A. Amazon S3\n    B. AWS CloudTrail\n    C...

# %%
# Make a copy of df0
df1 = df0.copy()

# %%
# Strip the number at the beginning and '\n' at the end of each question 
df1['question'] = df1['question'].str.replace(r'^\d{0,4}\.[ ]', '', regex=True).str.rstrip()

# %%
df1
# Out:
#                                              question  \
# 0    A single AWS account can only have one IAM user.
# 1   Amazon S3 buckets can be directly accessed fro...
# 2   AWS Lambda functions can only be triggered by ...
# 3   AWS CloudTrail can only record API calls made ...
# 4   AWS CloudFormation can only be used to create ...
# 5   Amazon DynamoDB supports both document and rel...
# 6   AWS Elastic Beanstalk automatically scales you...
# 7   AWS Direct Connect provides a dedicated privat...
# 8   AWS CloudWatch only monitors resources within ...
# 9   AWS Organizations allows you to manage multipl...
# 10  Which AWS service is primarily used for managi...
# 11    What is the primary purpose of Amazon Route 53?
# 12  Which AWS service is used for managing and mon...
# 13  Which AWS service is used for deploying and ma...
# 14  Which AWS service provides a managed database ...
# 15  Which AWS service is primarily used for securi...
# 16  Which AWS service allows you to create and man...
# 17  Which AWS service is primarily used for automa...
# 18  Which AWS service provides a managed service f...
# 19  Which AWS service is primarily used for collec...
# 20  Which of the following are valid methods for d...
# 21  Which of the following are benefits of using A...
# 22  Which of the following are components of an AW...
# 23  Which of the following are valid ways to confi...
# 24  Which of the following are ways to monitor AWS...
# 25  Which of the following are valid methods for d...
# 26  Which of the following are benefits of using A...
# 27  Which of the following are ways to access reso...
# 28  Which of the following are valid ways to manag...
# 29  Which of the following are ways to secure an A...
# 30  AWS Lambda functions can be triggered by event...
# 31  AWS CloudTrail can only record API calls made ...
# 32  AWS CloudFormation can be used to create, upda...
# 33  Amazon DynamoDB supports both document and key...
# 34  AWS Elastic Beanstalk can automatically scale ...
# 35  AWS Direct Connect provides a dedicated privat...
# 36  AWS CloudWatch can monitor resources in other ...
# 37  AWS Organizations allows you to manage multipl...
# 38  Amazon S3 buckets can be configured with diffe...
# 39  AWS IAM users can be assigned specific permiss...
# 40  Which AWS service is primarily used for managi...
# 41        What is the primary purpose of AWS Kinesis?
# 42  Which AWS service is used for managing and mon...
# 43  Which AWS service is used for deploying and ma...
# 44  Which AWS service provides a managed database ...
# 45  Which AWS service is primarily used for securi...
# 46  Which AWS service allows you to create and man...
# 47  Which AWS service is primarily used for automa...
# 48  Which AWS service provides a managed service f...
# 49  Which AWS service is primarily used for collec...
#
#                                                answer
# 0             A. True\n    B. False\n    Correct: B\n
# 1             A. True\n    B. False\n    Correct: B\n
# 2             A. True\n    B. False\n    Correct: B\n
# 3             A. True\n    B. False\n    Correct: B\n
# 4             A. True\n    B. False\n    Correct: B\n
# 5             A. True\n    B. False\n    Correct: B\n
# 6             A. True\n    B. False\n    Correct: A\n
# 7             A. True\n    B. False\n    Correct: A\n
# 8             A. True\n    B. False\n    Correct: B\n
# 9             A. True\n    B. False\n    Correct: A\n
# 10      A. Amazon EC2\n    B. Amazon ECS\n    C. A...
# 11      A. Providing object storage\n    B. Managi...
# 12      A. AWS CloudFormation\n    B. AWS CloudTra...
# 13      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 14      A. Amazon RDS\n    B. Amazon DynamoDB\n   ...
# 15      A. AWS CloudTrail\n    B. AWS IAM\n    C. ...
# 16      A. AWS VPC\n    B. Amazon Route 53\n    C....
# 17      A. AWS CloudFormation\n    B. AWS CloudTra...
# 18      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 19      A. Amazon S3\n    B. AWS CloudTrail\n    C...
# 20      A. Using the AWS Management Console\n    B...
# 21      A. Serverless architecture\n    B. Pay-per...
# 22      A. Subnets\n    B. Route tables\n    C. Se...
# 23      A. Using IAM policies\n    B. Using bucket...
# 24      A. Creating custom metrics\n    B. Using p...
# 25      A. Using the AWS Management Console\n    B...
# 26      A. Simplified deployment process\n    B. A...
# 27      A. Using a NAT gateway\n    B. Using a VPN...
# 28      A. Using AWS Organizations\n    B. Using A...
# 29      A. Using IAM roles\n    B. Using VPC endpo...
# 30            A. True\n    B. False\n    Correct: A\n
# 31            A. True\n    B. False\n    Correct: B\n
# 32            A. True\n    B. False\n    Correct: B\n
# 33            A. True\n    B. False\n    Correct: A\n
# 34            A. True\n    B. False\n    Correct: A\n
# 35            A. True\n    B. False\n    Correct: A\n
# 36            A. True\n    B. False\n    Correct: A\n
# 37            A. True\n    B. False\n    Correct: A\n
# 38            A. True\n    B. False\n    Correct: A\n
# 39            A. True\n    B. False\n    Correct: A\n
# 40      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 41      A. Providing object storage\n    B. Managi...
# 42      A. AWS CloudFormation\n    B. AWS CloudTra...
# 43      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 44      A. Amazon RDS\n    B. Amazon DynamoDB\n   ...
# 45      A. AWS CloudTrail\n    B. AWS IAM\n    C. ...
# 46      A. AWS VPC\n    B. Amazon Route 53\n    C....
# 47      A. AWS CloudFormation\n    B. AWS CloudTra...
# 48      A. AWS Lambda\n    B. Amazon EC2\n    C. A...
# 49      A. Amazon S3\n    B. AWS CloudTrail\n    C...

# %%
def convert_index(capital):
    """Return zero-based index from capital, 'A' has unicode code as 65"""
    return ord(capital) - 65

def split_choice(answer):
    """
    Split the `answer` data into multiple choices
    """
    # print(answer)
    
    # Use 'Correct Answer(s): ' to split text.
    # Index 0 is all choices, index 1 is all answers
    if 'Correct Answer' in answer:
        split_all = re.split(r'Correct Answer[s]*: ', answer)
    else:
        split_all = re.split('Correct: ', answer)
    # print("After strip 'Correct Answer(s): ' or 'Correct: ':", split_all)
    
    choices = split_all[0]
    # print('Choices text:', choices)
    
    correct_stack = split_all[1]
    # print('Correct stack:', correct_stack)
    
    # Split using ','
    correct_stack = correct_stack.split(',')
    
    # Pick only first capital indicating the choices
    correct_note = [item.strip()[0] for item in correct_stack]
    # print('Correct note:', correct_note)
    
    # Make zero-based index from alphabet
    correct_index = [convert_index(item) for item in correct_note]
    # print('Correct index', correct_index)
    
    # Split using 'X. ', index 0 is '', so pass
    choices = re.split(r'[A-Z]\.[ ]', choices)[1:]
    # Strip right side of choice text
    choices = [choice.rstrip() for choice in choices]
    # print('All choices in list: ', choices)
    
    # Separate choices into lists as `incorrect` and `correct`
    incorrect = [choice for index, choice in enumerate(choices) if index not in correct_index]
    # print('Incorrect in list: ', incorrect)
    correct = [choice for index, choice in enumerate(choices) if index in correct_index]
    # print('Correct in list: ', correct)
    
    return {'incorrect': incorrect,
            'correct': correct}

# %%
# Make a copy of `df1`
df2 = df1.copy()

# %%
# Test the function with sub set of data
df_test = df2.iloc[20:22]['answer'].apply(split_choice)

# %%
# Print out to preview results
display(df_test.str['incorrect'])
df_test.str['correct']
# Out:
# 20    [Using the AWS CLI, Using Terraform]
# 21                     [High availability]
# Name: answer, dtype: object
# 20    [Using the AWS Management Console, Using the A...
# 21    [Serverless architecture, Pay-per-use pricing,...
# Name: answer, dtype: object

# %%
# Apply the function to full dataset
df2['incorrect'] = df2['answer'].apply(split_choice).str['incorrect']
df2['correct'] = df2['answer'].apply(split_choice).str['correct']

# %%
# Preview a row
display(df2.loc[40, 'incorrect'])
display(df2.loc[40, 'correct'])
# Out:
# ['Amazon EC2', 'AWS Elastic Beanstalk', 'Amazon ECS']
# ['AWS Lambda']

# %%
# New order of columns
new_order = ['question', 'incorrect', 'correct']

# Make a copy of `df2` with new order of columns
df_clean = df2[new_order].copy()

# Preview data in a row
display(df_clean['incorrect'][45])
display(df_clean['correct'][45])
df_clean.iloc[45]
# Out:
# ['AWS CloudTrail', 'AWS CloudFormation', 'Amazon S3']
# ['AWS IAM']
# question     Which AWS service is primarily used for securi...
# incorrect      [AWS CloudTrail, AWS CloudFormation, Amazon S3]
# correct                                              [AWS IAM]
# Name: 45, dtype: object

# %%
# Preview the whole final table
df_clean
# Out:
#                                              question  \
# 0    A single AWS account can only have one IAM user.
# 1   Amazon S3 buckets can be directly accessed fro...
# 2   AWS Lambda functions can only be triggered by ...
# 3   AWS CloudTrail can only record API calls made ...
# 4   AWS CloudFormation can only be used to create ...
# 5   Amazon DynamoDB supports both document and rel...
# 6   AWS Elastic Beanstalk automatically scales you...
# 7   AWS Direct Connect provides a dedicated privat...
# 8   AWS CloudWatch only monitors resources within ...
# 9   AWS Organizations allows you to manage multipl...
# 10  Which AWS service is primarily used for managi...
# 11    What is the primary purpose of Amazon Route 53?
# 12  Which AWS service is used for managing and mon...
# 13  Which AWS service is used for deploying and ma...
# 14  Which AWS service provides a managed database ...
# 15  Which AWS service is primarily used for securi...
# 16  Which AWS service allows you to create and man...
# 17  Which AWS service is primarily used for automa...
# 18  Which AWS service provides a managed service f...
# 19  Which AWS service is primarily used for collec...
# 20  Which of the following are valid methods for d...
# 21  Which of the following are benefits of using A...
# 22  Which of the following are components of an AW...
# 23  Which of the following are valid ways to confi...
# 24  Which of the following are ways to monitor AWS...
# 25  Which of the following are valid methods for d...
# 26  Which of the following are benefits of using A...
# 27  Which of the following are ways to access reso...
# 28  Which of the following are valid ways to manag...
# 29  Which of the following are ways to secure an A...
# 30  AWS Lambda functions can be triggered by event...
# 31  AWS CloudTrail can only record API calls made ...
# 32  AWS CloudFormation can be used to create, upda...
# 33  Amazon DynamoDB supports both document and key...
# 34  AWS Elastic Beanstalk can automatically scale ...
# 35  AWS Direct Connect provides a dedicated privat...
# 36  AWS CloudWatch can monitor resources in other ...
# 37  AWS Organizations allows you to manage multipl...
# 38  Amazon S3 buckets can be configured with diffe...
# 39  AWS IAM users can be assigned specific permiss...
# 40  Which AWS service is primarily used for managi...
# 41        What is the primary purpose of AWS Kinesis?
# 42  Which AWS service is used for managing and mon...
# 43  Which AWS service is used for deploying and ma...
# 44  Which AWS service provides a managed database ...
# 45  Which AWS service is primarily used for securi...
# 46  Which AWS service allows you to create and man...
# 47  Which AWS service is primarily used for automa...
# 48  Which AWS service provides a managed service f...
# 49  Which AWS service is primarily used for collec...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                              [True]
# 5                                              [True]
# 6                                             [False]
# 7                                             [False]
# 8                                              [True]
# 9                                             [False]
# 10                [Amazon EC2, AWS Lambda, Amazon S3]
# 11  [Providing object storage, Managing virtual pr...
# 12    [AWS CloudFormation, AWS CloudTrail, Amazon S3]
# 13    [Amazon EC2, AWS Elastic Beanstalk, Amazon ECS]
# 14       [Amazon RDS, Amazon Redshift, Amazon Aurora]
# 15    [AWS CloudTrail, AWS CloudFormation, Amazon S3]
# 16       [Amazon Route 53, AWS CloudWatch, Amazon S3]
# 17       [AWS CloudTrail, AWS CloudWatch, Amazon EC2]
# 18                [AWS Lambda, Amazon EC2, Amazon S3]
# 19     [Amazon S3, AWS CloudTrail, Amazon CloudFront]
# 20               [Using the AWS CLI, Using Terraform]
# 21                                [High availability]
# 22                                   [Load balancers]
# 23                   [Using CloudFront distributions]
# 24                               [Analyzing log data]
# 25               [Using the AWS CLI, Using Terraform]
# 26                  [Built-in monitoring and logging]
# 27  [Using a direct connection, Using a public sub...
# 28   [Using AWS CloudFormation, Using AWS CloudTrail]
# 29                            [Using Lambda triggers]
# 30                                            [False]
# 31                                             [True]
# 32                                             [True]
# 33                                            [False]
# 34                                            [False]
# 35                                            [False]
# 36                                            [False]
# 37                                            [False]
# 38                                            [False]
# 39                                            [False]
# 40    [Amazon EC2, AWS Elastic Beanstalk, Amazon ECS]
# 41  [Providing object storage, Managing virtual pr...
# 42    [AWS CloudFormation, AWS CloudTrail, Amazon S3]
# 43    [Amazon EC2, AWS Elastic Beanstalk, Amazon ECS]
# 44       [Amazon RDS, Amazon Redshift, Amazon Aurora]
# 45    [AWS CloudTrail, AWS CloudFormation, Amazon S3]
# 46       [Amazon Route 53, AWS CloudWatch, Amazon S3]
# 47       [AWS CloudTrail, AWS CloudWatch, Amazon EC2]
# 48                [AWS Lambda, Amazon EC2, Amazon S3]
# 49     [Amazon S3, AWS CloudTrail, Amazon CloudFront]
#
#                                               correct
# 0                                             [False]
# 1                                             [False]
# 2                                             [False]
# 3                                             [False]
# 4                                             [False]
# 5                                             [False]
# 6                                              [True]
# 7                                              [True]
# 8                                             [False]
# 9                                              [True]
# 10                                       [Amazon ECS]
# 11                           [Providing DNS services]
# 12                                   [AWS CloudWatch]
# 13                                       [AWS Lambda]
# 14                                  [Amazon DynamoDB]
# 15                                          [AWS IAM]
# 16                                          [AWS VPC]
# 17                               [AWS CloudFormation]
# 18                            [AWS Elastic Beanstalk]
# 19                                   [AWS CloudWatch]
# 20  [Using the AWS Management Console, Using the A...
# 21  [Serverless architecture, Pay-per-use pricing,...
# 22           [Subnets, Route tables, Security groups]
# 23  [Using IAM policies, Using bucket policies, Us...
# 24  [Creating custom metrics, Using predefined met...
# 25  [Using the AWS Management Console, Using the A...
# 26  [Simplified deployment process, Automatic scal...
# 27      [Using a NAT gateway, Using a VPN connection]
# 28           [Using AWS Organizations, Using AWS IAM]
# 29  [Using IAM roles, Using VPC endpoints, Using L...
# 30                                             [True]
# 31                                            [False]
# 32                                            [False]
# 33                                             [True]
# 34                                             [True]
# 35                                             [True]
# 36                                             [True]
# 37                                             [True]
# 38                                             [True]
# 39                                             [True]
# 40                                       [AWS Lambda]
# 41              [Providing real-time data processing]
# 42                                   [AWS CloudWatch]
# 43                                       [AWS Lambda]
# 44                                  [Amazon DynamoDB]
# 45                                          [AWS IAM]
# 46                                          [AWS VPC]
# 47                               [AWS CloudFormation]
# 48                            [AWS Elastic Beanstalk]
# 49                                   [AWS CloudWatch]

# %%
# Pick up the read blob name with '.txt' excluded, to make new json file name
JSON_BLOB = READ_BLOB[:-4] + '.json'

# Convert `df_clean` to JSON string
export_json_string = df_clean.to_json()

# %%
# Write JSON string to GCS object as a JSON file
gcs_write(BUCKET, JSON_BLOB, export_json_string)

# %%
# Read just exported JSON file for testing purpose
read_json_string = gcs_read(BUCKET, JSON_BLOB, j_load=True)

# Convert to DataFrame
df_json = pd.DataFrame(read_json_string)

# %%
# Preview json file data as DataFrame
df_json
# Out:
#                                              question  \
# 0    A single AWS account can only have one IAM user.
# 1   Amazon S3 buckets can be directly accessed fro...
# 2   AWS Lambda functions can only be triggered by ...
# 3   AWS CloudTrail can only record API calls made ...
# 4   AWS CloudFormation can only be used to create ...
# 5   Amazon DynamoDB supports both document and rel...
# 6   AWS Elastic Beanstalk automatically scales you...
# 7   AWS Direct Connect provides a dedicated privat...
# 8   AWS CloudWatch only monitors resources within ...
# 9   AWS Organizations allows you to manage multipl...
# 10  Which AWS service is primarily used for managi...
# 11    What is the primary purpose of Amazon Route 53?
# 12  Which AWS service is used for managing and mon...
# 13  Which AWS service is used for deploying and ma...
# 14  Which AWS service provides a managed database ...
# 15  Which AWS service is primarily used for securi...
# 16  Which AWS service allows you to create and man...
# 17  Which AWS service is primarily used for automa...
# 18  Which AWS service provides a managed service f...
# 19  Which AWS service is primarily used for collec...
# 20  Which of the following are valid methods for d...
# 21  Which of the following are benefits of using A...
# 22  Which of the following are components of an AW...
# 23  Which of the following are valid ways to confi...
# 24  Which of the following are ways to monitor AWS...
# 25  Which of the following are valid methods for d...
# 26  Which of the following are benefits of using A...
# 27  Which of the following are ways to access reso...
# 28  Which of the following are valid ways to manag...
# 29  Which of the following are ways to secure an A...
# 30  AWS Lambda functions can be triggered by event...
# 31  AWS CloudTrail can only record API calls made ...
# 32  AWS CloudFormation can be used to create, upda...
# 33  Amazon DynamoDB supports both document and key...
# 34  AWS Elastic Beanstalk can automatically scale ...
# 35  AWS Direct Connect provides a dedicated privat...
# 36  AWS CloudWatch can monitor resources in other ...
# 37  AWS Organizations allows you to manage multipl...
# 38  Amazon S3 buckets can be configured with diffe...
# 39  AWS IAM users can be assigned specific permiss...
# 40  Which AWS service is primarily used for managi...
# 41        What is the primary purpose of AWS Kinesis?
# 42  Which AWS service is used for managing and mon...
# 43  Which AWS service is used for deploying and ma...
# 44  Which AWS service provides a managed database ...
# 45  Which AWS service is primarily used for securi...
# 46  Which AWS service allows you to create and man...
# 47  Which AWS service is primarily used for automa...
# 48  Which AWS service provides a managed service f...
# 49  Which AWS service is primarily used for collec...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                              [True]
# 5                                              [True]
# 6                                             [False]
# 7                                             [False]
# 8                                              [True]
# 9                                             [False]
# 10                [Amazon EC2, AWS Lambda, Amazon S3]
# 11  [Providing object storage, Managing virtual pr...
# 12    [AWS CloudFormation, AWS CloudTrail, Amazon S3]
# 13    [Amazon EC2, AWS Elastic Beanstalk, Amazon ECS]
# 14       [Amazon RDS, Amazon Redshift, Amazon Aurora]
# 15    [AWS CloudTrail, AWS CloudFormation, Amazon S3]
# 16       [Amazon Route 53, AWS CloudWatch, Amazon S3]
# 17       [AWS CloudTrail, AWS CloudWatch, Amazon EC2]
# 18                [AWS Lambda, Amazon EC2, Amazon S3]
# 19     [Amazon S3, AWS CloudTrail, Amazon CloudFront]
# 20               [Using the AWS CLI, Using Terraform]
# 21                                [High availability]
# 22                                   [Load balancers]
# 23                   [Using CloudFront distributions]
# 24                               [Analyzing log data]
# 25               [Using the AWS CLI, Using Terraform]
# 26                  [Built-in monitoring and logging]
# 27  [Using a direct connection, Using a public sub...
# 28   [Using AWS CloudFormation, Using AWS CloudTrail]
# 29                            [Using Lambda triggers]
# 30                                            [False]
# 31                                             [True]
# 32                                             [True]
# 33                                            [False]
# 34                                            [False]
# 35                                            [False]
# 36                                            [False]
# 37                                            [False]
# 38                                            [False]
# 39                                            [False]
# 40    [Amazon EC2, AWS Elastic Beanstalk, Amazon ECS]
# 41  [Providing object storage, Managing virtual pr...
# 42    [AWS CloudFormation, AWS CloudTrail, Amazon S3]
# 43    [Amazon EC2, AWS Elastic Beanstalk, Amazon ECS]
# 44       [Amazon RDS, Amazon Redshift, Amazon Aurora]
# 45    [AWS CloudTrail, AWS CloudFormation, Amazon S3]
# 46       [Amazon Route 53, AWS CloudWatch, Amazon S3]
# 47       [AWS CloudTrail, AWS CloudWatch, Amazon EC2]
# 48                [AWS Lambda, Amazon EC2, Amazon S3]
# 49     [Amazon S3, AWS CloudTrail, Amazon CloudFront]
#
#                                               correct
# 0                                             [False]
# 1                                             [False]
# 2                                             [False]
# 3                                             [False]
# 4                                             [False]
# 5                                             [False]
# 6                                              [True]
# 7                                              [True]
# 8                                             [False]
# 9                                              [True]
# 10                                       [Amazon ECS]
# 11                           [Providing DNS services]
# 12                                   [AWS CloudWatch]
# 13                                       [AWS Lambda]
# 14                                  [Amazon DynamoDB]
# 15                                          [AWS IAM]
# 16                                          [AWS VPC]
# 17                               [AWS CloudFormation]
# 18                            [AWS Elastic Beanstalk]
# 19                                   [AWS CloudWatch]
# 20  [Using the AWS Management Console, Using the A...
# 21  [Serverless architecture, Pay-per-use pricing,...
# 22           [Subnets, Route tables, Security groups]
# 23  [Using IAM policies, Using bucket policies, Us...
# 24  [Creating custom metrics, Using predefined met...
# 25  [Using the AWS Management Console, Using the A...
# 26  [Simplified deployment process, Automatic scal...
# 27      [Using a NAT gateway, Using a VPN connection]
# 28           [Using AWS Organizations, Using AWS IAM]
# 29  [Using IAM roles, Using VPC endpoints, Using L...
# 30                                             [True]
# 31                                            [False]
# 32                                            [False]
# 33                                             [True]
# 34                                             [True]
# 35                                             [True]
# 36                                             [True]
# 37                                             [True]
# 38                                             [True]
# 39                                             [True]
# 40                                       [AWS Lambda]
# 41              [Providing real-time data processing]
# 42                                   [AWS CloudWatch]
# 43                                       [AWS Lambda]
# 44                                  [Amazon DynamoDB]
# 45                                          [AWS IAM]
# 46                                          [AWS VPC]
# 47                               [AWS CloudFormation]
# 48                            [AWS Elastic Beanstalk]
# 49                                   [AWS CloudWatch]

# %%
# Preview index in JSON string to confirm
read_json_string['question']['15']
# Out:
# 'Which AWS service is primarily used for securing access to your AWS resources?'

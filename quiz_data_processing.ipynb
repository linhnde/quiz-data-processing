# %%
# Import general packages
import pandas as pd
import re
import io
import json

# Set environment variable to authenticate GCP credentials
# !export GOOGLE_APPLICATION_CREDENTIALS='book-to-quiz-7558e7ee5aca.json'

LOCATION = "us-central1"
PROJECT = 'book-to-quiz'
BUCKET = 'book-to-quiz-question-bank'
MODEL = "gemini-1.5-flash-001"

# %%
# Imports the Google Cloud client library
from google.cloud import storage

def gcs_read(bucket_name, blob_name, j_load=False):
    """
    Read a blob from GCS using file-like IO.
    Default use readlines() for text file.
    Change `j_load` to True if json.load() is used for reading clean JSON file.
    """
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("r") as file:
        if j_load:
            return json.load(file)
        return file.readlines()
    
def gcs_write(bucket_name, blob_name, content):
    """Write a blob from GCS using file-like IO"""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("w") as file:
        file.write(content)

# %%
# Import Vertex AI packages
import vertexai
from vertexai.generative_models import GenerativeModel
import vertexai.preview.generative_models as generative_models

def generate(p_text, g_config, s_settings):
    """Yield text with generator which receive prompt text, generation config and safety settings as arguments"""
    vertexai.init(project=PROJECT, location=LOCATION)
    model = GenerativeModel(
        MODEL,
    )
    responses = model.generate_content(
        [p_text],
        generation_config=g_config,
        safety_settings=s_settings,
        stream=True,
    )

    for response in responses:
        yield response.text

# %%
prompt = """Generate quiz with these requirements:
- Total questions: 50.
- Topic: AWS.
- Difficulty: Hard.
- Types: true/false, single correct answer, multiple correct answers.
- Indent questions with number.
- Indent choices and true/false with upper letter.
- If more than 2 correct answers questions, remind  \"(select [exact number] apply)\" before choice A.
- In each question, total correct answers is less than total choices.
- Choices consist multiple technically complicated steps.
- Show correct choices at the end of each question.
- No markdown, plain text.
- Group by type."""

generation_config = {
    "max_output_tokens": 8192,
    "temperature": 1,
    "top_p": 0.95,
}

safety_settings = {
    generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

# %%
# Assign generator to a variable
generator = generate(prompt, generation_config, safety_settings)

# %%
# Use string comprehension to gather text from generator
generate_text = ''.join(response for response in generator)

# %%
# Use print() for generate_text for better preview because generated_text is whole string, not list of lines
print(generate_text)
# Out:
# ## True/False
#
# 1.  **True/False:**  A single AWS account can be used to create multiple AWS Organizations.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 2. **True/False:**  Amazon S3 Standard-Infrequent Access (S3 Standard-IA) is a storage class for data that is accessed frequently, but not immediately.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 3. **True/False:**  Amazon CloudFront can be used to distribute static content, but not dynamic content.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 4. **True/False:**  Amazon VPC allows you to create a private network within AWS, but it does not support IPv6 addressing.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 5. **True/False:**  AWS Lambda functions can be triggered by events from multiple AWS services, including S3, DynamoDB, and API Gateway.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 6. **True/False:**  Amazon Elastic Beanstalk supports deployment of applications built with a variety of frameworks, including Java, Python, and .NET.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 7. **True/False:**  AWS IAM roles can be used to grant permissions to users, but not to other AWS services.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 8. **True/False:**  Amazon EC2 Auto Scaling groups can be configured to automatically scale based on metrics like CPU utilization and network traffic.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 9. **True/False:**  Amazon Redshift is a fully managed, petabyte-scale data warehouse service, optimized for analytical workloads.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 10. **True/False:**  Amazon Route 53 can be used to create and manage DNS records for applications running on AWS, but not for applications running outside of AWS.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 11. **True/False:**  Amazon CloudWatch can be used to monitor AWS resources and applications, but not to collect and analyze logs.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 12. **True/False:**  AWS CodePipeline allows you to automate the build, test, and deployment of applications, but it does not support integration with third-party tools.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 13. **True/False:**  Amazon Cognito can be used to authenticate and authorize users for web and mobile applications.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 14. **True/False:**  AWS Kinesis is a real-time data streaming service that can be used to process large volumes of data, but it does not support integration with third-party applications.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 15. **True/False:**  Amazon ElastiCache can be used to improve the performance of applications that require low-latency access to data.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 16. **True/False:**  AWS Step Functions is a serverless orchestration service that can be used to define and execute workflows.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 17. **True/False:**  Amazon DynamoDB is a fully managed, NoSQL database service that supports both document and key-value data models.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 18. **True/False:**  AWS Direct Connect allows you to establish a dedicated, private connection between your on-premises network and AWS.
#     A. True
#     B. False
#     **Correct Answer:** A. True
#
# 19. **True/False:**  Amazon CloudTrail can be used to record and monitor API calls made to AWS, but it does not support integration with third-party logging systems.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# 20. **True/False:**  AWS Security Hub provides a centralized view of security alerts across your AWS accounts, but it does not support integration with third-party security tools.
#     A. True
#     B. False
#     **Correct Answer:** B. False
#
# ## Single Correct Answer
#
# 21. Which AWS service is a fully managed, serverless data warehousing service optimized for analytics?
#     A. Amazon DynamoDB
#     B. Amazon Redshift
#     C. Amazon ElastiCache
#     D. Amazon S3
#     **Correct Answer:** B. Amazon Redshift
#
# 22. Which AWS service provides a managed, highly scalable message queuing service?
#     A. Amazon SQS
#     B. Amazon SNS
#     C. Amazon Kinesis
#     D. Amazon CloudFront
#     **Correct Answer:** A. Amazon SQS
#
# 23. Which AWS service allows you to create and manage DNS records for your applications?
#     A. Amazon Route 53
#     B. Amazon CloudFront
#     C. Amazon S3
#     D. Amazon EC2
#     **Correct Answer:** A. Amazon Route 53
#
# 24. Which AWS service allows you to build and deploy containerized applications?
#     A. Amazon Elastic Beanstalk
#     B. Amazon ECS
#     C. Amazon EKS
#     D. AWS Lambda
#     **Correct Answer:** B. Amazon ECS
#
# 25. Which AWS service provides a managed, serverless database service that supports both document and key-value data models?
#     A. Amazon DynamoDB
#     B. Amazon RDS
#     C. Amazon Redshift
#     D. Amazon ElastiCache
#     **Correct Answer:** A. Amazon DynamoDB
#
# 26. Which AWS service provides a fully managed, serverless service for running code in response to events?
#     A. Amazon EC2
#     B. AWS Lambda
#     C. Amazon ECS
#     D. Amazon Elastic Beanstalk
#     **Correct Answer:** B. AWS Lambda
#
# 27. Which AWS service allows you to create and manage virtual private clouds within AWS?
#     A. Amazon S3
#     B. Amazon Route 53
#     C. Amazon VPC
#     D. Amazon EC2
#     **Correct Answer:** C. Amazon VPC
#
# 28. Which AWS service allows you to create and manage user identities and permissions for accessing AWS resources?
#     A. AWS IAM
#     B. Amazon Cognito
#     C. AWS Organizations
#     D. Amazon CloudTrail
#     **Correct Answer:** A. AWS IAM
#
# 29. Which AWS service provides a managed service for managing and monitoring infrastructure changes in your AWS environment?
#     A. Amazon CloudTrail
#     B. AWS Config
#     C. Amazon CloudWatch
#     D. AWS Security Hub
#     **Correct Answer:** B. AWS Config
#
# 30. Which AWS service allows you to create and manage load balancers for your applications?
#     A. Amazon Elastic Load Balancing
#     B. Amazon Route 53
#     C. Amazon CloudFront
#     D. Amazon S3
#     **Correct Answer:** A. Amazon Elastic Load Balancing
#
# 31. Which AWS service allows you to encrypt data at rest and in transit?
#     A. AWS KMS
#     B. AWS IAM
#     C. Amazon CloudTrail
#     D. AWS Config
#     **Correct Answer:** A. AWS KMS
#
# 32. Which AWS service provides a fully managed, serverless service for processing streaming data in real-time?
#     A. Amazon SQS
#     B. Amazon Kinesis
#     C. Amazon SNS
#     D. Amazon DynamoDB
#     **Correct Answer:** B. Amazon Kinesis
#
# 33. Which AWS service provides a managed, in-memory caching service?
#     A. Amazon ElastiCache
#     B. Amazon DynamoDB
#     C. Amazon Redshift
#     D. Amazon S3
#     **Correct Answer:** A. Amazon ElastiCache
#
# 34. Which AWS service provides a managed service for running and managing containers in the cloud?
#     A. Amazon ECS
#     B. AWS Lambda
#     C. Amazon EC2
#     D. Amazon Elastic Beanstalk
#     **Correct Answer:** A. Amazon ECS
#
# 35. Which AWS service provides a managed service for deploying and managing Kubernetes clusters in the cloud?
#     A. Amazon EKS
#     B. Amazon ECS
#     C. Amazon EC2
#     D. AWS Lambda
#     **Correct Answer:** A. Amazon EKS
#
# 36. Which AWS service allows you to create and manage highly available, fault-tolerant applications in the cloud?
#     A. Amazon Elastic Beanstalk
#     B. Amazon ECS
#     C. Amazon EKS
#     D. AWS Lambda
#     **Correct Answer:** A. Amazon Elastic Beanstalk
#
# 37. Which AWS service provides a managed service for managing and automating your software development lifecycle?
#     A. AWS CodePipeline
#     B. AWS CodeDeploy
#     C. AWS CodeBuild
#     D. AWS CodeStar
#     **Correct Answer:** D. AWS CodeStar
#
# 38. Which AWS service provides a managed service for managing and automating your application deployments?
#     A. AWS CodeDeploy
#     B. AWS CodePipeline
#     C. AWS CodeBuild
#     D. AWS CodeStar
#     **Correct Answer:** A. AWS CodeDeploy
#
# 39. Which AWS service provides a managed service for building and testing your application code?
#     A. AWS CodeBuild
#     B. AWS CodePipeline
#     C. AWS CodeDeploy
#     D. AWS CodeStar
#     **Correct Answer:** A. AWS CodeBuild
#
# 40. Which AWS service provides a managed service for collecting, processing, and analyzing log data from your AWS resources?
#     A. Amazon CloudWatch
#     B. Amazon CloudTrail
#     C. AWS Config
#     D. AWS Security Hub
#     **Correct Answer:** A. Amazon CloudWatch
#
# ## Multiple Correct Answers
#
# 41. **(Select 2 apply)** Which AWS services can be used to create and manage security groups for your VPC?
#     A. Amazon VPC
#     B. AWS IAM
#     C. Amazon CloudTrail
#     D. AWS Security Hub
#     **Correct Answer:** A. Amazon VPC, B. AWS IAM
#
# 42. **(Select 3 apply)** Which AWS services can be used to monitor and analyze the performance of your AWS resources?
#     A. Amazon CloudWatch
#     B. AWS CodeBuild
#     C. AWS CodeDeploy
#     D. Amazon CloudTrail
#     **Correct Answer:** A. Amazon CloudWatch, C. AWS CodeDeploy, D. Amazon CloudTrail
#
# 43. **(Select 2 apply)** Which AWS services can be used to manage and automate your application deployments?
#     A. AWS CodeDeploy
#     B. AWS CodeBuild
#     C. AWS CodePipeline
#     D. AWS CodeStar
#     **Correct Answer:** A. AWS CodeDeploy, C. AWS CodePipeline
#
# 44. **(Select 3 apply)** Which AWS services can be used to manage and secure access to your AWS resources?
#     A. AWS IAM
#     B. Amazon Cognito
#     C. AWS Organizations
#     D. Amazon CloudTrail
#     **Correct Answer:** A. AWS IAM, B. Amazon Cognito, C. AWS Organizations
#
# 45. **(Select 2 apply)** Which AWS services can be used to collect and analyze security events from your AWS environment?
#     A. Amazon CloudWatch
#     B. Amazon CloudTrail
#     C. AWS Config
#     D. AWS Security Hub
#     **Correct Answer:** B. Amazon CloudTrail, D. AWS Security Hub
#
# 46. **(Select 2 apply)** Which AWS services can be used to manage and configure your AWS environment?
#     A. AWS Config
#     B. Amazon CloudTrail
#     C. Amazon CloudWatch
#     D. AWS Security Hub
#     **Correct Answer:** A. AWS Config, B. Amazon CloudTrail
#
# 47. **(Select 3 apply)** Which AWS services can be used to build and deploy applications in the cloud?
#     A. Amazon EC2
#     B. Amazon Elastic Beanstalk
#     C. Amazon ECS
#     D. AWS Lambda
#     **Correct Answer:** A. Amazon EC2, B. Amazon Elastic Beanstalk, C. Amazon ECS
#
# 48. **(Select 2 apply)** Which AWS services can be used to create and manage databases in the cloud?
#     A. Amazon RDS
#     B. Amazon DynamoDB
#     C. Amazon Redshift
#     D. Amazon ElastiCache
#     **Correct Answer:** A. Amazon RDS, B. Amazon DynamoDB
#
# 49. **(Select 3 apply)** Which AWS services can be used to manage and secure your data in the cloud?
#     A. AWS KMS
#     B. Amazon S3
#     C. Amazon CloudTrail
#     D. AWS Security Hub
#     **Correct Answer:** A. AWS KMS, B. Amazon S3, D. AWS Security Hub
#
# 50. **(Select 3 apply)** Which AWS services can be used to build and deploy serverless applications?
#     A. AWS Lambda
#     B. Amazon API Gateway
#     C. Amazon S3
#     D. Amazon DynamoDB
#     **Correct Answer:** A. AWS Lambda, B. Amazon API Gateway, D. Amazon DynamoDB

# %%
# Read generated text as lines
buf = io.StringIO(prompt)
lines = buf.readlines()

# Extract topic
topic_line = [line for line in lines if '- Topic: ' in line][0]
topic = topic_line[9:].rstrip('\n.')
topic = re.sub(' ', '_', topic.lower())
print('Topic:', topic)

# Extract difficulty
difficulty_line = [line for line in lines if '- Difficulty: ' in line][0]
difficulty = difficulty_line[14:].rstrip('\n.').lower()
print('Difficulty:', difficulty)

# Extract size
size_line = [line for line in lines if '- Total questions: ' in line][0]
size = size_line[19:].rstrip('\n.')
print('Size:', size)

# Combine topic, difficulty and size into .txt file name
file_name = f'{topic}_{difficulty}_{size}.txt'
print('File name:', file_name)
# Out:
# Topic: aws
# Difficulty: hard
# Size: 50
# File name: aws_hard_50.txt

# %%
# Assign file_name to a constant using for writing to GCS
WRITE_BLOB = file_name

gcs_write(BUCKET, WRITE_BLOB, generate_text)

# %%
# Assign file_name to a constant using for reading from GCS
READ_BLOB = file_name

# Read data as lines
data = gcs_read(BUCKET, READ_BLOB)

# Use display() because data is already list of lines structure
display(data)
# Out:
# ['## True/False\n',
#  '\n',
#  '1.  **True/False:**  A single AWS account can be used to create multiple AWS Organizations.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '2. **True/False:**  Amazon S3 Standard-Infrequent Access (S3 Standard-IA) is a storage class for data that is accessed frequently, but not immediately.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '3. **True/False:**  Amazon CloudFront can be used to distribute static content, but not dynamic content.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '4. **True/False:**  Amazon VPC allows you to create a private network within AWS, but it does not support IPv6 addressing.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '5. **True/False:**  AWS Lambda functions can be triggered by events from multiple AWS services, including S3, DynamoDB, and API Gateway.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '6. **True/False:**  Amazon Elastic Beanstalk supports deployment of applications built with a variety of frameworks, including Java, Python, and .NET.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '7. **True/False:**  AWS IAM roles can be used to grant permissions to users, but not to other AWS services.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '8. **True/False:**  Amazon EC2 Auto Scaling groups can be configured to automatically scale based on metrics like CPU utilization and network traffic.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '9. **True/False:**  Amazon Redshift is a fully managed, petabyte-scale data warehouse service, optimized for analytical workloads.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '10. **True/False:**  Amazon Route 53 can be used to create and manage DNS records for applications running on AWS, but not for applications running outside of AWS.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '11. **True/False:**  Amazon CloudWatch can be used to monitor AWS resources and applications, but not to collect and analyze logs.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '12. **True/False:**  AWS CodePipeline allows you to automate the build, test, and deployment of applications, but it does not support integration with third-party tools.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '13. **True/False:**  Amazon Cognito can be used to authenticate and authorize users for web and mobile applications.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '14. **True/False:**  AWS Kinesis is a real-time data streaming service that can be used to process large volumes of data, but it does not support integration with third-party applications.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '15. **True/False:**  Amazon ElastiCache can be used to improve the performance of applications that require low-latency access to data.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '16. **True/False:**  AWS Step Functions is a serverless orchestration service that can be used to define and execute workflows.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '17. **True/False:**  Amazon DynamoDB is a fully managed, NoSQL database service that supports both document and key-value data models.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '18. **True/False:**  AWS Direct Connect allows you to establish a dedicated, private connection between your on-premises network and AWS.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** A. True\n',
#  '\n',
#  '19. **True/False:**  Amazon CloudTrail can be used to record and monitor API calls made to AWS, but it does not support integration with third-party logging systems.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '20. **True/False:**  AWS Security Hub provides a centralized view of security alerts across your AWS accounts, but it does not support integration with third-party security tools.\n',
#  '    A. True\n',
#  '    B. False\n',
#  '    **Correct Answer:** B. False\n',
#  '\n',
#  '## Single Correct Answer\n',
#  '\n',
#  '21. Which AWS service is a fully managed, serverless data warehousing service optimized for analytics?\n',
#  '    A. Amazon DynamoDB\n',
#  '    B. Amazon Redshift\n',
#  '    C. Amazon ElastiCache\n',
#  '    D. Amazon S3\n',
#  '    **Correct Answer:** B. Amazon Redshift\n',
#  '\n',
#  '22. Which AWS service provides a managed, highly scalable message queuing service?\n',
#  '    A. Amazon SQS\n',
#  '    B. Amazon SNS\n',
#  '    C. Amazon Kinesis\n',
#  '    D. Amazon CloudFront\n',
#  '    **Correct Answer:** A. Amazon SQS\n',
#  '\n',
#  '23. Which AWS service allows you to create and manage DNS records for your applications?\n',
#  '    A. Amazon Route 53\n',
#  '    B. Amazon CloudFront\n',
#  '    C. Amazon S3\n',
#  '    D. Amazon EC2\n',
#  '    **Correct Answer:** A. Amazon Route 53\n',
#  '\n',
#  '24. Which AWS service allows you to build and deploy containerized applications?\n',
#  '    A. Amazon Elastic Beanstalk\n',
#  '    B. Amazon ECS\n',
#  '    C. Amazon EKS\n',
#  '    D. AWS Lambda\n',
#  '    **Correct Answer:** B. Amazon ECS\n',
#  '\n',
#  '25. Which AWS service provides a managed, serverless database service that supports both document and key-value data models?\n',
#  '    A. Amazon DynamoDB\n',
#  '    B. Amazon RDS\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon ElastiCache\n',
#  '    **Correct Answer:** A. Amazon DynamoDB\n',
#  '\n',
#  '26. Which AWS service provides a fully managed, serverless service for running code in response to events?\n',
#  '    A. Amazon EC2\n',
#  '    B. AWS Lambda\n',
#  '    C. Amazon ECS\n',
#  '    D. Amazon Elastic Beanstalk\n',
#  '    **Correct Answer:** B. AWS Lambda\n',
#  '\n',
#  '27. Which AWS service allows you to create and manage virtual private clouds within AWS?\n',
#  '    A. Amazon S3\n',
#  '    B. Amazon Route 53\n',
#  '    C. Amazon VPC\n',
#  '    D. Amazon EC2\n',
#  '    **Correct Answer:** C. Amazon VPC\n',
#  '\n',
#  '28. Which AWS service allows you to create and manage user identities and permissions for accessing AWS resources?\n',
#  '    A. AWS IAM\n',
#  '    B. Amazon Cognito\n',
#  '    C. AWS Organizations\n',
#  '    D. Amazon CloudTrail\n',
#  '    **Correct Answer:** A. AWS IAM\n',
#  '\n',
#  '29. Which AWS service provides a managed service for managing and monitoring infrastructure changes in your AWS environment?\n',
#  '    A. Amazon CloudTrail\n',
#  '    B. AWS Config\n',
#  '    C. Amazon CloudWatch\n',
#  '    D. AWS Security Hub\n',
#  '    **Correct Answer:** B. AWS Config\n',
#  '\n',
#  '30. Which AWS service allows you to create and manage load balancers for your applications?\n',
#  '    A. Amazon Elastic Load Balancing\n',
#  '    B. Amazon Route 53\n',
#  '    C. Amazon CloudFront\n',
#  '    D. Amazon S3\n',
#  '    **Correct Answer:** A. Amazon Elastic Load Balancing\n',
#  '\n',
#  '31. Which AWS service allows you to encrypt data at rest and in transit?\n',
#  '    A. AWS KMS\n',
#  '    B. AWS IAM\n',
#  '    C. Amazon CloudTrail\n',
#  '    D. AWS Config\n',
#  '    **Correct Answer:** A. AWS KMS\n',
#  '\n',
#  '32. Which AWS service provides a fully managed, serverless service for processing streaming data in real-time?\n',
#  '    A. Amazon SQS\n',
#  '    B. Amazon Kinesis\n',
#  '    C. Amazon SNS\n',
#  '    D. Amazon DynamoDB\n',
#  '    **Correct Answer:** B. Amazon Kinesis\n',
#  '\n',
#  '33. Which AWS service provides a managed, in-memory caching service?\n',
#  '    A. Amazon ElastiCache\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon S3\n',
#  '    **Correct Answer:** A. Amazon ElastiCache\n',
#  '\n',
#  '34. Which AWS service provides a managed service for running and managing containers in the cloud?\n',
#  '    A. Amazon ECS\n',
#  '    B. AWS Lambda\n',
#  '    C. Amazon EC2\n',
#  '    D. Amazon Elastic Beanstalk\n',
#  '    **Correct Answer:** A. Amazon ECS\n',
#  '\n',
#  '35. Which AWS service provides a managed service for deploying and managing Kubernetes clusters in the cloud?\n',
#  '    A. Amazon EKS\n',
#  '    B. Amazon ECS\n',
#  '    C. Amazon EC2\n',
#  '    D. AWS Lambda\n',
#  '    **Correct Answer:** A. Amazon EKS\n',
#  '\n',
#  '36. Which AWS service allows you to create and manage highly available, fault-tolerant applications in the cloud?\n',
#  '    A. Amazon Elastic Beanstalk\n',
#  '    B. Amazon ECS\n',
#  '    C. Amazon EKS\n',
#  '    D. AWS Lambda\n',
#  '    **Correct Answer:** A. Amazon Elastic Beanstalk\n',
#  '\n',
#  '37. Which AWS service provides a managed service for managing and automating your software development lifecycle?\n',
#  '    A. AWS CodePipeline\n',
#  '    B. AWS CodeDeploy\n',
#  '    C. AWS CodeBuild\n',
#  '    D. AWS CodeStar\n',
#  '    **Correct Answer:** D. AWS CodeStar\n',
#  '\n',
#  '38. Which AWS service provides a managed service for managing and automating your application deployments?\n',
#  '    A. AWS CodeDeploy\n',
#  '    B. AWS CodePipeline\n',
#  '    C. AWS CodeBuild\n',
#  '    D. AWS CodeStar\n',
#  '    **Correct Answer:** A. AWS CodeDeploy\n',
#  '\n',
#  '39. Which AWS service provides a managed service for building and testing your application code?\n',
#  '    A. AWS CodeBuild\n',
#  '    B. AWS CodePipeline\n',
#  '    C. AWS CodeDeploy\n',
#  '    D. AWS CodeStar\n',
#  '    **Correct Answer:** A. AWS CodeBuild\n',
#  '\n',
#  '40. Which AWS service provides a managed service for collecting, processing, and analyzing log data from your AWS resources?\n',
#  '    A. Amazon CloudWatch\n',
#  '    B. Amazon CloudTrail\n',
#  '    C. AWS Config\n',
#  '    D. AWS Security Hub\n',
#  '    **Correct Answer:** A. Amazon CloudWatch\n',
#  '\n',
#  '## Multiple Correct Answers\n',
#  '\n',
#  '41. **(Select 2 apply)** Which AWS services can be used to create and manage security groups for your VPC?\n',
#  '    A. Amazon VPC\n',
#  '    B. AWS IAM\n',
#  '    C. Amazon CloudTrail\n',
#  '    D. AWS Security Hub\n',
#  '    **Correct Answer:** A. Amazon VPC, B. AWS IAM\n',
#  '\n',
#  '42. **(Select 3 apply)** Which AWS services can be used to monitor and analyze the performance of your AWS resources?\n',
#  '    A. Amazon CloudWatch\n',
#  '    B. AWS CodeBuild\n',
#  '    C. AWS CodeDeploy\n',
#  '    D. Amazon CloudTrail\n',
#  '    **Correct Answer:** A. Amazon CloudWatch, C. AWS CodeDeploy, D. Amazon CloudTrail\n',
#  '\n',
#  '43. **(Select 2 apply)** Which AWS services can be used to manage and automate your application deployments?\n',
#  '    A. AWS CodeDeploy\n',
#  '    B. AWS CodeBuild\n',
#  '    C. AWS CodePipeline\n',
#  '    D. AWS CodeStar\n',
#  '    **Correct Answer:** A. AWS CodeDeploy, C. AWS CodePipeline\n',
#  '\n',
#  '44. **(Select 3 apply)** Which AWS services can be used to manage and secure access to your AWS resources?\n',
#  '    A. AWS IAM\n',
#  '    B. Amazon Cognito\n',
#  '    C. AWS Organizations\n',
#  '    D. Amazon CloudTrail\n',
#  '    **Correct Answer:** A. AWS IAM, B. Amazon Cognito, C. AWS Organizations\n',
#  '\n',
#  '45. **(Select 2 apply)** Which AWS services can be used to collect and analyze security events from your AWS environment?\n',
#  '    A. Amazon CloudWatch\n',
#  '    B. Amazon CloudTrail\n',
#  '    C. AWS Config\n',
#  '    D. AWS Security Hub\n',
#  '    **Correct Answer:** B. Amazon CloudTrail, D. AWS Security Hub\n',
#  '\n',
#  '46. **(Select 2 apply)** Which AWS services can be used to manage and configure your AWS environment?\n',
#  '    A. AWS Config\n',
#  '    B. Amazon CloudTrail\n',
#  '    C. Amazon CloudWatch\n',
#  '    D. AWS Security Hub\n',
#  '    **Correct Answer:** A. AWS Config, B. Amazon CloudTrail\n',
#  '\n',
#  '47. **(Select 3 apply)** Which AWS services can be used to build and deploy applications in the cloud?\n',
#  '    A. Amazon EC2\n',
#  '    B. Amazon Elastic Beanstalk\n',
#  '    C. Amazon ECS\n',
#  '    D. AWS Lambda\n',
#  '    **Correct Answer:** A. Amazon EC2, B. Amazon Elastic Beanstalk, C. Amazon ECS\n',
#  '\n',
#  '48. **(Select 2 apply)** Which AWS services can be used to create and manage databases in the cloud?\n',
#  '    A. Amazon RDS\n',
#  '    B. Amazon DynamoDB\n',
#  '    C. Amazon Redshift\n',
#  '    D. Amazon ElastiCache\n',
#  '    **Correct Answer:** A. Amazon RDS, B. Amazon DynamoDB\n',
#  '\n',
#  '49. **(Select 3 apply)** Which AWS services can be used to manage and secure your data in the cloud?\n',
#  '    A. AWS KMS\n',
#  '    B. Amazon S3\n',
#  '    C. Amazon CloudTrail\n',
#  '    D. AWS Security Hub\n',
#  '    **Correct Answer:** A. AWS KMS, B. Amazon S3, D. AWS Security Hub\n',
#  '\n',
#  '50. **(Select 3 apply)** Which AWS services can be used to build and deploy serverless applications?\n',
#  '    A. AWS Lambda\n',
#  '    B. Amazon API Gateway\n',
#  '    C. Amazon S3\n',
#  '    D. Amazon DynamoDB\n',
#  '    **Correct Answer:** A. AWS Lambda, B. Amazon API Gateway, D. Amazon DynamoDB']

# %%
def split_qa(lines_data):
    """
    Accepts list of lines.
    Returns a dictionary with keys `question` and `answer`
    """
    dict_data = {'question': [],
                 'answer': []}
    
    # Switch determines if the last line is in question section or not
    q_prev = False
    
    for line in lines_data:
        
        # Strip '**' style around 'Correct answer(s)' or 'Correct'
        line = line.replace('**', '')
        
        # Check if line is not blank, title or heading ('##')
        if (line != '\n') and ('##' not in line):
            
            # Call the first word of the line is `head`
            head = line.split()[0]
            
            # Append new question if all of these meet:
            # - Previous line is not in question text
            # - First character of `head` is numeric
            # - Last character of `head` is '.'
            if (not q_prev) and head[0].isnumeric() and head[-1] == ".":
                dict_data['question'].append(line)
                q_prev = True
    
            # Append new answer if all of these meet:
            # - Previous line is in question text
            # - `head` is 'A.'
            elif q_prev and head == 'A.':
                dict_data['answer'].append(line)
                q_prev = False
    
            # Add line to unfinished question
            elif q_prev:
                dict_data['question'][-1] += line
        
            # Add line to unfinished answer
            else:
                dict_data['answer'][-1] += line
    
    return dict_data

# %%
# Return split_qa result to a variable
dict0 = split_qa(data)

# Convert `dict0` to a DataFrame
df0 = pd.DataFrame(dict0)

print('Number of questions:', len(df0))
print('Columns:', df0.columns.values)
# Out:
# Number of questions: 50
# Columns: ['question' 'answer']

# %%
# View some rows
df0.iloc[15:60]
# Out:
#                                              question  \
# 15  16. True/False:  AWS Step Functions is a serve...
# 16  17. True/False:  Amazon DynamoDB is a fully ma...
# 17  18. True/False:  AWS Direct Connect allows you...
# 18  19. True/False:  Amazon CloudTrail can be used...
# 19  20. True/False:  AWS Security Hub provides a c...
# 20  21. Which AWS service is a fully managed, serv...
# 21  22. Which AWS service provides a managed, high...
# 22  23. Which AWS service allows you to create and...
# 23  24. Which AWS service allows you to build and ...
# 24  25. Which AWS service provides a managed, serv...
# 25  26. Which AWS service provides a fully managed...
# 26  27. Which AWS service allows you to create and...
# 27  28. Which AWS service allows you to create and...
# 28  29. Which AWS service provides a managed servi...
# 29  30. Which AWS service allows you to create and...
# 30  31. Which AWS service allows you to encrypt da...
# 31  32. Which AWS service provides a fully managed...
# 32  33. Which AWS service provides a managed, in-m...
# 33  34. Which AWS service provides a managed servi...
# 34  35. Which AWS service provides a managed servi...
# 35  36. Which AWS service allows you to create and...
# 36  37. Which AWS service provides a managed servi...
# 37  38. Which AWS service provides a managed servi...
# 38  39. Which AWS service provides a managed servi...
# 39  40. Which AWS service provides a managed servi...
# 40  41. (Select 2 apply) Which AWS services can be...
# 41  42. (Select 3 apply) Which AWS services can be...
# 42  43. (Select 2 apply) Which AWS services can be...
# 43  44. (Select 3 apply) Which AWS services can be...
# 44  45. (Select 2 apply) Which AWS services can be...
# 45  46. (Select 2 apply) Which AWS services can be...
# 46  47. (Select 3 apply) Which AWS services can be...
# 47  48. (Select 2 apply) Which AWS services can be...
# 48  49. (Select 3 apply) Which AWS services can be...
# 49  50. (Select 3 apply) Which AWS services can be...
#
#                                                answer
# 15      A. True\n    B. False\n    Correct Answer:...
# 16      A. True\n    B. False\n    Correct Answer:...
# 17      A. True\n    B. False\n    Correct Answer:...
# 18      A. True\n    B. False\n    Correct Answer:...
# 19      A. True\n    B. False\n    Correct Answer:...
# 20      A. Amazon DynamoDB\n    B. Amazon Redshift...
# 21      A. Amazon SQS\n    B. Amazon SNS\n    C. A...
# 22      A. Amazon Route 53\n    B. Amazon CloudFro...
# 23      A. Amazon Elastic Beanstalk\n    B. Amazon...
# 24      A. Amazon DynamoDB\n    B. Amazon RDS\n   ...
# 25      A. Amazon EC2\n    B. AWS Lambda\n    C. A...
# 26      A. Amazon S3\n    B. Amazon Route 53\n    ...
# 27      A. AWS IAM\n    B. Amazon Cognito\n    C. ...
# 28      A. Amazon CloudTrail\n    B. AWS Config\n ...
# 29      A. Amazon Elastic Load Balancing\n    B. A...
# 30      A. AWS KMS\n    B. AWS IAM\n    C. Amazon ...
# 31      A. Amazon SQS\n    B. Amazon Kinesis\n    ...
# 32      A. Amazon ElastiCache\n    B. Amazon Dynam...
# 33      A. Amazon ECS\n    B. AWS Lambda\n    C. A...
# 34      A. Amazon EKS\n    B. Amazon ECS\n    C. A...
# 35      A. Amazon Elastic Beanstalk\n    B. Amazon...
# 36      A. AWS CodePipeline\n    B. AWS CodeDeploy...
# 37      A. AWS CodeDeploy\n    B. AWS CodePipeline...
# 38      A. AWS CodeBuild\n    B. AWS CodePipeline\...
# 39      A. Amazon CloudWatch\n    B. Amazon CloudT...
# 40      A. Amazon VPC\n    B. AWS IAM\n    C. Amaz...
# 41      A. Amazon CloudWatch\n    B. AWS CodeBuild...
# 42      A. AWS CodeDeploy\n    B. AWS CodeBuild\n ...
# 43      A. AWS IAM\n    B. Amazon Cognito\n    C. ...
# 44      A. Amazon CloudWatch\n    B. Amazon CloudT...
# 45      A. AWS Config\n    B. Amazon CloudTrail\n ...
# 46      A. Amazon EC2\n    B. Amazon Elastic Beans...
# 47      A. Amazon RDS\n    B. Amazon DynamoDB\n   ...
# 48      A. AWS KMS\n    B. Amazon S3\n    C. Amazo...
# 49      A. AWS Lambda\n    B. Amazon API Gateway\n...

# %%
# Make a copy of df0
df1 = df0.copy()

# %%
# Strip the number at the beginning and '\n' at the end of each question 
df1['question'] = df1['question'].str.replace(r'^\d{0,4}\.[ ]', '', regex=True).str.rstrip()

# %%
df1
# Out:
#                                              question  \
# 0    True/False:  A single AWS account can be used...
# 1   True/False:  Amazon S3 Standard-Infrequent Acc...
# 2   True/False:  Amazon CloudFront can be used to ...
# 3   True/False:  Amazon VPC allows you to create a...
# 4   True/False:  AWS Lambda functions can be trigg...
# 5   True/False:  Amazon Elastic Beanstalk supports...
# 6   True/False:  AWS IAM roles can be used to gran...
# 7   True/False:  Amazon EC2 Auto Scaling groups ca...
# 8   True/False:  Amazon Redshift is a fully manage...
# 9   True/False:  Amazon Route 53 can be used to cr...
# 10  True/False:  Amazon CloudWatch can be used to ...
# 11  True/False:  AWS CodePipeline allows you to au...
# 12  True/False:  Amazon Cognito can be used to aut...
# 13  True/False:  AWS Kinesis is a real-time data s...
# 14  True/False:  Amazon ElastiCache can be used to...
# 15  True/False:  AWS Step Functions is a serverles...
# 16  True/False:  Amazon DynamoDB is a fully manage...
# 17  True/False:  AWS Direct Connect allows you to ...
# 18  True/False:  Amazon CloudTrail can be used to ...
# 19  True/False:  AWS Security Hub provides a centr...
# 20  Which AWS service is a fully managed, serverle...
# 21  Which AWS service provides a managed, highly s...
# 22  Which AWS service allows you to create and man...
# 23  Which AWS service allows you to build and depl...
# 24  Which AWS service provides a managed, serverle...
# 25  Which AWS service provides a fully managed, se...
# 26  Which AWS service allows you to create and man...
# 27  Which AWS service allows you to create and man...
# 28  Which AWS service provides a managed service f...
# 29  Which AWS service allows you to create and man...
# 30  Which AWS service allows you to encrypt data a...
# 31  Which AWS service provides a fully managed, se...
# 32  Which AWS service provides a managed, in-memor...
# 33  Which AWS service provides a managed service f...
# 34  Which AWS service provides a managed service f...
# 35  Which AWS service allows you to create and man...
# 36  Which AWS service provides a managed service f...
# 37  Which AWS service provides a managed service f...
# 38  Which AWS service provides a managed service f...
# 39  Which AWS service provides a managed service f...
# 40  (Select 2 apply) Which AWS services can be use...
# 41  (Select 3 apply) Which AWS services can be use...
# 42  (Select 2 apply) Which AWS services can be use...
# 43  (Select 3 apply) Which AWS services can be use...
# 44  (Select 2 apply) Which AWS services can be use...
# 45  (Select 2 apply) Which AWS services can be use...
# 46  (Select 3 apply) Which AWS services can be use...
# 47  (Select 2 apply) Which AWS services can be use...
# 48  (Select 3 apply) Which AWS services can be use...
# 49  (Select 3 apply) Which AWS services can be use...
#
#                                                answer
# 0       A. True\n    B. False\n    Correct Answer:...
# 1       A. True\n    B. False\n    Correct Answer:...
# 2       A. True\n    B. False\n    Correct Answer:...
# 3       A. True\n    B. False\n    Correct Answer:...
# 4       A. True\n    B. False\n    Correct Answer:...
# 5       A. True\n    B. False\n    Correct Answer:...
# 6       A. True\n    B. False\n    Correct Answer:...
# 7       A. True\n    B. False\n    Correct Answer:...
# 8       A. True\n    B. False\n    Correct Answer:...
# 9       A. True\n    B. False\n    Correct Answer:...
# 10      A. True\n    B. False\n    Correct Answer:...
# 11      A. True\n    B. False\n    Correct Answer:...
# 12      A. True\n    B. False\n    Correct Answer:...
# 13      A. True\n    B. False\n    Correct Answer:...
# 14      A. True\n    B. False\n    Correct Answer:...
# 15      A. True\n    B. False\n    Correct Answer:...
# 16      A. True\n    B. False\n    Correct Answer:...
# 17      A. True\n    B. False\n    Correct Answer:...
# 18      A. True\n    B. False\n    Correct Answer:...
# 19      A. True\n    B. False\n    Correct Answer:...
# 20      A. Amazon DynamoDB\n    B. Amazon Redshift...
# 21      A. Amazon SQS\n    B. Amazon SNS\n    C. A...
# 22      A. Amazon Route 53\n    B. Amazon CloudFro...
# 23      A. Amazon Elastic Beanstalk\n    B. Amazon...
# 24      A. Amazon DynamoDB\n    B. Amazon RDS\n   ...
# 25      A. Amazon EC2\n    B. AWS Lambda\n    C. A...
# 26      A. Amazon S3\n    B. Amazon Route 53\n    ...
# 27      A. AWS IAM\n    B. Amazon Cognito\n    C. ...
# 28      A. Amazon CloudTrail\n    B. AWS Config\n ...
# 29      A. Amazon Elastic Load Balancing\n    B. A...
# 30      A. AWS KMS\n    B. AWS IAM\n    C. Amazon ...
# 31      A. Amazon SQS\n    B. Amazon Kinesis\n    ...
# 32      A. Amazon ElastiCache\n    B. Amazon Dynam...
# 33      A. Amazon ECS\n    B. AWS Lambda\n    C. A...
# 34      A. Amazon EKS\n    B. Amazon ECS\n    C. A...
# 35      A. Amazon Elastic Beanstalk\n    B. Amazon...
# 36      A. AWS CodePipeline\n    B. AWS CodeDeploy...
# 37      A. AWS CodeDeploy\n    B. AWS CodePipeline...
# 38      A. AWS CodeBuild\n    B. AWS CodePipeline\...
# 39      A. Amazon CloudWatch\n    B. Amazon CloudT...
# 40      A. Amazon VPC\n    B. AWS IAM\n    C. Amaz...
# 41      A. Amazon CloudWatch\n    B. AWS CodeBuild...
# 42      A. AWS CodeDeploy\n    B. AWS CodeBuild\n ...
# 43      A. AWS IAM\n    B. Amazon Cognito\n    C. ...
# 44      A. Amazon CloudWatch\n    B. Amazon CloudT...
# 45      A. AWS Config\n    B. Amazon CloudTrail\n ...
# 46      A. Amazon EC2\n    B. Amazon Elastic Beans...
# 47      A. Amazon RDS\n    B. Amazon DynamoDB\n   ...
# 48      A. AWS KMS\n    B. Amazon S3\n    C. Amazo...
# 49      A. AWS Lambda\n    B. Amazon API Gateway\n...

# %%
def convert_index(capital):
    """Return zero-based index from capital, 'A' has unicode code as 65"""
    return ord(capital) - 65

def split_choice(answer):
    """
    Split the `answer` data into multiple choices
    """
    # print(answer)
    
    # Use 'Correct Answer(s): ' to split text.
    # Index 0 is all choices, index 1 is all answers
    if 'Correct Answer' in answer:
        split_all = re.split(r'Correct Answer[s]*: ', answer)
    else:
        split_all = re.split('Correct: ', answer)
    # print("After strip 'Correct Answer(s): ' or 'Correct: ':", split_all)
    
    choices = split_all[0]
    # print('Choices text:', choices)
    
    correct_stack = split_all[1]
    # print('Correct stack:', correct_stack)
    
    # Split using ','
    correct_stack = correct_stack.split(',')
    
    # Pick only first capital indicating the choices
    correct_note = [item.strip()[0] for item in correct_stack]
    # print('Correct note:', correct_note)
    
    # Make zero-based index from alphabet
    correct_index = [convert_index(item) for item in correct_note]
    # print('Correct index', correct_index)
    
    # Split using 'X. ', index 0 is '', so pass
    choices = re.split(r'[A-Z]\.[ ]', choices)[1:]
    # Strip right side of choice text
    choices = [choice.rstrip() for choice in choices]
    # print('All choices in list: ', choices)
    
    # Separate choices into lists as `incorrect` and `correct`
    incorrect = [choice for index, choice in enumerate(choices) if index not in correct_index]
    # print('Incorrect in list: ', incorrect)
    correct = [choice for index, choice in enumerate(choices) if index in correct_index]
    # print('Correct in list: ', correct)
    
    return {'incorrect': incorrect,
            'correct': correct}

# %%
# Make a copy of `df1`
df2 = df1.copy()

# %%
# Test the function with sub set of data
df_test = df2.iloc[20:22]['answer'].apply(split_choice)

# %%
# Print out to preview results
display(df_test.str['incorrect'])
df_test.str['correct']
# Out:
# 20    [Amazon DynamoDB, Amazon ElastiCache, Amazon S3]
# 21     [Amazon SNS, Amazon Kinesis, Amazon CloudFront]
# Name: answer, dtype: object
# 20    [Amazon Redshift]
# 21         [Amazon SQS]
# Name: answer, dtype: object

# %%
# Apply the function to full dataset
df2['incorrect'] = df2['answer'].apply(split_choice).str['incorrect']
df2['correct'] = df2['answer'].apply(split_choice).str['correct']

# %%
# Preview a row
display(df2.loc[40, 'incorrect'])
display(df2.loc[40, 'correct'])
# Out:
# ['Amazon CloudTrail', 'AWS Security Hub']
# ['Amazon VPC', 'AWS IAM']

# %%
# New order of columns
new_order = ['question', 'incorrect', 'correct']

# Make a copy of `df2` with new order of columns
df_clean = df2[new_order].copy()

# Preview data in a row
display(df_clean['incorrect'][45])
display(df_clean['correct'][45])
df_clean.iloc[45]
# Out:
# ['Amazon CloudWatch', 'AWS Security Hub']
# ['AWS Config', 'Amazon CloudTrail']
# question     (Select 2 apply) Which AWS services can be use...
# incorrect                [Amazon CloudWatch, AWS Security Hub]
# correct                        [AWS Config, Amazon CloudTrail]
# Name: 45, dtype: object

# %%
# Preview the whole final table
df_clean
# Out:
#                                              question  \
# 0    True/False:  A single AWS account can be used...
# 1   True/False:  Amazon S3 Standard-Infrequent Acc...
# 2   True/False:  Amazon CloudFront can be used to ...
# 3   True/False:  Amazon VPC allows you to create a...
# 4   True/False:  AWS Lambda functions can be trigg...
# 5   True/False:  Amazon Elastic Beanstalk supports...
# 6   True/False:  AWS IAM roles can be used to gran...
# 7   True/False:  Amazon EC2 Auto Scaling groups ca...
# 8   True/False:  Amazon Redshift is a fully manage...
# 9   True/False:  Amazon Route 53 can be used to cr...
# 10  True/False:  Amazon CloudWatch can be used to ...
# 11  True/False:  AWS CodePipeline allows you to au...
# 12  True/False:  Amazon Cognito can be used to aut...
# 13  True/False:  AWS Kinesis is a real-time data s...
# 14  True/False:  Amazon ElastiCache can be used to...
# 15  True/False:  AWS Step Functions is a serverles...
# 16  True/False:  Amazon DynamoDB is a fully manage...
# 17  True/False:  AWS Direct Connect allows you to ...
# 18  True/False:  Amazon CloudTrail can be used to ...
# 19  True/False:  AWS Security Hub provides a centr...
# 20  Which AWS service is a fully managed, serverle...
# 21  Which AWS service provides a managed, highly s...
# 22  Which AWS service allows you to create and man...
# 23  Which AWS service allows you to build and depl...
# 24  Which AWS service provides a managed, serverle...
# 25  Which AWS service provides a fully managed, se...
# 26  Which AWS service allows you to create and man...
# 27  Which AWS service allows you to create and man...
# 28  Which AWS service provides a managed service f...
# 29  Which AWS service allows you to create and man...
# 30  Which AWS service allows you to encrypt data a...
# 31  Which AWS service provides a fully managed, se...
# 32  Which AWS service provides a managed, in-memor...
# 33  Which AWS service provides a managed service f...
# 34  Which AWS service provides a managed service f...
# 35  Which AWS service allows you to create and man...
# 36  Which AWS service provides a managed service f...
# 37  Which AWS service provides a managed service f...
# 38  Which AWS service provides a managed service f...
# 39  Which AWS service provides a managed service f...
# 40  (Select 2 apply) Which AWS services can be use...
# 41  (Select 3 apply) Which AWS services can be use...
# 42  (Select 2 apply) Which AWS services can be use...
# 43  (Select 3 apply) Which AWS services can be use...
# 44  (Select 2 apply) Which AWS services can be use...
# 45  (Select 2 apply) Which AWS services can be use...
# 46  (Select 3 apply) Which AWS services can be use...
# 47  (Select 2 apply) Which AWS services can be use...
# 48  (Select 3 apply) Which AWS services can be use...
# 49  (Select 3 apply) Which AWS services can be use...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                             [False]
# 5                                             [False]
# 6                                              [True]
# 7                                             [False]
# 8                                             [False]
# 9                                              [True]
# 10                                             [True]
# 11                                             [True]
# 12                                            [False]
# 13                                             [True]
# 14                                            [False]
# 15                                            [False]
# 16                                            [False]
# 17                                            [False]
# 18                                             [True]
# 19                                             [True]
# 20   [Amazon DynamoDB, Amazon ElastiCache, Amazon S3]
# 21    [Amazon SNS, Amazon Kinesis, Amazon CloudFront]
# 22         [Amazon CloudFront, Amazon S3, Amazon EC2]
# 23  [Amazon Elastic Beanstalk, Amazon EKS, AWS Lam...
# 24  [Amazon RDS, Amazon Redshift, Amazon ElastiCache]
# 25  [Amazon EC2, Amazon ECS, Amazon Elastic Beanst...
# 26           [Amazon S3, Amazon Route 53, Amazon EC2]
# 27  [Amazon Cognito, AWS Organizations, Amazon Clo...
# 28  [Amazon CloudTrail, Amazon CloudWatch, AWS Sec...
# 29    [Amazon Route 53, Amazon CloudFront, Amazon S3]
# 30           [AWS IAM, Amazon CloudTrail, AWS Config]
# 31          [Amazon SQS, Amazon SNS, Amazon DynamoDB]
# 32      [Amazon DynamoDB, Amazon Redshift, Amazon S3]
# 33  [AWS Lambda, Amazon EC2, Amazon Elastic Beanst...
# 34               [Amazon ECS, Amazon EC2, AWS Lambda]
# 35               [Amazon ECS, Amazon EKS, AWS Lambda]
# 36  [AWS CodePipeline, AWS CodeDeploy, AWS CodeBuild]
# 37    [AWS CodePipeline, AWS CodeBuild, AWS CodeStar]
# 38   [AWS CodePipeline, AWS CodeDeploy, AWS CodeStar]
# 39  [Amazon CloudTrail, AWS Config, AWS Security Hub]
# 40              [Amazon CloudTrail, AWS Security Hub]
# 41                                    [AWS CodeBuild]
# 42                      [AWS CodeBuild, AWS CodeStar]
# 43                                [Amazon CloudTrail]
# 44                    [Amazon CloudWatch, AWS Config]
# 45              [Amazon CloudWatch, AWS Security Hub]
# 46                                       [AWS Lambda]
# 47              [Amazon Redshift, Amazon ElastiCache]
# 48                                [Amazon CloudTrail]
# 49                                        [Amazon S3]
#
#                                               correct
# 0                                             [False]
# 1                                             [False]
# 2                                             [False]
# 3                                             [False]
# 4                                              [True]
# 5                                              [True]
# 6                                             [False]
# 7                                              [True]
# 8                                              [True]
# 9                                             [False]
# 10                                            [False]
# 11                                            [False]
# 12                                             [True]
# 13                                            [False]
# 14                                             [True]
# 15                                             [True]
# 16                                             [True]
# 17                                             [True]
# 18                                            [False]
# 19                                            [False]
# 20                                  [Amazon Redshift]
# 21                                       [Amazon SQS]
# 22                                  [Amazon Route 53]
# 23                                       [Amazon ECS]
# 24                                  [Amazon DynamoDB]
# 25                                       [AWS Lambda]
# 26                                       [Amazon VPC]
# 27                                          [AWS IAM]
# 28                                       [AWS Config]
# 29                    [Amazon Elastic Load Balancing]
# 30                                          [AWS KMS]
# 31                                   [Amazon Kinesis]
# 32                               [Amazon ElastiCache]
# 33                                       [Amazon ECS]
# 34                                       [Amazon EKS]
# 35                         [Amazon Elastic Beanstalk]
# 36                                     [AWS CodeStar]
# 37                                   [AWS CodeDeploy]
# 38                                    [AWS CodeBuild]
# 39                                [Amazon CloudWatch]
# 40                              [Amazon VPC, AWS IAM]
# 41  [Amazon CloudWatch, AWS CodeDeploy, Amazon Clo...
# 42                 [AWS CodeDeploy, AWS CodePipeline]
# 43       [AWS IAM, Amazon Cognito, AWS Organizations]
# 44              [Amazon CloudTrail, AWS Security Hub]
# 45                    [AWS Config, Amazon CloudTrail]
# 46  [Amazon EC2, Amazon Elastic Beanstalk, Amazon ...
# 47                      [Amazon RDS, Amazon DynamoDB]
# 48             [AWS KMS, Amazon S3, AWS Security Hub]
# 49  [AWS Lambda, Amazon API Gateway, Amazon DynamoDB]

# %%
# Pick up the read blob name with '.txt' excluded, to make new json file name
JSON_BLOB = READ_BLOB[:-4] + '.json'

# Convert `df_clean` to JSON string
export_json_string = df_clean.to_json()

# %%
# Write JSON string to GCS object as a JSON file
gcs_write(BUCKET, JSON_BLOB, export_json_string)

# %%
# Read just exported JSON file for testing purpose
read_json_string = gcs_read(BUCKET, JSON_BLOB, j_load=True)

# Convert to DataFrame
df_json = pd.DataFrame(read_json_string)

# %%
# Preview json file data as DataFrame
df_json
# Out:
#                                              question  \
# 0    True/False:  A single AWS account can be used...
# 1   True/False:  Amazon S3 Standard-Infrequent Acc...
# 2   True/False:  Amazon CloudFront can be used to ...
# 3   True/False:  Amazon VPC allows you to create a...
# 4   True/False:  AWS Lambda functions can be trigg...
# 5   True/False:  Amazon Elastic Beanstalk supports...
# 6   True/False:  AWS IAM roles can be used to gran...
# 7   True/False:  Amazon EC2 Auto Scaling groups ca...
# 8   True/False:  Amazon Redshift is a fully manage...
# 9   True/False:  Amazon Route 53 can be used to cr...
# 10  True/False:  Amazon CloudWatch can be used to ...
# 11  True/False:  AWS CodePipeline allows you to au...
# 12  True/False:  Amazon Cognito can be used to aut...
# 13  True/False:  AWS Kinesis is a real-time data s...
# 14  True/False:  Amazon ElastiCache can be used to...
# 15  True/False:  AWS Step Functions is a serverles...
# 16  True/False:  Amazon DynamoDB is a fully manage...
# 17  True/False:  AWS Direct Connect allows you to ...
# 18  True/False:  Amazon CloudTrail can be used to ...
# 19  True/False:  AWS Security Hub provides a centr...
# 20  Which AWS service is a fully managed, serverle...
# 21  Which AWS service provides a managed, highly s...
# 22  Which AWS service allows you to create and man...
# 23  Which AWS service allows you to build and depl...
# 24  Which AWS service provides a managed, serverle...
# 25  Which AWS service provides a fully managed, se...
# 26  Which AWS service allows you to create and man...
# 27  Which AWS service allows you to create and man...
# 28  Which AWS service provides a managed service f...
# 29  Which AWS service allows you to create and man...
# 30  Which AWS service allows you to encrypt data a...
# 31  Which AWS service provides a fully managed, se...
# 32  Which AWS service provides a managed, in-memor...
# 33  Which AWS service provides a managed service f...
# 34  Which AWS service provides a managed service f...
# 35  Which AWS service allows you to create and man...
# 36  Which AWS service provides a managed service f...
# 37  Which AWS service provides a managed service f...
# 38  Which AWS service provides a managed service f...
# 39  Which AWS service provides a managed service f...
# 40  (Select 2 apply) Which AWS services can be use...
# 41  (Select 3 apply) Which AWS services can be use...
# 42  (Select 2 apply) Which AWS services can be use...
# 43  (Select 3 apply) Which AWS services can be use...
# 44  (Select 2 apply) Which AWS services can be use...
# 45  (Select 2 apply) Which AWS services can be use...
# 46  (Select 3 apply) Which AWS services can be use...
# 47  (Select 2 apply) Which AWS services can be use...
# 48  (Select 3 apply) Which AWS services can be use...
# 49  (Select 3 apply) Which AWS services can be use...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                             [False]
# 5                                             [False]
# 6                                              [True]
# 7                                             [False]
# 8                                             [False]
# 9                                              [True]
# 10                                             [True]
# 11                                             [True]
# 12                                            [False]
# 13                                             [True]
# 14                                            [False]
# 15                                            [False]
# 16                                            [False]
# 17                                            [False]
# 18                                             [True]
# 19                                             [True]
# 20   [Amazon DynamoDB, Amazon ElastiCache, Amazon S3]
# 21    [Amazon SNS, Amazon Kinesis, Amazon CloudFront]
# 22         [Amazon CloudFront, Amazon S3, Amazon EC2]
# 23  [Amazon Elastic Beanstalk, Amazon EKS, AWS Lam...
# 24  [Amazon RDS, Amazon Redshift, Amazon ElastiCache]
# 25  [Amazon EC2, Amazon ECS, Amazon Elastic Beanst...
# 26           [Amazon S3, Amazon Route 53, Amazon EC2]
# 27  [Amazon Cognito, AWS Organizations, Amazon Clo...
# 28  [Amazon CloudTrail, Amazon CloudWatch, AWS Sec...
# 29    [Amazon Route 53, Amazon CloudFront, Amazon S3]
# 30           [AWS IAM, Amazon CloudTrail, AWS Config]
# 31          [Amazon SQS, Amazon SNS, Amazon DynamoDB]
# 32      [Amazon DynamoDB, Amazon Redshift, Amazon S3]
# 33  [AWS Lambda, Amazon EC2, Amazon Elastic Beanst...
# 34               [Amazon ECS, Amazon EC2, AWS Lambda]
# 35               [Amazon ECS, Amazon EKS, AWS Lambda]
# 36  [AWS CodePipeline, AWS CodeDeploy, AWS CodeBuild]
# 37    [AWS CodePipeline, AWS CodeBuild, AWS CodeStar]
# 38   [AWS CodePipeline, AWS CodeDeploy, AWS CodeStar]
# 39  [Amazon CloudTrail, AWS Config, AWS Security Hub]
# 40              [Amazon CloudTrail, AWS Security Hub]
# 41                                    [AWS CodeBuild]
# 42                      [AWS CodeBuild, AWS CodeStar]
# 43                                [Amazon CloudTrail]
# 44                    [Amazon CloudWatch, AWS Config]
# 45              [Amazon CloudWatch, AWS Security Hub]
# 46                                       [AWS Lambda]
# 47              [Amazon Redshift, Amazon ElastiCache]
# 48                                [Amazon CloudTrail]
# 49                                        [Amazon S3]
#
#                                               correct
# 0                                             [False]
# 1                                             [False]
# 2                                             [False]
# 3                                             [False]
# 4                                              [True]
# 5                                              [True]
# 6                                             [False]
# 7                                              [True]
# 8                                              [True]
# 9                                             [False]
# 10                                            [False]
# 11                                            [False]
# 12                                             [True]
# 13                                            [False]
# 14                                             [True]
# 15                                             [True]
# 16                                             [True]
# 17                                             [True]
# 18                                            [False]
# 19                                            [False]
# 20                                  [Amazon Redshift]
# 21                                       [Amazon SQS]
# 22                                  [Amazon Route 53]
# 23                                       [Amazon ECS]
# 24                                  [Amazon DynamoDB]
# 25                                       [AWS Lambda]
# 26                                       [Amazon VPC]
# 27                                          [AWS IAM]
# 28                                       [AWS Config]
# 29                    [Amazon Elastic Load Balancing]
# 30                                          [AWS KMS]
# 31                                   [Amazon Kinesis]
# 32                               [Amazon ElastiCache]
# 33                                       [Amazon ECS]
# 34                                       [Amazon EKS]
# 35                         [Amazon Elastic Beanstalk]
# 36                                     [AWS CodeStar]
# 37                                   [AWS CodeDeploy]
# 38                                    [AWS CodeBuild]
# 39                                [Amazon CloudWatch]
# 40                              [Amazon VPC, AWS IAM]
# 41  [Amazon CloudWatch, AWS CodeDeploy, Amazon Clo...
# 42                 [AWS CodeDeploy, AWS CodePipeline]
# 43       [AWS IAM, Amazon Cognito, AWS Organizations]
# 44              [Amazon CloudTrail, AWS Security Hub]
# 45                    [AWS Config, Amazon CloudTrail]
# 46  [Amazon EC2, Amazon Elastic Beanstalk, Amazon ...
# 47                      [Amazon RDS, Amazon DynamoDB]
# 48             [AWS KMS, Amazon S3, AWS Security Hub]
# 49  [AWS Lambda, Amazon API Gateway, Amazon DynamoDB]

# %%
# Preview index in JSON string to confirm
read_json_string['question']['15']
# Out:
# 'True/False:  AWS Step Functions is a serverless orchestration service that can be used to define and execute workflows.'

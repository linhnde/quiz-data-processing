# %%
# Import general packages
import pandas as pd
import re
import io
import json

# Set environment variable to authenticate GCP credentials
# !export GOOGLE_APPLICATION_CREDENTIALS='book-to-quiz-7558e7ee5aca.json'

LOCATION = "us-central1"
PROJECT = 'book-to-quiz'
BUCKET = 'book-to-quiz-question-bank'
MODEL = "gemini-1.5-flash-001"

# %%
# Imports the Google Cloud client library
from google.cloud import storage

def gcs_read(bucket_name, blob_name, j_load=False):
    """
    Read a blob from GCS using file-like IO.
    Default use readlines() for text file.
    Change `j_load` to True if json.load() is used for reading clean JSON file.
    """
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("r") as file:
        if j_load:
            return json.load(file)
        return file.readlines()
    
def gcs_write(bucket_name, blob_name, content):
    """Write a blob from GCS using file-like IO"""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    with blob.open("w") as file:
        file.write(content)

# %%
# Import Vertex AI packages
import vertexai
from vertexai.generative_models import GenerativeModel
import vertexai.preview.generative_models as generative_models

def generate(p_text, g_config, s_settings):
    """Yield text with generator which receive prompt text, generation config and safety settings as arguments"""
    vertexai.init(project=PROJECT, location=LOCATION)
    model = GenerativeModel(
        MODEL,
    )
    responses = model.generate_content(
        [p_text],
        generation_config=g_config,
        safety_settings=s_settings,
        stream=True,
    )

    for response in responses:
        yield response.text

# %%
prompt = """Generate quiz with these requirements:
- Total questions: 50.
- Topic: AWS.
- Difficulty: Hard.
- Types: true/false, single correct answer, multiple correct answers.
- Indent questions with number.
- Indent choices and true/false with upper letter.
- If more than 2 correct answers questions, remind  \"(select [exact number] apply)\" before choice A.
- In each question, total correct answers is less than total choices.
- Choices consist multiple technically complicated steps.
- Show correct choices at the end of each question.
- No markdown, plain text.
- Group by type."""

generation_config = {
    "max_output_tokens": 8192,
    "temperature": 1,
    "top_p": 0.95,
}

safety_settings = {
    generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

# %%
# Assign generator to a variable
generator = generate(prompt, generation_config, safety_settings)

# %%
# Use string comprehension to gather text from generator
generate_text = ''.join(response for response in generator)

# %%
# Use print() for generate_text for better preview because generated_text is whole string, not list of lines
print(generate_text)
# Out:
# ## True/False
#
# 1. You can use Amazon S3 to store data for a relational database like MySQL.
# A. True
# B. False
# **Correct: B. False**
#
# 2. Amazon EC2 instances can be launched in multiple Availability Zones within a single AWS Region.
# A. True
# B. False
# **Correct: A. True**
#
# 3. Amazon CloudFront can be used to deliver content from Amazon S3 to users around the world with low latency.
# A. True
# B. False
# **Correct: A. True**
#
# 4. Amazon Elastic Beanstalk supports deploying applications built using .NET, PHP, Java, Python, Ruby, Node.js, and Go.
# A. True
# B. False
# **Correct: A. True**
#
# 5. Amazon DynamoDB is a fully managed NoSQL database service that supports both document and key-value data models.
# A. True
# B. False
# **Correct: A. True**
#
# 6. Amazon SQS is a message queuing service that can be used to decouple applications and ensure that messages are delivered reliably.
# A. True
# B. False
# **Correct: A. True**
#
# 7. AWS Lambda is a serverless compute service that allows you to run code without provisioning or managing servers.
# A. True
# B. False
# **Correct: A. True**
#
# 8. Amazon CloudWatch can be used to monitor AWS resources and applications, and trigger actions based on predefined thresholds.
# A. True
# B. False
# **Correct: A. True**
#
# 9. Amazon VPC allows you to create a private network within AWS, isolating your resources from the public internet.
# A. True
# B. False
# **Correct: A. True**
#
# 10. Amazon Route 53 is a DNS service that can be used to route traffic to your AWS resources, including EC2 instances, S3 buckets, and ELB load balancers.
# A. True
# B. False
# **Correct: A. True**
#
# ## Single Correct Answer
#
# 11. Which of the following AWS services can be used to create a fully managed, scalable, and highly available database?
# A. Amazon RDS
# B. Amazon S3
# C. Amazon EC2
# D. Amazon Redshift
# **Correct: A. Amazon RDS**
#
# 12. Which of the following AWS services is a fully managed, serverless compute service that allows you to run code without provisioning or managing servers?
# A. Amazon EC2
# B. Amazon Lambda
# C. Amazon SQS
# D. Amazon DynamoDB
# **Correct: B. Amazon Lambda**
#
# 13. Which of the following AWS services can be used to deliver content to users around the world with low latency?
# A. Amazon S3
# B. Amazon EC2
# C. Amazon CloudFront
# D. Amazon Route 53
# **Correct: C. Amazon CloudFront**
#
# 14. Which of the following AWS services can be used to create a private network within AWS, isolating your resources from the public internet?
# A. Amazon S3
# B. Amazon VPC
# C. Amazon Route 53
# D. Amazon CloudWatch
# **Correct: B. Amazon VPC**
#
# 15. Which of the following AWS services is a managed, NoSQL database service that supports both document and key-value data models?
# A. Amazon RDS
# B. Amazon DynamoDB
# C. Amazon Redshift
# D. Amazon SQS
# **Correct: B. Amazon DynamoDB**
#
# 16. Which of the following AWS services can be used to monitor AWS resources and applications, and trigger actions based on predefined thresholds?
# A. Amazon CloudWatch
# B. Amazon Route 53
# C. Amazon SQS
# D. Amazon EC2
# **Correct: A. Amazon CloudWatch**
#
# 17. Which of the following AWS services can be used to create and manage virtual private clouds (VPCs)?
# A. Amazon EC2
# B. Amazon VPC
# C. Amazon Route 53
# D. Amazon CloudWatch
# **Correct: B. Amazon VPC**
#
# 18. Which of the following AWS services can be used to automate tasks and manage infrastructure using code?
# A. AWS CloudFormation
# B. Amazon EC2
# C. Amazon S3
# D. Amazon DynamoDB
# **Correct: A. AWS CloudFormation**
#
# 19. Which of the following AWS services is a fully managed, serverless data warehouse service?
# A. Amazon RDS
# B. Amazon DynamoDB
# C. Amazon Redshift
# D. Amazon SQS
# **Correct: C. Amazon Redshift**
#
# 20. Which of the following AWS services can be used to create and manage load balancers?
# A. Amazon EC2
# B. Amazon Route 53
# C. Amazon Elastic Load Balancing (ELB)
# D. Amazon CloudFront
# **Correct: C. Amazon Elastic Load Balancing (ELB)**
#
# ## Multiple Correct Answers
#
# 21. (select 2 apply) Which of the following AWS services can be used to store data?
# A. Amazon S3
# B. Amazon EC2
# C. Amazon DynamoDB
# D. Amazon Redshift
# **Correct: A. Amazon S3, C. Amazon DynamoDB**
#
# 22. (select 3 apply) Which of the following AWS services can be used to manage and deploy applications?
# A. Amazon EC2
# B. Amazon Elastic Beanstalk
# C. AWS CloudFormation
# D. Amazon S3
# **Correct: A. Amazon EC2, B. Amazon Elastic Beanstalk, C. AWS CloudFormation**
#
# 23. (select 2 apply) Which of the following AWS services can be used to monitor and manage resources and applications?
# A. Amazon CloudWatch
# B. Amazon Route 53
# C. Amazon SQS
# D. Amazon CloudTrail
# **Correct: A. Amazon CloudWatch, D. Amazon CloudTrail**
#
# 24. (select 3 apply) Which of the following AWS services can be used to manage networking in AWS?
# A. Amazon VPC
# B. Amazon Route 53
# C. Amazon CloudFront
# D. Amazon Direct Connect
# **Correct: A. Amazon VPC, B. Amazon Route 53, D. Amazon Direct Connect**
#
# 25. (select 2 apply) Which of the following AWS services can be used to manage security in AWS?
# A. AWS IAM
# B. Amazon S3
# C. AWS Security Hub
# D. Amazon CloudTrail
# **Correct: A. AWS IAM, C. AWS Security Hub**
#
# 26. (select 3 apply) Which of the following AWS services can be used to manage data backups and recovery?
# A. Amazon S3
# B. Amazon Glacier
# C. Amazon DynamoDB
# D. Amazon RDS
# **Correct: A. Amazon S3, B. Amazon Glacier, D. Amazon RDS**
#
# 27. (select 2 apply) Which of the following AWS services can be used to manage data analytics?
# A. Amazon Redshift
# B. Amazon EMR
# C. Amazon SQS
# D. Amazon Athena
# **Correct: A. Amazon Redshift, B. Amazon EMR**
#
# 28. (select 3 apply) Which of the following AWS services can be used to manage data processing and transformation?
# A. Amazon Kinesis
# B. Amazon S3
# C. Amazon EMR
# D. Amazon Redshift
# **Correct: A. Amazon Kinesis, C. Amazon EMR, D. Amazon Redshift**
#
# 29. (select 2 apply) Which of the following AWS services can be used to manage serverless applications?
# A. AWS Lambda
# B. Amazon EC2
# C. AWS API Gateway
# D. Amazon SQS
# **Correct: A. AWS Lambda, C. AWS API Gateway**
#
# 30. (select 3 apply) Which of the following AWS services can be used to manage machine learning models and applications?
# A. Amazon SageMaker
# B. Amazon Rekognition
# C. Amazon Comprehend
# D. Amazon EC2
# **Correct: A. Amazon SageMaker, B. Amazon Rekognition, C. Amazon Comprehend**
#
# ## True/False
#
# 31. You can use Amazon S3 to store data for a relational database like MySQL.
# A. True
# B. False
# **Correct: B. False**
#
# 32. Amazon EC2 instances can be launched in multiple Availability Zones within a single AWS Region.
# A. True
# B. False
# **Correct: A. True**
#
# 33. Amazon CloudFront can be used to deliver content from Amazon S3 to users around the world with low latency.
# A. True
# B. False
# **Correct: A. True**
#
# 34. Amazon Elastic Beanstalk supports deploying applications built using .NET, PHP, Java, Python, Ruby, Node.js, and Go.
# A. True
# B. False
# **Correct: A. True**
#
# 35. Amazon DynamoDB is a fully managed NoSQL database service that supports both document and key-value data models.
# A. True
# B. False
# **Correct: A. True**
#
# 36. Amazon SQS is a message queuing service that can be used to decouple applications and ensure that messages are delivered reliably.
# A. True
# B. False
# **Correct: A. True**
#
# 37. AWS Lambda is a serverless compute service that allows you to run code without provisioning or managing servers.
# A. True
# B. False
# **Correct: A. True**
#
# 38. Amazon CloudWatch can be used to monitor AWS resources and applications, and trigger actions based on predefined thresholds.
# A. True
# B. False
# **Correct: A. True**
#
# 39. Amazon VPC allows you to create a private network within AWS, isolating your resources from the public internet.
# A. True
# B. False
# **Correct: A. True**
#
# 40. Amazon Route 53 is a DNS service that can be used to route traffic to your AWS resources, including EC2 instances, S3 buckets, and ELB load balancers.
# A. True
# B. False
# **Correct: A. True**
#
# ## Single Correct Answer
#
# 41. Which of the following AWS services can be used to create a fully managed, scalable, and highly available database?
# A. Amazon RDS
# B. Amazon S3
# C. Amazon EC2
# D. Amazon Redshift
# **Correct: A. Amazon RDS**
#
# 42. Which of the following AWS services is a fully managed, serverless compute service that allows you to run code without provisioning or managing servers?
# A. Amazon EC2
# B. Amazon Lambda
# C. Amazon SQS
# D. Amazon DynamoDB
# **Correct: B. Amazon Lambda**
#
# 43. Which of the following AWS services can be used to deliver content to users around the world with low latency?
# A. Amazon S3
# B. Amazon EC2
# C. Amazon CloudFront
# D. Amazon Route 53
# **Correct: C. Amazon CloudFront**
#
# 44. Which of the following AWS services can be used to create a private network within AWS, isolating your resources from the public internet?
# A. Amazon S3
# B. Amazon VPC
# C. Amazon Route 53
# D. Amazon CloudWatch
# **Correct: B. Amazon VPC**
#
# 45. Which of the following AWS services is a managed, NoSQL database service that supports both document and key-value data models?
# A. Amazon RDS
# B. Amazon DynamoDB
# C. Amazon Redshift
# D. Amazon SQS
# **Correct: B. Amazon DynamoDB**
#
# 46. Which of the following AWS services can be used to monitor AWS resources and applications, and trigger actions based on predefined thresholds?
# A. Amazon CloudWatch
# B. Amazon Route 53
# C. Amazon SQS
# D. Amazon EC2
# **Correct: A. Amazon CloudWatch**
#
# 47. Which of the following AWS services can be used to create and manage virtual private clouds (VPCs)?
# A. Amazon EC2
# B. Amazon VPC
# C. Amazon Route 53
# D. Amazon CloudWatch
# **Correct: B. Amazon VPC**
#
# 48. Which of the following AWS services can be used to automate tasks and manage infrastructure using code?
# A. AWS CloudFormation
# B. Amazon EC2
# C. Amazon S3
# D. Amazon DynamoDB
# **Correct: A. AWS CloudFormation**
#
# 49. Which of the following AWS services is a fully managed, serverless data warehouse service?
# A. Amazon RDS
# B. Amazon DynamoDB
# C. Amazon Redshift
# D. Amazon SQS
# **Correct: C. Amazon Redshift**
#
# 50. Which of the following AWS services can be used to create and manage load balancers?
# A. Amazon EC2
# B. Amazon Route 53
# C. Amazon Elastic Load Balancing (ELB)
# D. Amazon CloudFront
# **Correct: C. Amazon Elastic Load Balancing (ELB)**

# %%
# Read generated text as lines
buf = io.StringIO(prompt)
lines = buf.readlines()

# Extract topic
topic_line = [line for line in lines if '- Topic: ' in line][0]
topic = topic_line[9:].rstrip('\n.')
topic = re.sub(' ', '_', topic.lower())
print('Topic:', topic)

# Extract difficulty
difficulty_line = [line for line in lines if '- Difficulty: ' in line][0]
difficulty = difficulty_line[14:].rstrip('\n.').lower()
print('Difficulty:', difficulty)

# Extract size
size_line = [line for line in lines if '- Total questions: ' in line][0]
size = size_line[19:].rstrip('\n.')
print('Size:', size)

# Combine topic, difficulty and size into .txt file name
file_name = f'{topic}_{difficulty}_{size}.txt'
print('File name:', file_name)
# Out:
# Topic: aws
# Difficulty: hard
# Size: 50
# File name: aws_hard_50.txt

# %%
# Assign file_name to a constant using for writing to GCS
WRITE_BLOB = file_name

gcs_write(BUCKET, WRITE_BLOB, generate_text)

# %%
# Assign file_name to a constant using for reading from GCS
READ_BLOB = file_name

# Read data as lines
data = gcs_read(BUCKET, READ_BLOB)

# Use display() because data is already list of lines structure
display(data)
# Out:
# ['## True/False\n',
#  '\n',
#  '1. You can use Amazon S3 to store data for a relational database like MySQL.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: B. False**\n',
#  '\n',
#  '2. Amazon EC2 instances can be launched in multiple Availability Zones within a single AWS Region.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '3. Amazon CloudFront can be used to deliver content from Amazon S3 to users around the world with low latency.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '4. Amazon Elastic Beanstalk supports deploying applications built using .NET, PHP, Java, Python, Ruby, Node.js, and Go.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '5. Amazon DynamoDB is a fully managed NoSQL database service that supports both document and key-value data models.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '6. Amazon SQS is a message queuing service that can be used to decouple applications and ensure that messages are delivered reliably.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '7. AWS Lambda is a serverless compute service that allows you to run code without provisioning or managing servers.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '8. Amazon CloudWatch can be used to monitor AWS resources and applications, and trigger actions based on predefined thresholds.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '9. Amazon VPC allows you to create a private network within AWS, isolating your resources from the public internet.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '10. Amazon Route 53 is a DNS service that can be used to route traffic to your AWS resources, including EC2 instances, S3 buckets, and ELB load balancers.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '## Single Correct Answer\n',
#  '\n',
#  '11. Which of the following AWS services can be used to create a fully managed, scalable, and highly available database?\n',
#  'A. Amazon RDS\n',
#  'B. Amazon S3\n',
#  'C. Amazon EC2\n',
#  'D. Amazon Redshift\n',
#  '**Correct: A. Amazon RDS**\n',
#  '\n',
#  '12. Which of the following AWS services is a fully managed, serverless compute service that allows you to run code without provisioning or managing servers?\n',
#  'A. Amazon EC2\n',
#  'B. Amazon Lambda\n',
#  'C. Amazon SQS\n',
#  'D. Amazon DynamoDB\n',
#  '**Correct: B. Amazon Lambda**\n',
#  '\n',
#  '13. Which of the following AWS services can be used to deliver content to users around the world with low latency?\n',
#  'A. Amazon S3\n',
#  'B. Amazon EC2\n',
#  'C. Amazon CloudFront\n',
#  'D. Amazon Route 53\n',
#  '**Correct: C. Amazon CloudFront**\n',
#  '\n',
#  '14. Which of the following AWS services can be used to create a private network within AWS, isolating your resources from the public internet?\n',
#  'A. Amazon S3\n',
#  'B. Amazon VPC\n',
#  'C. Amazon Route 53\n',
#  'D. Amazon CloudWatch\n',
#  '**Correct: B. Amazon VPC**\n',
#  '\n',
#  '15. Which of the following AWS services is a managed, NoSQL database service that supports both document and key-value data models?\n',
#  'A. Amazon RDS\n',
#  'B. Amazon DynamoDB\n',
#  'C. Amazon Redshift\n',
#  'D. Amazon SQS\n',
#  '**Correct: B. Amazon DynamoDB**\n',
#  '\n',
#  '16. Which of the following AWS services can be used to monitor AWS resources and applications, and trigger actions based on predefined thresholds?\n',
#  'A. Amazon CloudWatch\n',
#  'B. Amazon Route 53\n',
#  'C. Amazon SQS\n',
#  'D. Amazon EC2\n',
#  '**Correct: A. Amazon CloudWatch**\n',
#  '\n',
#  '17. Which of the following AWS services can be used to create and manage virtual private clouds (VPCs)?\n',
#  'A. Amazon EC2\n',
#  'B. Amazon VPC\n',
#  'C. Amazon Route 53\n',
#  'D. Amazon CloudWatch\n',
#  '**Correct: B. Amazon VPC**\n',
#  '\n',
#  '18. Which of the following AWS services can be used to automate tasks and manage infrastructure using code?\n',
#  'A. AWS CloudFormation\n',
#  'B. Amazon EC2\n',
#  'C. Amazon S3\n',
#  'D. Amazon DynamoDB\n',
#  '**Correct: A. AWS CloudFormation**\n',
#  '\n',
#  '19. Which of the following AWS services is a fully managed, serverless data warehouse service?\n',
#  'A. Amazon RDS\n',
#  'B. Amazon DynamoDB\n',
#  'C. Amazon Redshift\n',
#  'D. Amazon SQS\n',
#  '**Correct: C. Amazon Redshift**\n',
#  '\n',
#  '20. Which of the following AWS services can be used to create and manage load balancers?\n',
#  'A. Amazon EC2\n',
#  'B. Amazon Route 53\n',
#  'C. Amazon Elastic Load Balancing (ELB)\n',
#  'D. Amazon CloudFront\n',
#  '**Correct: C. Amazon Elastic Load Balancing (ELB)**\n',
#  '\n',
#  '## Multiple Correct Answers\n',
#  '\n',
#  '21. (select 2 apply) Which of the following AWS services can be used to store data?\n',
#  'A. Amazon S3\n',
#  'B. Amazon EC2\n',
#  'C. Amazon DynamoDB\n',
#  'D. Amazon Redshift\n',
#  '**Correct: A. Amazon S3, C. Amazon DynamoDB**\n',
#  '\n',
#  '22. (select 3 apply) Which of the following AWS services can be used to manage and deploy applications?\n',
#  'A. Amazon EC2\n',
#  'B. Amazon Elastic Beanstalk\n',
#  'C. AWS CloudFormation\n',
#  'D. Amazon S3\n',
#  '**Correct: A. Amazon EC2, B. Amazon Elastic Beanstalk, C. AWS CloudFormation**\n',
#  '\n',
#  '23. (select 2 apply) Which of the following AWS services can be used to monitor and manage resources and applications?\n',
#  'A. Amazon CloudWatch\n',
#  'B. Amazon Route 53\n',
#  'C. Amazon SQS\n',
#  'D. Amazon CloudTrail\n',
#  '**Correct: A. Amazon CloudWatch, D. Amazon CloudTrail**\n',
#  '\n',
#  '24. (select 3 apply) Which of the following AWS services can be used to manage networking in AWS?\n',
#  'A. Amazon VPC\n',
#  'B. Amazon Route 53\n',
#  'C. Amazon CloudFront\n',
#  'D. Amazon Direct Connect\n',
#  '**Correct: A. Amazon VPC, B. Amazon Route 53, D. Amazon Direct Connect**\n',
#  '\n',
#  '25. (select 2 apply) Which of the following AWS services can be used to manage security in AWS?\n',
#  'A. AWS IAM\n',
#  'B. Amazon S3\n',
#  'C. AWS Security Hub\n',
#  'D. Amazon CloudTrail\n',
#  '**Correct: A. AWS IAM, C. AWS Security Hub**\n',
#  '\n',
#  '26. (select 3 apply) Which of the following AWS services can be used to manage data backups and recovery?\n',
#  'A. Amazon S3\n',
#  'B. Amazon Glacier\n',
#  'C. Amazon DynamoDB\n',
#  'D. Amazon RDS\n',
#  '**Correct: A. Amazon S3, B. Amazon Glacier, D. Amazon RDS**\n',
#  '\n',
#  '27. (select 2 apply) Which of the following AWS services can be used to manage data analytics?\n',
#  'A. Amazon Redshift\n',
#  'B. Amazon EMR\n',
#  'C. Amazon SQS\n',
#  'D. Amazon Athena\n',
#  '**Correct: A. Amazon Redshift, B. Amazon EMR**\n',
#  '\n',
#  '28. (select 3 apply) Which of the following AWS services can be used to manage data processing and transformation?\n',
#  'A. Amazon Kinesis\n',
#  'B. Amazon S3\n',
#  'C. Amazon EMR\n',
#  'D. Amazon Redshift\n',
#  '**Correct: A. Amazon Kinesis, C. Amazon EMR, D. Amazon Redshift**\n',
#  '\n',
#  '29. (select 2 apply) Which of the following AWS services can be used to manage serverless applications?\n',
#  'A. AWS Lambda\n',
#  'B. Amazon EC2\n',
#  'C. AWS API Gateway\n',
#  'D. Amazon SQS\n',
#  '**Correct: A. AWS Lambda, C. AWS API Gateway**\n',
#  '\n',
#  '30. (select 3 apply) Which of the following AWS services can be used to manage machine learning models and applications?\n',
#  'A. Amazon SageMaker\n',
#  'B. Amazon Rekognition\n',
#  'C. Amazon Comprehend\n',
#  'D. Amazon EC2\n',
#  '**Correct: A. Amazon SageMaker, B. Amazon Rekognition, C. Amazon Comprehend**\n',
#  '\n',
#  '## True/False\n',
#  '\n',
#  '31. You can use Amazon S3 to store data for a relational database like MySQL.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: B. False**\n',
#  '\n',
#  '32. Amazon EC2 instances can be launched in multiple Availability Zones within a single AWS Region.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '33. Amazon CloudFront can be used to deliver content from Amazon S3 to users around the world with low latency.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '34. Amazon Elastic Beanstalk supports deploying applications built using .NET, PHP, Java, Python, Ruby, Node.js, and Go.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '35. Amazon DynamoDB is a fully managed NoSQL database service that supports both document and key-value data models.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '36. Amazon SQS is a message queuing service that can be used to decouple applications and ensure that messages are delivered reliably.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '37. AWS Lambda is a serverless compute service that allows you to run code without provisioning or managing servers.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '38. Amazon CloudWatch can be used to monitor AWS resources and applications, and trigger actions based on predefined thresholds.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '39. Amazon VPC allows you to create a private network within AWS, isolating your resources from the public internet.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '40. Amazon Route 53 is a DNS service that can be used to route traffic to your AWS resources, including EC2 instances, S3 buckets, and ELB load balancers.\n',
#  'A. True\n',
#  'B. False\n',
#  '**Correct: A. True**\n',
#  '\n',
#  '## Single Correct Answer\n',
#  '\n',
#  '41. Which of the following AWS services can be used to create a fully managed, scalable, and highly available database?\n',
#  'A. Amazon RDS\n',
#  'B. Amazon S3\n',
#  'C. Amazon EC2\n',
#  'D. Amazon Redshift\n',
#  '**Correct: A. Amazon RDS**\n',
#  '\n',
#  '42. Which of the following AWS services is a fully managed, serverless compute service that allows you to run code without provisioning or managing servers?\n',
#  'A. Amazon EC2\n',
#  'B. Amazon Lambda\n',
#  'C. Amazon SQS\n',
#  'D. Amazon DynamoDB\n',
#  '**Correct: B. Amazon Lambda**\n',
#  '\n',
#  '43. Which of the following AWS services can be used to deliver content to users around the world with low latency?\n',
#  'A. Amazon S3\n',
#  'B. Amazon EC2\n',
#  'C. Amazon CloudFront\n',
#  'D. Amazon Route 53\n',
#  '**Correct: C. Amazon CloudFront**\n',
#  '\n',
#  '44. Which of the following AWS services can be used to create a private network within AWS, isolating your resources from the public internet?\n',
#  'A. Amazon S3\n',
#  'B. Amazon VPC\n',
#  'C. Amazon Route 53\n',
#  'D. Amazon CloudWatch\n',
#  '**Correct: B. Amazon VPC**\n',
#  '\n',
#  '45. Which of the following AWS services is a managed, NoSQL database service that supports both document and key-value data models?\n',
#  'A. Amazon RDS\n',
#  'B. Amazon DynamoDB\n',
#  'C. Amazon Redshift\n',
#  'D. Amazon SQS\n',
#  '**Correct: B. Amazon DynamoDB**\n',
#  '\n',
#  '46. Which of the following AWS services can be used to monitor AWS resources and applications, and trigger actions based on predefined thresholds?\n',
#  'A. Amazon CloudWatch\n',
#  'B. Amazon Route 53\n',
#  'C. Amazon SQS\n',
#  'D. Amazon EC2\n',
#  '**Correct: A. Amazon CloudWatch**\n',
#  '\n',
#  '47. Which of the following AWS services can be used to create and manage virtual private clouds (VPCs)?\n',
#  'A. Amazon EC2\n',
#  'B. Amazon VPC\n',
#  'C. Amazon Route 53\n',
#  'D. Amazon CloudWatch\n',
#  '**Correct: B. Amazon VPC**\n',
#  '\n',
#  '48. Which of the following AWS services can be used to automate tasks and manage infrastructure using code?\n',
#  'A. AWS CloudFormation\n',
#  'B. Amazon EC2\n',
#  'C. Amazon S3\n',
#  'D. Amazon DynamoDB\n',
#  '**Correct: A. AWS CloudFormation**\n',
#  '\n',
#  '49. Which of the following AWS services is a fully managed, serverless data warehouse service?\n',
#  'A. Amazon RDS\n',
#  'B. Amazon DynamoDB\n',
#  'C. Amazon Redshift\n',
#  'D. Amazon SQS\n',
#  '**Correct: C. Amazon Redshift**\n',
#  '\n',
#  '50. Which of the following AWS services can be used to create and manage load balancers?\n',
#  'A. Amazon EC2\n',
#  'B. Amazon Route 53\n',
#  'C. Amazon Elastic Load Balancing (ELB)\n',
#  'D. Amazon CloudFront\n',
#  '**Correct: C. Amazon Elastic Load Balancing (ELB)**']

# %%
def split_qa(lines_data):
    """
    Accepts list of lines.
    Returns a dictionary with keys `question` and `answer`
    """
    dict_data = {'question': [],
                 'answer': []}
    
    # Switch determines if the last line is in question section or not
    q_prev = False
    
    for line in lines_data:
        
        # Strip '**' style around 'Correct answer(s)' or 'Correct'
        line = line.replace('**', '')
        
        # Check if line is not blank, title or heading ('##')
        if (line != '\n') and ('##' not in line):
            
            # Call the first word of the line is `head`
            head = line.split()[0]
            
            # Append new question if all of these meet:
            # - Previous line is not in question text
            # - First character of `head` is numeric
            # - Last character of `head` is '.'
            if (not q_prev) and head[0].isnumeric() and head[-1] == ".":
                dict_data['question'].append(line)
                q_prev = True
    
            # Append new answer if all of these meet:
            # - Previous line is in question text
            # - `head` is 'A.'
            elif q_prev and head == 'A.':
                dict_data['answer'].append(line)
                q_prev = False
    
            # Add line to unfinished question
            elif q_prev:
                dict_data['question'][-1] += line
        
            # Add line to unfinished answer
            else:
                dict_data['answer'][-1] += line
    
    return dict_data

# %%
# Return split_qa result to a variable
dict0 = split_qa(data)

# Convert `dict0` to a DataFrame
df0 = pd.DataFrame(dict0)

print('Number of questions:', len(df0))
print('Columns:', df0.columns.values)
# Out:
# Number of questions: 50
# Columns: ['question' 'answer']

# %%
# View some rows
df0.iloc[15:60]
# Out:
#                                              question  \
# 15  16. Which of the following AWS services can be...
# 16  17. Which of the following AWS services can be...
# 17  18. Which of the following AWS services can be...
# 18  19. Which of the following AWS services is a f...
# 19  20. Which of the following AWS services can be...
# 20  21. (select 2 apply) Which of the following AW...
# 21  22. (select 3 apply) Which of the following AW...
# 22  23. (select 2 apply) Which of the following AW...
# 23  24. (select 3 apply) Which of the following AW...
# 24  25. (select 2 apply) Which of the following AW...
# 25  26. (select 3 apply) Which of the following AW...
# 26  27. (select 2 apply) Which of the following AW...
# 27  28. (select 3 apply) Which of the following AW...
# 28  29. (select 2 apply) Which of the following AW...
# 29  30. (select 3 apply) Which of the following AW...
# 30  31. You can use Amazon S3 to store data for a ...
# 31  32. Amazon EC2 instances can be launched in mu...
# 32  33. Amazon CloudFront can be used to deliver c...
# 33  34. Amazon Elastic Beanstalk supports deployin...
# 34  35. Amazon DynamoDB is a fully managed NoSQL d...
# 35  36. Amazon SQS is a message queuing service th...
# 36  37. AWS Lambda is a serverless compute service...
# 37  38. Amazon CloudWatch can be used to monitor A...
# 38  39. Amazon VPC allows you to create a private ...
# 39  40. Amazon Route 53 is a DNS service that can ...
# 40  41. Which of the following AWS services can be...
# 41  42. Which of the following AWS services is a f...
# 42  43. Which of the following AWS services can be...
# 43  44. Which of the following AWS services can be...
# 44  45. Which of the following AWS services is a m...
# 45  46. Which of the following AWS services can be...
# 46  47. Which of the following AWS services can be...
# 47  48. Which of the following AWS services can be...
# 48  49. Which of the following AWS services is a f...
# 49  50. Which of the following AWS services can be...
#
#                                                answer
# 15  A. Amazon CloudWatch\nB. Amazon Route 53\nC. A...
# 16  A. Amazon EC2\nB. Amazon VPC\nC. Amazon Route ...
# 17  A. AWS CloudFormation\nB. Amazon EC2\nC. Amazo...
# 18  A. Amazon RDS\nB. Amazon DynamoDB\nC. Amazon R...
# 19  A. Amazon EC2\nB. Amazon Route 53\nC. Amazon E...
# 20  A. Amazon S3\nB. Amazon EC2\nC. Amazon DynamoD...
# 21  A. Amazon EC2\nB. Amazon Elastic Beanstalk\nC....
# 22  A. Amazon CloudWatch\nB. Amazon Route 53\nC. A...
# 23  A. Amazon VPC\nB. Amazon Route 53\nC. Amazon C...
# 24  A. AWS IAM\nB. Amazon S3\nC. AWS Security Hub\...
# 25  A. Amazon S3\nB. Amazon Glacier\nC. Amazon Dyn...
# 26  A. Amazon Redshift\nB. Amazon EMR\nC. Amazon S...
# 27  A. Amazon Kinesis\nB. Amazon S3\nC. Amazon EMR...
# 28  A. AWS Lambda\nB. Amazon EC2\nC. AWS API Gatew...
# 29  A. Amazon SageMaker\nB. Amazon Rekognition\nC....
# 30             A. True\nB. False\nCorrect: B. False\n
# 31              A. True\nB. False\nCorrect: A. True\n
# 32              A. True\nB. False\nCorrect: A. True\n
# 33              A. True\nB. False\nCorrect: A. True\n
# 34              A. True\nB. False\nCorrect: A. True\n
# 35              A. True\nB. False\nCorrect: A. True\n
# 36              A. True\nB. False\nCorrect: A. True\n
# 37              A. True\nB. False\nCorrect: A. True\n
# 38              A. True\nB. False\nCorrect: A. True\n
# 39              A. True\nB. False\nCorrect: A. True\n
# 40  A. Amazon RDS\nB. Amazon S3\nC. Amazon EC2\nD....
# 41  A. Amazon EC2\nB. Amazon Lambda\nC. Amazon SQS...
# 42  A. Amazon S3\nB. Amazon EC2\nC. Amazon CloudFr...
# 43  A. Amazon S3\nB. Amazon VPC\nC. Amazon Route 5...
# 44  A. Amazon RDS\nB. Amazon DynamoDB\nC. Amazon R...
# 45  A. Amazon CloudWatch\nB. Amazon Route 53\nC. A...
# 46  A. Amazon EC2\nB. Amazon VPC\nC. Amazon Route ...
# 47  A. AWS CloudFormation\nB. Amazon EC2\nC. Amazo...
# 48  A. Amazon RDS\nB. Amazon DynamoDB\nC. Amazon R...
# 49  A. Amazon EC2\nB. Amazon Route 53\nC. Amazon E...

# %%
# Make a copy of df0
df1 = df0.copy()

# %%
# Strip the number at the beginning and '\n' at the end of each question 
df1['question'] = df1['question'].str.replace(r'^\d{0,4}\.[ ]', '', regex=True).str.rstrip()

# %%
df1
# Out:
#                                              question  \
# 0   You can use Amazon S3 to store data for a rela...
# 1   Amazon EC2 instances can be launched in multip...
# 2   Amazon CloudFront can be used to deliver conte...
# 3   Amazon Elastic Beanstalk supports deploying ap...
# 4   Amazon DynamoDB is a fully managed NoSQL datab...
# 5   Amazon SQS is a message queuing service that c...
# 6   AWS Lambda is a serverless compute service tha...
# 7   Amazon CloudWatch can be used to monitor AWS r...
# 8   Amazon VPC allows you to create a private netw...
# 9   Amazon Route 53 is a DNS service that can be u...
# 10  Which of the following AWS services can be use...
# 11  Which of the following AWS services is a fully...
# 12  Which of the following AWS services can be use...
# 13  Which of the following AWS services can be use...
# 14  Which of the following AWS services is a manag...
# 15  Which of the following AWS services can be use...
# 16  Which of the following AWS services can be use...
# 17  Which of the following AWS services can be use...
# 18  Which of the following AWS services is a fully...
# 19  Which of the following AWS services can be use...
# 20  (select 2 apply) Which of the following AWS se...
# 21  (select 3 apply) Which of the following AWS se...
# 22  (select 2 apply) Which of the following AWS se...
# 23  (select 3 apply) Which of the following AWS se...
# 24  (select 2 apply) Which of the following AWS se...
# 25  (select 3 apply) Which of the following AWS se...
# 26  (select 2 apply) Which of the following AWS se...
# 27  (select 3 apply) Which of the following AWS se...
# 28  (select 2 apply) Which of the following AWS se...
# 29  (select 3 apply) Which of the following AWS se...
# 30  You can use Amazon S3 to store data for a rela...
# 31  Amazon EC2 instances can be launched in multip...
# 32  Amazon CloudFront can be used to deliver conte...
# 33  Amazon Elastic Beanstalk supports deploying ap...
# 34  Amazon DynamoDB is a fully managed NoSQL datab...
# 35  Amazon SQS is a message queuing service that c...
# 36  AWS Lambda is a serverless compute service tha...
# 37  Amazon CloudWatch can be used to monitor AWS r...
# 38  Amazon VPC allows you to create a private netw...
# 39  Amazon Route 53 is a DNS service that can be u...
# 40  Which of the following AWS services can be use...
# 41  Which of the following AWS services is a fully...
# 42  Which of the following AWS services can be use...
# 43  Which of the following AWS services can be use...
# 44  Which of the following AWS services is a manag...
# 45  Which of the following AWS services can be use...
# 46  Which of the following AWS services can be use...
# 47  Which of the following AWS services can be use...
# 48  Which of the following AWS services is a fully...
# 49  Which of the following AWS services can be use...
#
#                                                answer
# 0              A. True\nB. False\nCorrect: B. False\n
# 1               A. True\nB. False\nCorrect: A. True\n
# 2               A. True\nB. False\nCorrect: A. True\n
# 3               A. True\nB. False\nCorrect: A. True\n
# 4               A. True\nB. False\nCorrect: A. True\n
# 5               A. True\nB. False\nCorrect: A. True\n
# 6               A. True\nB. False\nCorrect: A. True\n
# 7               A. True\nB. False\nCorrect: A. True\n
# 8               A. True\nB. False\nCorrect: A. True\n
# 9               A. True\nB. False\nCorrect: A. True\n
# 10  A. Amazon RDS\nB. Amazon S3\nC. Amazon EC2\nD....
# 11  A. Amazon EC2\nB. Amazon Lambda\nC. Amazon SQS...
# 12  A. Amazon S3\nB. Amazon EC2\nC. Amazon CloudFr...
# 13  A. Amazon S3\nB. Amazon VPC\nC. Amazon Route 5...
# 14  A. Amazon RDS\nB. Amazon DynamoDB\nC. Amazon R...
# 15  A. Amazon CloudWatch\nB. Amazon Route 53\nC. A...
# 16  A. Amazon EC2\nB. Amazon VPC\nC. Amazon Route ...
# 17  A. AWS CloudFormation\nB. Amazon EC2\nC. Amazo...
# 18  A. Amazon RDS\nB. Amazon DynamoDB\nC. Amazon R...
# 19  A. Amazon EC2\nB. Amazon Route 53\nC. Amazon E...
# 20  A. Amazon S3\nB. Amazon EC2\nC. Amazon DynamoD...
# 21  A. Amazon EC2\nB. Amazon Elastic Beanstalk\nC....
# 22  A. Amazon CloudWatch\nB. Amazon Route 53\nC. A...
# 23  A. Amazon VPC\nB. Amazon Route 53\nC. Amazon C...
# 24  A. AWS IAM\nB. Amazon S3\nC. AWS Security Hub\...
# 25  A. Amazon S3\nB. Amazon Glacier\nC. Amazon Dyn...
# 26  A. Amazon Redshift\nB. Amazon EMR\nC. Amazon S...
# 27  A. Amazon Kinesis\nB. Amazon S3\nC. Amazon EMR...
# 28  A. AWS Lambda\nB. Amazon EC2\nC. AWS API Gatew...
# 29  A. Amazon SageMaker\nB. Amazon Rekognition\nC....
# 30             A. True\nB. False\nCorrect: B. False\n
# 31              A. True\nB. False\nCorrect: A. True\n
# 32              A. True\nB. False\nCorrect: A. True\n
# 33              A. True\nB. False\nCorrect: A. True\n
# 34              A. True\nB. False\nCorrect: A. True\n
# 35              A. True\nB. False\nCorrect: A. True\n
# 36              A. True\nB. False\nCorrect: A. True\n
# 37              A. True\nB. False\nCorrect: A. True\n
# 38              A. True\nB. False\nCorrect: A. True\n
# 39              A. True\nB. False\nCorrect: A. True\n
# 40  A. Amazon RDS\nB. Amazon S3\nC. Amazon EC2\nD....
# 41  A. Amazon EC2\nB. Amazon Lambda\nC. Amazon SQS...
# 42  A. Amazon S3\nB. Amazon EC2\nC. Amazon CloudFr...
# 43  A. Amazon S3\nB. Amazon VPC\nC. Amazon Route 5...
# 44  A. Amazon RDS\nB. Amazon DynamoDB\nC. Amazon R...
# 45  A. Amazon CloudWatch\nB. Amazon Route 53\nC. A...
# 46  A. Amazon EC2\nB. Amazon VPC\nC. Amazon Route ...
# 47  A. AWS CloudFormation\nB. Amazon EC2\nC. Amazo...
# 48  A. Amazon RDS\nB. Amazon DynamoDB\nC. Amazon R...
# 49  A. Amazon EC2\nB. Amazon Route 53\nC. Amazon E...

# %%
def convert_index(capital):
    """Return zero-based index from capital, 'A' has unicode code as 65"""
    return ord(capital) - 65

def split_choice(answer):
    """
    Split the `answer` data into multiple choices
    """
    # print(answer)
    
    # Use 'Correct Answer(s): ' to split text.
    # Index 0 is all choices, index 1 is all answers
    if 'Correct Answer' in answer:
        split_all = re.split(r'Correct Answer[s]*: ', answer)
    else:
        split_all = re.split('Correct: ', answer)
    # print("After strip 'Correct Answer(s): ' or 'Correct: ':", split_all)
    
    choices = split_all[0]
    # print('Choices text:', choices)
    
    correct_stack = split_all[1]
    # print('Correct stack:', correct_stack)
    
    # Split using ','
    correct_stack = correct_stack.split(',')
    
    # Pick only first capital indicating the choices
    correct_note = [item.strip()[0] for item in correct_stack]
    # print('Correct note:', correct_note)
    
    # Make zero-based index from alphabet
    correct_index = [convert_index(item) for item in correct_note]
    # print('Correct index', correct_index)
    
    # Split using 'X. ', index 0 is '', so pass
    choices = re.split(r'[A-Z]\.[ ]', choices)[1:]
    # Strip right side of choice text
    choices = [choice.rstrip() for choice in choices]
    # print('All choices in list: ', choices)
    
    # Separate choices into lists as `incorrect` and `correct`
    incorrect = [choice for index, choice in enumerate(choices) if index not in correct_index]
    # print('Incorrect in list: ', incorrect)
    correct = [choice for index, choice in enumerate(choices) if index in correct_index]
    # print('Correct in list: ', correct)
    
    return {'incorrect': incorrect,
            'correct': correct}

# %%
# Make a copy of `df1`
df_2 = df1.copy()

# %%
# Test the function with sub set of data
df_test = df_2.iloc[20:22]['answer'].apply(split_choice)

# %%
# Print out to preview results
display(df_test.str['incorrect'])
df_test.str['correct']
# Out:
# 20    [Amazon EC2, Amazon Redshift]
# 21                      [Amazon S3]
# Name: answer, dtype: object
# 20                         [Amazon S3, Amazon DynamoDB]
# 21    [Amazon EC2, Amazon Elastic Beanstalk, AWS Clo...
# Name: answer, dtype: object

# %%
# Apply the function to full dataset
df_2['incorrect'] = df_2['answer'].apply(split_choice).str['incorrect']
df_2['correct'] = df_2['answer'].apply(split_choice).str['correct']

# %%
# Preview a row
display(df_2.loc[40, 'incorrect'])
display(df_2.loc[40, 'correct'])
# Out:
# ['Amazon S3', 'Amazon EC2', 'Amazon Redshift']
# ['Amazon RDS']

# %%
# New order of columns
new_order = ['question', 'incorrect', 'correct']

# Make a copy of `df_a` with new order of columns
df_clean = df_2[new_order].copy()

# Preview data in a row
display(df_clean['incorrect'][45])
display(df_clean['correct'][45])
df_clean.iloc[45]
# Out:
# ['Amazon Route 53', 'Amazon SQS', 'Amazon EC2']
# ['Amazon CloudWatch']
# question     Which of the following AWS services can be use...
# incorrect            [Amazon Route 53, Amazon SQS, Amazon EC2]
# correct                                    [Amazon CloudWatch]
# Name: 45, dtype: object

# %%
# Preview the whole final table
df_clean
# Out:
#                                              question  \
# 0   You can use Amazon S3 to store data for a rela...
# 1   Amazon EC2 instances can be launched in multip...
# 2   Amazon CloudFront can be used to deliver conte...
# 3   Amazon Elastic Beanstalk supports deploying ap...
# 4   Amazon DynamoDB is a fully managed NoSQL datab...
# 5   Amazon SQS is a message queuing service that c...
# 6   AWS Lambda is a serverless compute service tha...
# 7   Amazon CloudWatch can be used to monitor AWS r...
# 8   Amazon VPC allows you to create a private netw...
# 9   Amazon Route 53 is a DNS service that can be u...
# 10  Which of the following AWS services can be use...
# 11  Which of the following AWS services is a fully...
# 12  Which of the following AWS services can be use...
# 13  Which of the following AWS services can be use...
# 14  Which of the following AWS services is a manag...
# 15  Which of the following AWS services can be use...
# 16  Which of the following AWS services can be use...
# 17  Which of the following AWS services can be use...
# 18  Which of the following AWS services is a fully...
# 19  Which of the following AWS services can be use...
# 20  (select 2 apply) Which of the following AWS se...
# 21  (select 3 apply) Which of the following AWS se...
# 22  (select 2 apply) Which of the following AWS se...
# 23  (select 3 apply) Which of the following AWS se...
# 24  (select 2 apply) Which of the following AWS se...
# 25  (select 3 apply) Which of the following AWS se...
# 26  (select 2 apply) Which of the following AWS se...
# 27  (select 3 apply) Which of the following AWS se...
# 28  (select 2 apply) Which of the following AWS se...
# 29  (select 3 apply) Which of the following AWS se...
# 30  You can use Amazon S3 to store data for a rela...
# 31  Amazon EC2 instances can be launched in multip...
# 32  Amazon CloudFront can be used to deliver conte...
# 33  Amazon Elastic Beanstalk supports deploying ap...
# 34  Amazon DynamoDB is a fully managed NoSQL datab...
# 35  Amazon SQS is a message queuing service that c...
# 36  AWS Lambda is a serverless compute service tha...
# 37  Amazon CloudWatch can be used to monitor AWS r...
# 38  Amazon VPC allows you to create a private netw...
# 39  Amazon Route 53 is a DNS service that can be u...
# 40  Which of the following AWS services can be use...
# 41  Which of the following AWS services is a fully...
# 42  Which of the following AWS services can be use...
# 43  Which of the following AWS services can be use...
# 44  Which of the following AWS services is a manag...
# 45  Which of the following AWS services can be use...
# 46  Which of the following AWS services can be use...
# 47  Which of the following AWS services can be use...
# 48  Which of the following AWS services is a fully...
# 49  Which of the following AWS services can be use...
#
#                                            incorrect  \
# 0                                             [True]
# 1                                            [False]
# 2                                            [False]
# 3                                            [False]
# 4                                            [False]
# 5                                            [False]
# 6                                            [False]
# 7                                            [False]
# 8                                            [False]
# 9                                            [False]
# 10          [Amazon S3, Amazon EC2, Amazon Redshift]
# 11         [Amazon EC2, Amazon SQS, Amazon DynamoDB]
# 12          [Amazon S3, Amazon EC2, Amazon Route 53]
# 13   [Amazon S3, Amazon Route 53, Amazon CloudWatch]
# 14         [Amazon RDS, Amazon Redshift, Amazon SQS]
# 15         [Amazon Route 53, Amazon SQS, Amazon EC2]
# 16  [Amazon EC2, Amazon Route 53, Amazon CloudWatch]
# 17          [Amazon EC2, Amazon S3, Amazon DynamoDB]
# 18         [Amazon RDS, Amazon DynamoDB, Amazon SQS]
# 19  [Amazon EC2, Amazon Route 53, Amazon CloudFront]
# 20                     [Amazon EC2, Amazon Redshift]
# 21                                       [Amazon S3]
# 22                     [Amazon Route 53, Amazon SQS]
# 23                               [Amazon CloudFront]
# 24                    [Amazon S3, Amazon CloudTrail]
# 25                                 [Amazon DynamoDB]
# 26                       [Amazon SQS, Amazon Athena]
# 27                                       [Amazon S3]
# 28                          [Amazon EC2, Amazon SQS]
# 29                                      [Amazon EC2]
# 30                                            [True]
# 31                                           [False]
# 32                                           [False]
# 33                                           [False]
# 34                                           [False]
# 35                                           [False]
# 36                                           [False]
# 37                                           [False]
# 38                                           [False]
# 39                                           [False]
# 40          [Amazon S3, Amazon EC2, Amazon Redshift]
# 41         [Amazon EC2, Amazon SQS, Amazon DynamoDB]
# 42          [Amazon S3, Amazon EC2, Amazon Route 53]
# 43   [Amazon S3, Amazon Route 53, Amazon CloudWatch]
# 44         [Amazon RDS, Amazon Redshift, Amazon SQS]
# 45         [Amazon Route 53, Amazon SQS, Amazon EC2]
# 46  [Amazon EC2, Amazon Route 53, Amazon CloudWatch]
# 47          [Amazon EC2, Amazon S3, Amazon DynamoDB]
# 48         [Amazon RDS, Amazon DynamoDB, Amazon SQS]
# 49  [Amazon EC2, Amazon Route 53, Amazon CloudFront]
#
#                                               correct
# 0                                             [False]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                              [True]
# 5                                              [True]
# 6                                              [True]
# 7                                              [True]
# 8                                              [True]
# 9                                              [True]
# 10                                       [Amazon RDS]
# 11                                    [Amazon Lambda]
# 12                                [Amazon CloudFront]
# 13                                       [Amazon VPC]
# 14                                  [Amazon DynamoDB]
# 15                                [Amazon CloudWatch]
# 16                                       [Amazon VPC]
# 17                               [AWS CloudFormation]
# 18                                  [Amazon Redshift]
# 19              [Amazon Elastic Load Balancing (ELB)]
# 20                       [Amazon S3, Amazon DynamoDB]
# 21  [Amazon EC2, Amazon Elastic Beanstalk, AWS Clo...
# 22             [Amazon CloudWatch, Amazon CloudTrail]
# 23  [Amazon VPC, Amazon Route 53, Amazon Direct Co...
# 24                        [AWS IAM, AWS Security Hub]
# 25            [Amazon S3, Amazon Glacier, Amazon RDS]
# 26                      [Amazon Redshift, Amazon EMR]
# 27      [Amazon Kinesis, Amazon EMR, Amazon Redshift]
# 28                      [AWS Lambda, AWS API Gateway]
# 29  [Amazon SageMaker, Amazon Rekognition, Amazon ...
# 30                                            [False]
# 31                                             [True]
# 32                                             [True]
# 33                                             [True]
# 34                                             [True]
# 35                                             [True]
# 36                                             [True]
# 37                                             [True]
# 38                                             [True]
# 39                                             [True]
# 40                                       [Amazon RDS]
# 41                                    [Amazon Lambda]
# 42                                [Amazon CloudFront]
# 43                                       [Amazon VPC]
# 44                                  [Amazon DynamoDB]
# 45                                [Amazon CloudWatch]
# 46                                       [Amazon VPC]
# 47                               [AWS CloudFormation]
# 48                                  [Amazon Redshift]
# 49              [Amazon Elastic Load Balancing (ELB)]

# %%
# Pick up the read blob name with '.txt' excluded, to make new json file name
JSON_BLOB = READ_BLOB[:-4] + '.json'

# Convert `df_clean` to JSON string
export_json_string = df_clean.to_json()

# %%
# Write JSON string to GCS object as a JSON file
gcs_write(BUCKET, JSON_BLOB, export_json_string)

# %%
# Read just exported JSON file for testing purpose
read_json_string = gcs_read(BUCKET, JSON_BLOB, j_load=True)

# Convert to DataFrame
df_json = pd.DataFrame(read_json_string)

# %%
# Preview json file data as DataFrame
df_json
# Out:
#                                              question  \
# 0   You can use Amazon S3 to store data for a rela...
# 1   Amazon EC2 instances can be launched in multip...
# 2   Amazon CloudFront can be used to deliver conte...
# 3   Amazon Elastic Beanstalk supports deploying ap...
# 4   Amazon DynamoDB is a fully managed NoSQL datab...
# 5   Amazon SQS is a message queuing service that c...
# 6   AWS Lambda is a serverless compute service tha...
# 7   Amazon CloudWatch can be used to monitor AWS r...
# 8   Amazon VPC allows you to create a private netw...
# 9   Amazon Route 53 is a DNS service that can be u...
# 10  Which of the following AWS services can be use...
# 11  Which of the following AWS services is a fully...
# 12  Which of the following AWS services can be use...
# 13  Which of the following AWS services can be use...
# 14  Which of the following AWS services is a manag...
# 15  Which of the following AWS services can be use...
# 16  Which of the following AWS services can be use...
# 17  Which of the following AWS services can be use...
# 18  Which of the following AWS services is a fully...
# 19  Which of the following AWS services can be use...
# 20  (select 2 apply) Which of the following AWS se...
# 21  (select 3 apply) Which of the following AWS se...
# 22  (select 2 apply) Which of the following AWS se...
# 23  (select 3 apply) Which of the following AWS se...
# 24  (select 2 apply) Which of the following AWS se...
# 25  (select 3 apply) Which of the following AWS se...
# 26  (select 2 apply) Which of the following AWS se...
# 27  (select 3 apply) Which of the following AWS se...
# 28  (select 2 apply) Which of the following AWS se...
# 29  (select 3 apply) Which of the following AWS se...
# 30  You can use Amazon S3 to store data for a rela...
# 31  Amazon EC2 instances can be launched in multip...
# 32  Amazon CloudFront can be used to deliver conte...
# 33  Amazon Elastic Beanstalk supports deploying ap...
# 34  Amazon DynamoDB is a fully managed NoSQL datab...
# 35  Amazon SQS is a message queuing service that c...
# 36  AWS Lambda is a serverless compute service tha...
# 37  Amazon CloudWatch can be used to monitor AWS r...
# 38  Amazon VPC allows you to create a private netw...
# 39  Amazon Route 53 is a DNS service that can be u...
# 40  Which of the following AWS services can be use...
# 41  Which of the following AWS services is a fully...
# 42  Which of the following AWS services can be use...
# 43  Which of the following AWS services can be use...
# 44  Which of the following AWS services is a manag...
# 45  Which of the following AWS services can be use...
# 46  Which of the following AWS services can be use...
# 47  Which of the following AWS services can be use...
# 48  Which of the following AWS services is a fully...
# 49  Which of the following AWS services can be use...
#
#                                            incorrect  \
# 0                                             [True]
# 1                                            [False]
# 2                                            [False]
# 3                                            [False]
# 4                                            [False]
# 5                                            [False]
# 6                                            [False]
# 7                                            [False]
# 8                                            [False]
# 9                                            [False]
# 10          [Amazon S3, Amazon EC2, Amazon Redshift]
# 11         [Amazon EC2, Amazon SQS, Amazon DynamoDB]
# 12          [Amazon S3, Amazon EC2, Amazon Route 53]
# 13   [Amazon S3, Amazon Route 53, Amazon CloudWatch]
# 14         [Amazon RDS, Amazon Redshift, Amazon SQS]
# 15         [Amazon Route 53, Amazon SQS, Amazon EC2]
# 16  [Amazon EC2, Amazon Route 53, Amazon CloudWatch]
# 17          [Amazon EC2, Amazon S3, Amazon DynamoDB]
# 18         [Amazon RDS, Amazon DynamoDB, Amazon SQS]
# 19  [Amazon EC2, Amazon Route 53, Amazon CloudFront]
# 20                     [Amazon EC2, Amazon Redshift]
# 21                                       [Amazon S3]
# 22                     [Amazon Route 53, Amazon SQS]
# 23                               [Amazon CloudFront]
# 24                    [Amazon S3, Amazon CloudTrail]
# 25                                 [Amazon DynamoDB]
# 26                       [Amazon SQS, Amazon Athena]
# 27                                       [Amazon S3]
# 28                          [Amazon EC2, Amazon SQS]
# 29                                      [Amazon EC2]
# 30                                            [True]
# 31                                           [False]
# 32                                           [False]
# 33                                           [False]
# 34                                           [False]
# 35                                           [False]
# 36                                           [False]
# 37                                           [False]
# 38                                           [False]
# 39                                           [False]
# 40          [Amazon S3, Amazon EC2, Amazon Redshift]
# 41         [Amazon EC2, Amazon SQS, Amazon DynamoDB]
# 42          [Amazon S3, Amazon EC2, Amazon Route 53]
# 43   [Amazon S3, Amazon Route 53, Amazon CloudWatch]
# 44         [Amazon RDS, Amazon Redshift, Amazon SQS]
# 45         [Amazon Route 53, Amazon SQS, Amazon EC2]
# 46  [Amazon EC2, Amazon Route 53, Amazon CloudWatch]
# 47          [Amazon EC2, Amazon S3, Amazon DynamoDB]
# 48         [Amazon RDS, Amazon DynamoDB, Amazon SQS]
# 49  [Amazon EC2, Amazon Route 53, Amazon CloudFront]
#
#                                               correct
# 0                                             [False]
# 1                                              [True]
# 2                                              [True]
# 3                                              [True]
# 4                                              [True]
# 5                                              [True]
# 6                                              [True]
# 7                                              [True]
# 8                                              [True]
# 9                                              [True]
# 10                                       [Amazon RDS]
# 11                                    [Amazon Lambda]
# 12                                [Amazon CloudFront]
# 13                                       [Amazon VPC]
# 14                                  [Amazon DynamoDB]
# 15                                [Amazon CloudWatch]
# 16                                       [Amazon VPC]
# 17                               [AWS CloudFormation]
# 18                                  [Amazon Redshift]
# 19              [Amazon Elastic Load Balancing (ELB)]
# 20                       [Amazon S3, Amazon DynamoDB]
# 21  [Amazon EC2, Amazon Elastic Beanstalk, AWS Clo...
# 22             [Amazon CloudWatch, Amazon CloudTrail]
# 23  [Amazon VPC, Amazon Route 53, Amazon Direct Co...
# 24                        [AWS IAM, AWS Security Hub]
# 25            [Amazon S3, Amazon Glacier, Amazon RDS]
# 26                      [Amazon Redshift, Amazon EMR]
# 27      [Amazon Kinesis, Amazon EMR, Amazon Redshift]
# 28                      [AWS Lambda, AWS API Gateway]
# 29  [Amazon SageMaker, Amazon Rekognition, Amazon ...
# 30                                            [False]
# 31                                             [True]
# 32                                             [True]
# 33                                             [True]
# 34                                             [True]
# 35                                             [True]
# 36                                             [True]
# 37                                             [True]
# 38                                             [True]
# 39                                             [True]
# 40                                       [Amazon RDS]
# 41                                    [Amazon Lambda]
# 42                                [Amazon CloudFront]
# 43                                       [Amazon VPC]
# 44                                  [Amazon DynamoDB]
# 45                                [Amazon CloudWatch]
# 46                                       [Amazon VPC]
# 47                               [AWS CloudFormation]
# 48                                  [Amazon Redshift]
# 49              [Amazon Elastic Load Balancing (ELB)]

# %%
# Preview index in JSON string to confirm
read_json_string['question']['15']
# Out:
# 'Which of the following AWS services can be used to monitor AWS resources and applications, and trigger actions based on predefined thresholds?'

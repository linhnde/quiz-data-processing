# %%
# Import packages
import pandas as pd
import re

# %%
# Imports the Google Cloud client library
from google.cloud import storage

# !export GOOGLE_APPLICATION_CREDENTIALS='book-to-quiz-7558e7ee5aca.json'

def gcs_read(bucket_name, blob_name):
    """Write and read a blob from GCS using file-like IO"""
    # The ID of your GCS bucket
    # bucket_name = "your-bucket-name"

    # The ID of your new GCS object
    # blob_name = "storage-object-name"

    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)

    # Mode can be specified as wb/rb for bytes mode.
    # See: https://docs.python.org/3/library/io.html

    with blob.open("r") as f:
        # Return data as lines
        return f.readlines()

# %%
BUCKET = 'book-to-quiz-question-bank'
BLOB = 'aws_hard.txt'
data = gcs_read(BUCKET, BLOB)
# Print first line and last line to confirm the content
print(data[0], '[...]\n', data[-1])
# Out:
# ## True/False (17 questions)
#  [...]
#  **Correct Answer: C. Redshift Query Optimization, D. Redshift Data Sharing**

# %%
dict_data = {'question': [],
             'answer': []}

# Switch determine if the last line is in question section or no
q_prev = False

for line in data:
  # Check if line is not blank or title
  if (line != '\n') and ('##' not in line):
    # Call the first word of the line is `head`
    head = line.split()[0]

    # Append new question if all of these meet:
    # - `q_prev` is False
    # - First character of `head` is numeric
    # - Last character of `head` is numeric or 'r'
    if (not q_prev) and head[0].isnumeric() and head[-1] == ".":
      dict_data['question'].append(line)
      q_prev = True

    # Append new answer if all of these meet:
    # - `q_prev` is True
    # - `head` is 'A.' or '*A.'
    elif q_prev and head == 'A.':
      dict_data['answer'].append(line)
      q_prev = False

    # Add line to unfinished question
    elif q_prev:
      dict_data['question'][-1] += line

    # Add line to unfinished answer
    else:
      dict_data['answer'][-1] += line

# Convert `dict_data` to a DataFrame and make a copy of it
df0 = pd.DataFrame(dict_data)

print('Number of questions: ', len(df0))
print('Columns: ', df0.columns.values)
# Out:
# Number of questions:  50
# Columns:  ['question' 'answer']

# %%
# View some indices (15 to 38)
df0.iloc[15:39]
# Out:
#                                              question  \
# 15  16. You are using Amazon Kinesis Data Streams ...
# 16  17. You are using Amazon SNS to send notificat...
# 17  1. You are running a web application on Amazon...
# 18  2. You are designing a database for a new appl...
# 19  3. You are using Amazon CloudWatch to monitor ...
# 20  4. You are building a new application that req...
# 21  5. You are using Amazon API Gateway to expose ...
# 22  6. You are using Amazon Route 53 to manage the...
# 23  7. You are using Amazon SQS to implement a mes...
# 24  8. You are building a serverless application u...
# 25  9. You are using Amazon ECS to deploy a contai...
# 26  10. You are using Amazon CloudFront to distrib...
# 27  11. You are using Amazon Cognito for user auth...
# 28  12. You are using Amazon EKS to deploy a Kuber...
# 29  13. You are using Amazon CloudWatch Events to ...
# 30  14. You are using Amazon Kinesis Data Streams ...
# 31  15. You are using Amazon SNS to send notificat...
# 32  16. You are using Amazon Redshift for data war...
# 33  1. You are designing a highly available and sc...
# 34  2. You are using Amazon EC2 instances to host ...
# 35  3. You are using Amazon DynamoDB for storing d...
# 36  4. You are using Amazon CloudWatch to monitor ...
# 37  5. You are using Amazon S3 to store your appli...
# 38  6. You are using Amazon Route 53 to manage the...
#
#                                                answer
# 15   A. True\nB. False\n**Correct Answer: A. True**\n
# 16   A. True\nB. False\n**Correct Answer: A. True**\n
# 17  A. Amazon S3\nB. Amazon Route 53\nC. Amazon Cl...
# 18  A. Amazon RDS for MySQL\nB. Amazon DynamoDB\nC...
# 19  A. CPUUtilization\nB. NetworkIn\nC. DiskReadBy...
# 20  A. Amazon S3\nB. Amazon EBS\nC. Amazon KMS\nD....
# 21  A. Custom authorizers\nB. Usage plans\nC. CORS...
# 22  A. HTTP health check\nB. HTTPS health check\nC...
# 23  A. Message retention\nB. Dead letter queues\nC...
# 24  A. Attaching the "AmazonDynamoDBFullAccess" ma...
# 25  A. ECS task definitions\nB. ECS cluster capaci...
# 26  A. Configuring the S3 bucket's access policy\n...
# 27  A. Cognito user pools\nB. Cognito identity poo...
# 28  A. EKS node groups\nB. EKS cluster autoscaling...
# 29  A. aws.s3.object.created:Put\nB. aws.s3.bucket...
# 30  A. Kinesis Data Streams shards\nB. Kinesis Dat...
# 31  A. SNS topic subscriptions\nB. SNS message ret...
# 32  A. Redshift Spectrum\nB. Redshift Cluster Auto...
# 33  A. Amazon S3\nB. Amazon DynamoDB\nC. Amazon El...
# 34  A. Use security groups to control network traf...
# 35  A. DynamoDB global tables\nB. DynamoDB on-dema...
# 36  A. CPUUtilization\nB. NetworkIn\nC. DiskReadBy...
# 37  A. Use bucket policies to control access to yo...
# 38  A. Route 53 health checks\nB. Route 53 failove...

# %%
# Make a copy of df0
df1 = df0.copy()

# %%
# Strip the numbers
df1['question'] = df1['question'].str.replace(r'^\d{0,4}\.[ ]', '', regex=True)

# %%
df1
# Out:
#                                              question  \
# 0   You are running a mission-critical application...
# 1   You are setting up a new Amazon S3 bucket for ...
# 2   You are designing a highly scalable, low-laten...
# 3   You are using Amazon CloudFront to distribute ...
# 4   You are developing a serverless application th...
# 5   You are using Amazon ECS to deploy a container...
# 6   You are using Amazon API Gateway to expose a R...
# 7   You are using Amazon Route 53 for DNS manageme...
# 8   You are using Amazon CloudWatch to monitor you...
# 9   You are using Amazon VPC to create a private n...
# 10  You are using Amazon SQS to implement a messag...
# 11  You are using Amazon Redshift for data warehou...
# 12  You are using Amazon EKS to deploy a Kubernete...
# 13  You are using Amazon Cognito for user authenti...
# 14  You are using Amazon CloudWatch Events to trig...
# 15  You are using Amazon Kinesis Data Streams for ...
# 16  You are using Amazon SNS to send notifications...
# 17  You are running a web application on Amazon EC...
# 18  You are designing a database for a new applica...
# 19  You are using Amazon CloudWatch to monitor the...
# 20  You are building a new application that requir...
# 21  You are using Amazon API Gateway to expose a R...
# 22  You are using Amazon Route 53 to manage the DN...
# 23  You are using Amazon SQS to implement a messag...
# 24  You are building a serverless application usin...
# 25  You are using Amazon ECS to deploy a container...
# 26  You are using Amazon CloudFront to distribute ...
# 27  You are using Amazon Cognito for user authenti...
# 28  You are using Amazon EKS to deploy a Kubernete...
# 29  You are using Amazon CloudWatch Events to trig...
# 30  You are using Amazon Kinesis Data Streams for ...
# 31  You are using Amazon SNS to send notifications...
# 32  You are using Amazon Redshift for data warehou...
# 33  You are designing a highly available and scala...
# 34  You are using Amazon EC2 instances to host you...
# 35  You are using Amazon DynamoDB for storing data...
# 36  You are using Amazon CloudWatch to monitor the...
# 37  You are using Amazon S3 to store your applicat...
# 38  You are using Amazon Route 53 to manage the DN...
# 39  You are using Amazon CloudFront to distribute ...
# 40  You are using Amazon ElastiCache to implement ...
# 41  You are using Amazon SNS to send notifications...
# 42  You are using Amazon SQS to implement a messag...
# 43  You are using Amazon ECS to deploy a container...
# 44  You are using Amazon API Gateway to expose a R...
# 45  You are using Amazon Kinesis Data Streams for ...
# 46  You are using Amazon CloudWatch Events to trig...
# 47  You are using Amazon Cognito for user authenti...
# 48  You are using Amazon EKS to deploy a Kubernete...
# 49  You are using Amazon Redshift for data warehou...
#
#                                                answer
# 0   A. True\nB. False\n**Correct Answer: B. False**\n
# 1   A. True\nB. False\n**Correct Answer: B. False**\n
# 2    A. True\nB. False\n**Correct Answer: A. True**\n
# 3   A. True\nB. False\n**Correct Answer: B. False**\n
# 4   A. True\nB. False\n**Correct Answer: B. False**\n
# 5    A. True\nB. False\n**Correct Answer: A. True**\n
# 6    A. True\nB. False\n**Correct Answer: A. True**\n
# 7    A. True\nB. False\n**Correct Answer: A. True**\n
# 8   A. True\nB. False\n**Correct Answer: B. False**\n
# 9    A. True\nB. False\n**Correct Answer: A. True**\n
# 10   A. True\nB. False\n**Correct Answer: A. True**\n
# 11   A. True\nB. False\n**Correct Answer: A. True**\n
# 12   A. True\nB. False\n**Correct Answer: A. True**\n
# 13   A. True\nB. False\n**Correct Answer: A. True**\n
# 14   A. True\nB. False\n**Correct Answer: A. True**\n
# 15   A. True\nB. False\n**Correct Answer: A. True**\n
# 16   A. True\nB. False\n**Correct Answer: A. True**\n
# 17  A. Amazon S3\nB. Amazon Route 53\nC. Amazon Cl...
# 18  A. Amazon RDS for MySQL\nB. Amazon DynamoDB\nC...
# 19  A. CPUUtilization\nB. NetworkIn\nC. DiskReadBy...
# 20  A. Amazon S3\nB. Amazon EBS\nC. Amazon KMS\nD....
# 21  A. Custom authorizers\nB. Usage plans\nC. CORS...
# 22  A. HTTP health check\nB. HTTPS health check\nC...
# 23  A. Message retention\nB. Dead letter queues\nC...
# 24  A. Attaching the "AmazonDynamoDBFullAccess" ma...
# 25  A. ECS task definitions\nB. ECS cluster capaci...
# 26  A. Configuring the S3 bucket's access policy\n...
# 27  A. Cognito user pools\nB. Cognito identity poo...
# 28  A. EKS node groups\nB. EKS cluster autoscaling...
# 29  A. aws.s3.object.created:Put\nB. aws.s3.bucket...
# 30  A. Kinesis Data Streams shards\nB. Kinesis Dat...
# 31  A. SNS topic subscriptions\nB. SNS message ret...
# 32  A. Redshift Spectrum\nB. Redshift Cluster Auto...
# 33  A. Amazon S3\nB. Amazon DynamoDB\nC. Amazon El...
# 34  A. Use security groups to control network traf...
# 35  A. DynamoDB global tables\nB. DynamoDB on-dema...
# 36  A. CPUUtilization\nB. NetworkIn\nC. DiskReadBy...
# 37  A. Use bucket policies to control access to yo...
# 38  A. Route 53 health checks\nB. Route 53 failove...
# 39  A. CloudFront origin shields\nB. CloudFront cu...
# 40  A. ElastiCache replication\nB. ElastiCache mul...
# 41  A. SNS topic subscriptions\nB. SNS message fil...
# 42  A. SQS message retention\nB. SQS dead letter q...
# 43  A. Use ECS task definitions to define security...
# 44  A. API Gateway custom authorizers\nB. API Gate...
# 45  A. Kinesis Data Streams shards\nB. Kinesis Dat...
# 46  A. aws.s3.object.created:Put\nB. aws.s3.object...
# 47  A. Cognito user pools\nB. Cognito identity poo...
# 48  A. EKS node groups\nB. EKS cluster autoscaling...
# 49  A. Redshift Spectrum\nB. Redshift Cluster Auto...

# %%
# Make a copy of `df1`
df_2 = df1.copy()

# %%
df_2
# Out:
#                                              question  \
# 0   You are running a mission-critical application...
# 1   You are setting up a new Amazon S3 bucket for ...
# 2   You are designing a highly scalable, low-laten...
# 3   You are using Amazon CloudFront to distribute ...
# 4   You are developing a serverless application th...
# 5   You are using Amazon ECS to deploy a container...
# 6   You are using Amazon API Gateway to expose a R...
# 7   You are using Amazon Route 53 for DNS manageme...
# 8   You are using Amazon CloudWatch to monitor you...
# 9   You are using Amazon VPC to create a private n...
# 10  You are using Amazon SQS to implement a messag...
# 11  You are using Amazon Redshift for data warehou...
# 12  You are using Amazon EKS to deploy a Kubernete...
# 13  You are using Amazon Cognito for user authenti...
# 14  You are using Amazon CloudWatch Events to trig...
# 15  You are using Amazon Kinesis Data Streams for ...
# 16  You are using Amazon SNS to send notifications...
# 17  You are running a web application on Amazon EC...
# 18  You are designing a database for a new applica...
# 19  You are using Amazon CloudWatch to monitor the...
# 20  You are building a new application that requir...
# 21  You are using Amazon API Gateway to expose a R...
# 22  You are using Amazon Route 53 to manage the DN...
# 23  You are using Amazon SQS to implement a messag...
# 24  You are building a serverless application usin...
# 25  You are using Amazon ECS to deploy a container...
# 26  You are using Amazon CloudFront to distribute ...
# 27  You are using Amazon Cognito for user authenti...
# 28  You are using Amazon EKS to deploy a Kubernete...
# 29  You are using Amazon CloudWatch Events to trig...
# 30  You are using Amazon Kinesis Data Streams for ...
# 31  You are using Amazon SNS to send notifications...
# 32  You are using Amazon Redshift for data warehou...
# 33  You are designing a highly available and scala...
# 34  You are using Amazon EC2 instances to host you...
# 35  You are using Amazon DynamoDB for storing data...
# 36  You are using Amazon CloudWatch to monitor the...
# 37  You are using Amazon S3 to store your applicat...
# 38  You are using Amazon Route 53 to manage the DN...
# 39  You are using Amazon CloudFront to distribute ...
# 40  You are using Amazon ElastiCache to implement ...
# 41  You are using Amazon SNS to send notifications...
# 42  You are using Amazon SQS to implement a messag...
# 43  You are using Amazon ECS to deploy a container...
# 44  You are using Amazon API Gateway to expose a R...
# 45  You are using Amazon Kinesis Data Streams for ...
# 46  You are using Amazon CloudWatch Events to trig...
# 47  You are using Amazon Cognito for user authenti...
# 48  You are using Amazon EKS to deploy a Kubernete...
# 49  You are using Amazon Redshift for data warehou...
#
#                                                answer
# 0   A. True\nB. False\n**Correct Answer: B. False**\n
# 1   A. True\nB. False\n**Correct Answer: B. False**\n
# 2    A. True\nB. False\n**Correct Answer: A. True**\n
# 3   A. True\nB. False\n**Correct Answer: B. False**\n
# 4   A. True\nB. False\n**Correct Answer: B. False**\n
# 5    A. True\nB. False\n**Correct Answer: A. True**\n
# 6    A. True\nB. False\n**Correct Answer: A. True**\n
# 7    A. True\nB. False\n**Correct Answer: A. True**\n
# 8   A. True\nB. False\n**Correct Answer: B. False**\n
# 9    A. True\nB. False\n**Correct Answer: A. True**\n
# 10   A. True\nB. False\n**Correct Answer: A. True**\n
# 11   A. True\nB. False\n**Correct Answer: A. True**\n
# 12   A. True\nB. False\n**Correct Answer: A. True**\n
# 13   A. True\nB. False\n**Correct Answer: A. True**\n
# 14   A. True\nB. False\n**Correct Answer: A. True**\n
# 15   A. True\nB. False\n**Correct Answer: A. True**\n
# 16   A. True\nB. False\n**Correct Answer: A. True**\n
# 17  A. Amazon S3\nB. Amazon Route 53\nC. Amazon Cl...
# 18  A. Amazon RDS for MySQL\nB. Amazon DynamoDB\nC...
# 19  A. CPUUtilization\nB. NetworkIn\nC. DiskReadBy...
# 20  A. Amazon S3\nB. Amazon EBS\nC. Amazon KMS\nD....
# 21  A. Custom authorizers\nB. Usage plans\nC. CORS...
# 22  A. HTTP health check\nB. HTTPS health check\nC...
# 23  A. Message retention\nB. Dead letter queues\nC...
# 24  A. Attaching the "AmazonDynamoDBFullAccess" ma...
# 25  A. ECS task definitions\nB. ECS cluster capaci...
# 26  A. Configuring the S3 bucket's access policy\n...
# 27  A. Cognito user pools\nB. Cognito identity poo...
# 28  A. EKS node groups\nB. EKS cluster autoscaling...
# 29  A. aws.s3.object.created:Put\nB. aws.s3.bucket...
# 30  A. Kinesis Data Streams shards\nB. Kinesis Dat...
# 31  A. SNS topic subscriptions\nB. SNS message ret...
# 32  A. Redshift Spectrum\nB. Redshift Cluster Auto...
# 33  A. Amazon S3\nB. Amazon DynamoDB\nC. Amazon El...
# 34  A. Use security groups to control network traf...
# 35  A. DynamoDB global tables\nB. DynamoDB on-dema...
# 36  A. CPUUtilization\nB. NetworkIn\nC. DiskReadBy...
# 37  A. Use bucket policies to control access to yo...
# 38  A. Route 53 health checks\nB. Route 53 failove...
# 39  A. CloudFront origin shields\nB. CloudFront cu...
# 40  A. ElastiCache replication\nB. ElastiCache mul...
# 41  A. SNS topic subscriptions\nB. SNS message fil...
# 42  A. SQS message retention\nB. SQS dead letter q...
# 43  A. Use ECS task definitions to define security...
# 44  A. API Gateway custom authorizers\nB. API Gate...
# 45  A. Kinesis Data Streams shards\nB. Kinesis Dat...
# 46  A. aws.s3.object.created:Put\nB. aws.s3.object...
# 47  A. Cognito user pools\nB. Cognito identity poo...
# 48  A. EKS node groups\nB. EKS cluster autoscaling...
# 49  A. Redshift Spectrum\nB. Redshift Cluster Auto...

# %%
df_2['answer'][30]
# Out:
# 'A. Kinesis Data Streams shards\nB. Kinesis Data Streams retention policy\nC. Kinesis Data Streams scaling policy\nD. Kinesis Data Streams consumer groups\n**Correct Answer: A. Kinesis Data Streams shards**\n'

# %%
def choices_split(answer):
    """
    Split the `answer` data into multiple choices
    """
    # Use '**' to split text, index 0 is all choices, index 1 is all answers, index 2 is '\n'
    # print(answer)
    split_all = re.split(r'\*\*', answer)
    # print("Strip '**': ", split_all)
    choices = split_all[0]
    # print('Choices text:', choices)
    correct = split_all[1].replace('Correct Answer: ', '')
    # print('Correct text:', correct)
    
    choices = re.split(r'[A-Z]\.[ ]', choices)[1:]
    choices = [choice.rstrip() for choice in choices]
    # print('All choices in list: ', choices)
    correct = re.split(r'[A-Z]\.[ ]', correct)[1:]
    correct = [item.rstrip(', ') for item in correct]
    # print('Correct in list: ', correct)
    incorrect = list(set(choices) - set(correct))
    # print('Incorrect in list: ', incorrect)
    
    return {'incorrect': incorrect,
            'correct': correct}

# %%
df_test = df_2.iloc[40:42]['answer'].apply(choices_split)

# %%
display(df_test.str['incorrect'])
df_test.str['correct']
# Out:
# 40    [ElastiCache data sharding, ElastiCache cluste...
# 41    [SNS message deduplication, SNS message retry ...
# Name: answer, dtype: object
# 40    [ElastiCache replication, ElastiCache multi-AZ...
# 41     [SNS topic subscriptions, SNS message filtering]
# Name: answer, dtype: object

# %%
df_2['incorrect'] = df_2['answer'].apply(choices_split).str['incorrect']
df_2['correct'] = df_2['answer'].apply(choices_split).str['correct']

# %%
display(df_2.loc[40, 'incorrect'])
display(df_2.loc[40, 'correct'])
# Out:
# ['ElastiCache data sharding', 'ElastiCache cluster auto scaling']
# ['ElastiCache replication', 'ElastiCache multi-AZ deployments']

# %%
# New order of columns
new_order = ['question', 'incorrect', 'correct']

# Make a copy of `df_a` with new order of columns
df_clean = df_2[new_order].copy()

display(df_clean['incorrect'][45])

display(df_clean['correct'][45])

df_clean.iloc[45]
# Out:
# ['Kinesis Data Streams retention policy',
#  'Kinesis Data Streams scaling policy']
# ['Kinesis Data Streams shards', 'Kinesis Data Streams consumer groups']
# question     You are using Amazon Kinesis Data Streams for ...
# incorrect    [Kinesis Data Streams retention policy, Kinesi...
# correct      [Kinesis Data Streams shards, Kinesis Data Str...
# Name: 45, dtype: object

# %%
df_clean
# Out:
#                                              question  \
# 0   You are running a mission-critical application...
# 1   You are setting up a new Amazon S3 bucket for ...
# 2   You are designing a highly scalable, low-laten...
# 3   You are using Amazon CloudFront to distribute ...
# 4   You are developing a serverless application th...
# 5   You are using Amazon ECS to deploy a container...
# 6   You are using Amazon API Gateway to expose a R...
# 7   You are using Amazon Route 53 for DNS manageme...
# 8   You are using Amazon CloudWatch to monitor you...
# 9   You are using Amazon VPC to create a private n...
# 10  You are using Amazon SQS to implement a messag...
# 11  You are using Amazon Redshift for data warehou...
# 12  You are using Amazon EKS to deploy a Kubernete...
# 13  You are using Amazon Cognito for user authenti...
# 14  You are using Amazon CloudWatch Events to trig...
# 15  You are using Amazon Kinesis Data Streams for ...
# 16  You are using Amazon SNS to send notifications...
# 17  You are running a web application on Amazon EC...
# 18  You are designing a database for a new applica...
# 19  You are using Amazon CloudWatch to monitor the...
# 20  You are building a new application that requir...
# 21  You are using Amazon API Gateway to expose a R...
# 22  You are using Amazon Route 53 to manage the DN...
# 23  You are using Amazon SQS to implement a messag...
# 24  You are building a serverless application usin...
# 25  You are using Amazon ECS to deploy a container...
# 26  You are using Amazon CloudFront to distribute ...
# 27  You are using Amazon Cognito for user authenti...
# 28  You are using Amazon EKS to deploy a Kubernete...
# 29  You are using Amazon CloudWatch Events to trig...
# 30  You are using Amazon Kinesis Data Streams for ...
# 31  You are using Amazon SNS to send notifications...
# 32  You are using Amazon Redshift for data warehou...
# 33  You are designing a highly available and scala...
# 34  You are using Amazon EC2 instances to host you...
# 35  You are using Amazon DynamoDB for storing data...
# 36  You are using Amazon CloudWatch to monitor the...
# 37  You are using Amazon S3 to store your applicat...
# 38  You are using Amazon Route 53 to manage the DN...
# 39  You are using Amazon CloudFront to distribute ...
# 40  You are using Amazon ElastiCache to implement ...
# 41  You are using Amazon SNS to send notifications...
# 42  You are using Amazon SQS to implement a messag...
# 43  You are using Amazon ECS to deploy a container...
# 44  You are using Amazon API Gateway to expose a R...
# 45  You are using Amazon Kinesis Data Streams for ...
# 46  You are using Amazon CloudWatch Events to trig...
# 47  You are using Amazon Cognito for user authenti...
# 48  You are using Amazon EKS to deploy a Kubernete...
# 49  You are using Amazon Redshift for data warehou...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                              [True]
# 2                                             [False]
# 3                                              [True]
# 4                                              [True]
# 5                                             [False]
# 6                                             [False]
# 7                                             [False]
# 8                                              [True]
# 9                                             [False]
# 10                                            [False]
# 11                                            [False]
# 12                                            [False]
# 13                                            [False]
# 14                                            [False]
# 15                                            [False]
# 16                                            [False]
# 17    [Amazon CloudFront, Amazon Route 53, Amazon S3]
# 18  [Amazon DynamoDB, Amazon RDS for MySQL, Amazon...
# 19         [NetworkIn, DiskReadBytes, DiskWriteBytes]
# 20           [Amazon DynamoDB, Amazon EBS, Amazon S3]
# 21  [Custom authorizers, Integration requests, COR...
# 22  [HTTPS health check, HTTP health check, CloudW...
# 23  [Message visibility timeout, Message deduplica...
# 24  [Creating an IAM role with permissions to Dyna...
# 25  [ECS cluster capacity, ECS task definitions, E...
# 26  [Configuring CloudFront's viewer request origi...
# 27  [Cognito identity pools, Cognito custom authen...
# 28  [EKS cluster control plane, EKS cluster autosc...
# 29  [aws.s3.bucket.deleted, aws.s3.object.put, aws...
# 30  [Kinesis Data Streams retention policy, Kinesi...
# 31  [SNS message deduplication, SNS topic subscrip...
# 32  [Redshift Spectrum, Redshift Data Sharing, Red...
# 33              [Amazon ElastiCache, Amazon Redshift]
# 34  [Use AWS Key Management Service (KMS) to encry...
# 35  [DynamoDB provisioned capacity, DynamoDB on-de...
# 36                                   [DiskWriteBytes]
# 37  [Configure S3 access control lists (ACLs) to g...
# 38  [Route 53 latency-based routing, Route 53 weig...
# 39  [CloudFront origin shields, CloudFront custom ...
# 40  [ElastiCache data sharding, ElastiCache cluste...
# 41  [SNS message deduplication, SNS message retry ...
# 42  [SQS message deduplication, SQS message retent...
# 43  [Use ECS cluster capacity to manage the number...
# 44  [API Gateway CORS configuration, API Gateway i...
# 45  [Kinesis Data Streams retention policy, Kinesi...
# 46     [aws.s3.bucket.deleted, aws.s3.bucket.created]
# 47  [Cognito identity pools, Cognito custom authen...
# 48  [EKS cluster control plane, EKS cluster autosc...
# 49  [Redshift Spectrum, Redshift Cluster Auto Scal...
#
#                                               correct
# 0                                             [False]
# 1                                             [False]
# 2                                              [True]
# 3                                             [False]
# 4                                             [False]
# 5                                              [True]
# 6                                              [True]
# 7                                              [True]
# 8                                             [False]
# 9                                              [True]
# 10                                             [True]
# 11                                             [True]
# 12                                             [True]
# 13                                             [True]
# 14                                             [True]
# 15                                             [True]
# 16                                             [True]
# 17                              [Amazon Auto Scaling]
# 18                                    [Amazon Aurora]
# 19                                   [CPUUtilization]
# 20                                       [Amazon KMS]
# 21                                      [Usage plans]
# 22                                 [TCP health check]
# 23                                [Message retention]
# 24  [Configuring the Lambda function's execution r...
# 25                     [ECS service scaling policies]
# 26        [Using CloudFront's origin access identity]
# 27                     [Cognito federated identities]
# 28                          [EKS managed node groups]
# 29                            [aws.s3.bucket.created]
# 30                      [Kinesis Data Streams shards]
# 31                         [SNS message retry policy]
# 32                      [Redshift Query Optimization]
# 33                       [Amazon S3, Amazon DynamoDB]
# 34  [Use security groups to control network traffi...
# 35         [DynamoDB global tables, DynamoDB streams]
# 36         [CPUUtilization, NetworkIn, DiskReadBytes]
# 37  [Use bucket policies to control access to your...
# 38  [Route 53 health checks, Route 53 failover rou...
# 39  [CloudFront cache behaviors, CloudFront signed...
# 40  [ElastiCache replication, ElastiCache multi-AZ...
# 41   [SNS topic subscriptions, SNS message filtering]
# 42  [SQS dead letter queues, SQS message visibilit...
# 43  [Use ECS task definitions to define security c...
# 44  [API Gateway custom authorizers, API Gateway u...
# 45  [Kinesis Data Streams shards, Kinesis Data Str...
# 46     [aws.s3.object.created:Put, aws.s3.object.put]
# 47  [Cognito user pools, Cognito federated identit...
# 48         [EKS node groups, EKS managed node groups]
# 49  [Redshift Query Optimization, Redshift Data Sh...

# %%
export_file = BLOB[:-4] + '.json'
# Export `df_clean` to a JSON file
df_clean.to_json(export_file)

# %%
df_json = pd.read_json(export_file)

# %%
df_json
# Out:
#                                              question  \
# 0   You are running a mission-critical application...
# 1   You are setting up a new Amazon S3 bucket for ...
# 2   You are designing a highly scalable, low-laten...
# 3   You are using Amazon CloudFront to distribute ...
# 4   You are developing a serverless application th...
# 5   You are using Amazon ECS to deploy a container...
# 6   You are using Amazon API Gateway to expose a R...
# 7   You are using Amazon Route 53 for DNS manageme...
# 8   You are using Amazon CloudWatch to monitor you...
# 9   You are using Amazon VPC to create a private n...
# 10  You are using Amazon SQS to implement a messag...
# 11  You are using Amazon Redshift for data warehou...
# 12  You are using Amazon EKS to deploy a Kubernete...
# 13  You are using Amazon Cognito for user authenti...
# 14  You are using Amazon CloudWatch Events to trig...
# 15  You are using Amazon Kinesis Data Streams for ...
# 16  You are using Amazon SNS to send notifications...
# 17  You are running a web application on Amazon EC...
# 18  You are designing a database for a new applica...
# 19  You are using Amazon CloudWatch to monitor the...
# 20  You are building a new application that requir...
# 21  You are using Amazon API Gateway to expose a R...
# 22  You are using Amazon Route 53 to manage the DN...
# 23  You are using Amazon SQS to implement a messag...
# 24  You are building a serverless application usin...
# 25  You are using Amazon ECS to deploy a container...
# 26  You are using Amazon CloudFront to distribute ...
# 27  You are using Amazon Cognito for user authenti...
# 28  You are using Amazon EKS to deploy a Kubernete...
# 29  You are using Amazon CloudWatch Events to trig...
# 30  You are using Amazon Kinesis Data Streams for ...
# 31  You are using Amazon SNS to send notifications...
# 32  You are using Amazon Redshift for data warehou...
# 33  You are designing a highly available and scala...
# 34  You are using Amazon EC2 instances to host you...
# 35  You are using Amazon DynamoDB for storing data...
# 36  You are using Amazon CloudWatch to monitor the...
# 37  You are using Amazon S3 to store your applicat...
# 38  You are using Amazon Route 53 to manage the DN...
# 39  You are using Amazon CloudFront to distribute ...
# 40  You are using Amazon ElastiCache to implement ...
# 41  You are using Amazon SNS to send notifications...
# 42  You are using Amazon SQS to implement a messag...
# 43  You are using Amazon ECS to deploy a container...
# 44  You are using Amazon API Gateway to expose a R...
# 45  You are using Amazon Kinesis Data Streams for ...
# 46  You are using Amazon CloudWatch Events to trig...
# 47  You are using Amazon Cognito for user authenti...
# 48  You are using Amazon EKS to deploy a Kubernete...
# 49  You are using Amazon Redshift for data warehou...
#
#                                             incorrect  \
# 0                                              [True]
# 1                                              [True]
# 2                                             [False]
# 3                                              [True]
# 4                                              [True]
# 5                                             [False]
# 6                                             [False]
# 7                                             [False]
# 8                                              [True]
# 9                                             [False]
# 10                                            [False]
# 11                                            [False]
# 12                                            [False]
# 13                                            [False]
# 14                                            [False]
# 15                                            [False]
# 16                                            [False]
# 17    [Amazon CloudFront, Amazon Route 53, Amazon S3]
# 18  [Amazon DynamoDB, Amazon RDS for MySQL, Amazon...
# 19         [NetworkIn, DiskReadBytes, DiskWriteBytes]
# 20           [Amazon DynamoDB, Amazon EBS, Amazon S3]
# 21  [Custom authorizers, Integration requests, COR...
# 22  [HTTPS health check, HTTP health check, CloudW...
# 23  [Message visibility timeout, Message deduplica...
# 24  [Creating an IAM role with permissions to Dyna...
# 25  [ECS cluster capacity, ECS task definitions, E...
# 26  [Configuring CloudFront's viewer request origi...
# 27  [Cognito identity pools, Cognito custom authen...
# 28  [EKS cluster control plane, EKS cluster autosc...
# 29  [aws.s3.bucket.deleted, aws.s3.object.put, aws...
# 30  [Kinesis Data Streams retention policy, Kinesi...
# 31  [SNS message deduplication, SNS topic subscrip...
# 32  [Redshift Spectrum, Redshift Data Sharing, Red...
# 33              [Amazon ElastiCache, Amazon Redshift]
# 34  [Use AWS Key Management Service (KMS) to encry...
# 35  [DynamoDB provisioned capacity, DynamoDB on-de...
# 36                                   [DiskWriteBytes]
# 37  [Configure S3 access control lists (ACLs) to g...
# 38  [Route 53 latency-based routing, Route 53 weig...
# 39  [CloudFront origin shields, CloudFront custom ...
# 40  [ElastiCache data sharding, ElastiCache cluste...
# 41  [SNS message deduplication, SNS message retry ...
# 42  [SQS message deduplication, SQS message retent...
# 43  [Use ECS cluster capacity to manage the number...
# 44  [API Gateway CORS configuration, API Gateway i...
# 45  [Kinesis Data Streams retention policy, Kinesi...
# 46     [aws.s3.bucket.deleted, aws.s3.bucket.created]
# 47  [Cognito identity pools, Cognito custom authen...
# 48  [EKS cluster control plane, EKS cluster autosc...
# 49  [Redshift Spectrum, Redshift Cluster Auto Scal...
#
#                                               correct
# 0                                             [False]
# 1                                             [False]
# 2                                              [True]
# 3                                             [False]
# 4                                             [False]
# 5                                              [True]
# 6                                              [True]
# 7                                              [True]
# 8                                             [False]
# 9                                              [True]
# 10                                             [True]
# 11                                             [True]
# 12                                             [True]
# 13                                             [True]
# 14                                             [True]
# 15                                             [True]
# 16                                             [True]
# 17                              [Amazon Auto Scaling]
# 18                                    [Amazon Aurora]
# 19                                   [CPUUtilization]
# 20                                       [Amazon KMS]
# 21                                      [Usage plans]
# 22                                 [TCP health check]
# 23                                [Message retention]
# 24  [Configuring the Lambda function's execution r...
# 25                     [ECS service scaling policies]
# 26        [Using CloudFront's origin access identity]
# 27                     [Cognito federated identities]
# 28                          [EKS managed node groups]
# 29                            [aws.s3.bucket.created]
# 30                      [Kinesis Data Streams shards]
# 31                         [SNS message retry policy]
# 32                      [Redshift Query Optimization]
# 33                       [Amazon S3, Amazon DynamoDB]
# 34  [Use security groups to control network traffi...
# 35         [DynamoDB global tables, DynamoDB streams]
# 36         [CPUUtilization, NetworkIn, DiskReadBytes]
# 37  [Use bucket policies to control access to your...
# 38  [Route 53 health checks, Route 53 failover rou...
# 39  [CloudFront cache behaviors, CloudFront signed...
# 40  [ElastiCache replication, ElastiCache multi-AZ...
# 41   [SNS topic subscriptions, SNS message filtering]
# 42  [SQS dead letter queues, SQS message visibilit...
# 43  [Use ECS task definitions to define security c...
# 44  [API Gateway custom authorizers, API Gateway u...
# 45  [Kinesis Data Streams shards, Kinesis Data Str...
# 46     [aws.s3.object.created:Put, aws.s3.object.put]
# 47  [Cognito user pools, Cognito federated identit...
# 48         [EKS node groups, EKS managed node groups]
# 49  [Redshift Query Optimization, Redshift Data Sh...

# %%
import json

f = open(export_file)
data = json.load(f)
data['question']['15']
# Out:
# 'You are using Amazon Kinesis Data Streams for real-time data processing. You can configure Kinesis Data Streams to automatically scale the number of shards based on the data throughput. This allows you to handle high data volumes without needing to manually adjust the number of shards.\n'
